# %%
data_orig = pd.read_csv('/Users/kimjeongseob/Desktop/Github upload/5.EDA/EDA 프로젝트/googleplaystore.csv')
data_orig.head()
data_orig.loc[9148]
# Out:
# App               Command & Conquer: Rivals
# Category                             FAMILY
# Rating                                  NaN
# Reviews                                   0
# Size                     Varies with device
# Installs                                  0
# Type                                    NaN
# Price                                     0
# Content Rating                 Everyone 10+
# Genres                             Strategy
# Last Updated                  June 28, 2018
# Current Ver              Varies with device
# Android Ver              Varies with device
# Name: 9148, dtype: object

# %%
# - 10472 행 -> 한 컬럼씩 밀림
# - 9148 행 -> 모두 nan 값

data_orig = data_orig.drop(index = 10472)
data_orig = data_orig.drop(index = 9148)

# %%
data_orig.shape
# Out:
# (10839, 13)

# %%
data_orig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10839 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10839 non-null  object
#  1   Category        10839 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10839 non-null  object
#  4   Size            10839 non-null  object
#  5   Installs        10839 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10839 non-null  object
#  8   Content Rating  10839 non-null  object
#  9   Genres          10839 non-null  object
#  10  Last Updated    10839 non-null  object
#  11  Current Ver     10831 non-null  object
#  12  Android Ver     10837 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.2+ MB

# %%
data = df1
col_df2 = ['Size','Installs','Type']
col_df3 = ['Price','Content Rating','Genres','pri_genres','sec_genres']
col_df4 = ['Current_Ver','Ver_Mon','Ver_Year','And_1st_Ver','And_Last_Ver']

# %%
data['Size'] = df2['Size']
data['Installs'] =df2['Installs']
data['Type'] = df2['Type']
data['Price'] = df3['Price']
data['Content Rating'] = df3['Content Rating']
data['Genres'] = df3['Genres']
data['pri_genres'] = df3['pri_genres']
data['sec_genres'] = df3['sec_genres']
data['Current_Ver'] = df4['Current_Ver']
data['Ver_Mon'] = df4['Ver_Mon']
data['Ver_Year'] = df4['Ver_Year']
data['And_1st_Ver'] = df4['And_1st_Ver']
data['And_Last_Ver'] = df4['And_Last_Ver']
data = data.drop(columns = ['Unnamed: 0'])
data
# Out:
#                   Category  Rating   Reviews  Size    Installs  Type  Price  \
# 0           ART_AND_DESIGN     4.1     159.0  19.0     10000.0   0.0    0.0
# 1           ART_AND_DESIGN     3.9     967.0  14.0    500000.0   0.0    0.0
# 2           ART_AND_DESIGN     4.7   87510.0   8.7   5000000.0   0.0    0.0
# 3           ART_AND_DESIGN     4.5  215644.0  25.0  50000000.0   0.0    0.0
# 4           ART_AND_DESIGN     4.3     967.0   2.8    100000.0   0.0    0.0
# ...                    ...     ...       ...   ...         ...   ...    ...
# 10834               FAMILY     4.5      38.0  53.0      5000.0   0.0    0.0
# 10835               FAMILY     5.0       4.0   3.6       100.0   0.0    0.0
# 10836              MEDICAL     0.0       3.0   9.5      1000.0   0.0    0.0
# 10837  BOOKS_AND_REFERENCE     4.5     114.0  37.0      1000.0   0.0    0.0
# 10838            LIFESTYLE     4.5  398307.0  19.0  10000000.0   0.0    0.0
#
# ...

# %%
data.to_csv('/Users/kimjeongseob/Desktop/Github upload/5.EDA/EDA 프로젝트/2차 _ 분석/데이터.csv',header = ['Category','Rating','reviews','Size','Installs','Type','Price','Content Rating','Genres','pri_genres','sec_genres','Current_Ver','Ver_Mon','Ver_Year','And_1st_Ver','And_Last_Ver'],index = True)

# %%
data
# Out:
#                   Category  Rating   Reviews  Size    Installs  Type  Price  \
# 0           ART_AND_DESIGN     4.1     159.0  19.0     10000.0   0.0    0.0
# 1           ART_AND_DESIGN     3.9     967.0  14.0    500000.0   0.0    0.0
# 2           ART_AND_DESIGN     4.7   87510.0   8.7   5000000.0   0.0    0.0
# 3           ART_AND_DESIGN     4.5  215644.0  25.0  50000000.0   0.0    0.0
# 4           ART_AND_DESIGN     4.3     967.0   2.8    100000.0   0.0    0.0
# ...                    ...     ...       ...   ...         ...   ...    ...
# 10834               FAMILY     4.5      38.0  53.0      5000.0   0.0    0.0
# 10835               FAMILY     5.0       4.0   3.6       100.0   0.0    0.0
# 10836              MEDICAL     0.0       3.0   9.5      1000.0   0.0    0.0
# 10837  BOOKS_AND_REFERENCE     4.5     114.0  37.0      1000.0   0.0    0.0
# 10838            LIFESTYLE     4.5  398307.0  19.0  10000000.0   0.0    0.0
#
# ...

# %%
data
# Out:
#                   Category  Rating   Reviews  Size    Installs  Type  Price  \
# 0           ART_AND_DESIGN     4.1     159.0  19.0     10000.0   0.0    0.0
# 1           ART_AND_DESIGN     3.9     967.0  14.0    500000.0   0.0    0.0
# 2           ART_AND_DESIGN     4.7   87510.0   8.7   5000000.0   0.0    0.0
# 3           ART_AND_DESIGN     4.5  215644.0  25.0  50000000.0   0.0    0.0
# 4           ART_AND_DESIGN     4.3     967.0   2.8    100000.0   0.0    0.0
# ...                    ...     ...       ...   ...         ...   ...    ...
# 10834               FAMILY     4.5      38.0  53.0      5000.0   0.0    0.0
# 10835               FAMILY     5.0       4.0   3.6       100.0   0.0    0.0
# 10836              MEDICAL     0.0       3.0   9.5      1000.0   0.0    0.0
# 10837  BOOKS_AND_REFERENCE     4.5     114.0  37.0      1000.0   0.0    0.0
# 10838            LIFESTYLE     4.5  398307.0  19.0  10000000.0   0.0    0.0
#
# ...

# %%
data['Content Rating'] = data['Content Rating'].astype('string')
data['Genres'] = data['Genres'].astype('string')
data['pri_genres'] = data['pri_genres'].astype('string')
data['sec_genres'] = data['sec_genres'].astype('string')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10839 entries, 0 to 10838
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        10839 non-null  object
#  1   Rating          10839 non-null  float64
#  2   Reviews         10839 non-null  float64
#  3   Size            10839 non-null  float64
#  4   Installs        10839 non-null  float64
#  5   Type            10839 non-null  float64
#  6   Price           10839 non-null  float64
#  7   Content Rating  10839 non-null  string
#  8   Genres          10839 non-null  string
#  9   pri_genres      10839 non-null  string
#  10  sec_genres      10839 non-null  string
#  11  Current_Ver     10831 non-null  object
#  12  Ver_Mon         10839 non-null  float64
#  13  Ver_Year        10839 non-null  float64
#  14  And_1st_Ver     10839 non-null  float64
#  15  And_Last_Ver    10819 non-null  float64
# dtypes: float64(10), object(2), string(4)
# ...

# %%
data.to_csv('/Users/kimjeongseob/Desktop/Github upload/5.EDA/EDA 프로젝트/2차 _ 분석/데이터_2.csv',header = ['Category','Rating','reviews','Size','Installs','Type','Price','Content Rating','Genres','pri_genres','sec_genres','Current_Ver','Ver_Mon','Ver_Year','And_1st_Ver','And_Last_Ver'],index = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10839 entries, 0 to 10838
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        10839 non-null  object
#  1   Rating          10839 non-null  float64
#  2   Reviews         10839 non-null  float64
#  3   Size            10839 non-null  float64
#  4   Installs        10839 non-null  float64
#  5   Type            10839 non-null  float64
#  6   Price           10839 non-null  float64
#  7   Content Rating  10839 non-null  string
#  8   Genres          10839 non-null  string
#  9   pri_genres      10839 non-null  string
#  10  sec_genres      10839 non-null  string
#  11  Current_Ver     10831 non-null  object
#  12  Ver_Mon         10839 non-null  float64
#  13  Ver_Year        10839 non-null  float64
#  14  And_1st_Ver     10839 non-null  float64
#  15  And_Last_Ver    10819 non-null  float64
# dtypes: float64(10), object(2), string(4)
# ...

# %%
# 인스톨 - 모든 컬럼 간 상관관계를 볼 수 있는 판다스 툴?

# 인스톨 - 카테고리
# 인스톨 - 가격과 리뷰수, c - a,b   df.plot.scatter(x='a', y='b', c='c', s=50); / df.plot.scatter(x='a', y='b', s=df['c'] * 200);
# 인스톨과 모든 컬럼 -> 스캐터 플롯

# In [83]: from pandas.plotting import scatter_matrix
# In [84]: df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])
# In [85]: scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde')
# In [109]: from pandas.plotting import radviz


# radviz?

# In [110]: data = pd.read_csv('data/iris.data')
# In [111]: plt.figure()
# Out[111]: <Figure size 640x480 with 0 Axes>
# In [112]: radviz(data, 'Name')
# Out[112]: <matplotlib.axes._subplots.AxesSubplot at 0x7f3d090f6710>

# %%
data.head()
# Out:
#          Category  Rating   Reviews  Size    Installs  Type  Price  \
# 0  ART_AND_DESIGN     4.1     159.0  19.0     10000.0   0.0    0.0
# 1  ART_AND_DESIGN     3.9     967.0  14.0    500000.0   0.0    0.0
# 2  ART_AND_DESIGN     4.7   87510.0   8.7   5000000.0   0.0    0.0
# 3  ART_AND_DESIGN     4.5  215644.0  25.0  50000000.0   0.0    0.0
# 4  ART_AND_DESIGN     4.3     967.0   2.8    100000.0   0.0    0.0
#
#   Content Rating                     Genres    pri_genres    sec_genres  \
# 0       Everyone               Art & Design  Art & Design  Art & Design
# 1       Everyone  Art & Design;Pretend Play  Art & Design  Pretend Play
# 2       Everyone               Art & Design  Art & Design  Art & Design
# 3           Teen               Art & Design  Art & Design  Art & Design
# 4       Everyone    Art & Design;Creativity  Art & Design    Creativity
#
#   Current_Ver  Ver_Mon  Ver_Year  And_1st_Ver  And_Last_Ver
# 0       1.0.0      1.0    2018.0          4.0          11.0
# ...

# %% [markdown]
# # 전체적인 상관관계 분석
# ## - price, size, Reviews, Rating, Installs

# %%
# 전체적인 상관관계 분석 - seaborn, heatmap
# 참고 : https://www.kaggle.com/mhmdpkts/playstore-preprocessing-and-eda


fit, ax = plt.subplots(figsize = (10,8))
ax = sns.heatmap(data[['Installs','Rating','Reviews','Size','Price']].corr(), annot=True, Linewidths=.5, fmt='.1f')
plt.show()

# 인스톨 - 리뷰 간 계수 0.6, 나머진 거의 없음..

# %% [markdown]
# # 카테고리 - count
# # 카테고리 - install

# %%
# 카테고리별 앱 갯수

plt.figure(figsize = (10,10))
g = sns.countplot(x='Category',data = data)
g.set_xticklabels(g.get_xticklabels(),rotation=90)
plt.title('Count of app in each category', size=20)
# Out:
# Text(0.5, 1.0, 'Count of app in each category')

# %%
# category 별 rate
# rate... 하위 25% 모두 0인 것들이 있는데.. 전처리할 때 value 조정한 것 있었는 지?

g = sns.catplot(x="Category",y="Rating",data=data, kind="box", height = 10 ,
palette = "Set1")
g.despine(left=True)
g.set_xticklabels(rotation=90)
g.set( xticks=range(0,34))
g = g.set_ylabels("Rating")
plt.title('Boxplot of Rating VS Category',size = 20)
# Out:
# Text(0.5, 1.0, 'Boxplot of Rating VS Category')

# %% [markdown]
# ### instrall 수의 편차가 너무 커 그래프가 담기 어려움
# - value를 조정해줘야할 필요가 있음

# %%
data_orig['Installs'].unique()
data_orig['Installs'].value_counts().sum()
# Out:
# 10839

# %%
data['Installs'].unique()
# Out:
# array([1.e+04, 5.e+05, 5.e+06, 5.e+07, 1.e+05, 5.e+04, 1.e+06, 1.e+07,
#        5.e+03, 1.e+08, 1.e+09, 1.e+03, 5.e+08, 5.e+01, 1.e+02, 5.e+02,
#        1.e+01, 1.e+00, 5.e+00, 0.e+00])

# %%
data['Installs'].value_counts().sum()
# Out:
# 10837

# %%
# install value값 조정 -> categorize

# 1) install 컬럼을 object형으로..

data['Installs'] = data_orig['Installs']
data['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', nan], dtype=object)

# %%
data.Installs = data.Installs.apply(lambda x: x.replace(',',''))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-254-5c91373a7016> in <module>
# ----> 1 data.Installs = data.Installs.apply(lambda x: x.replace(',',''))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-254-5c91373a7016> in <lambda>(x)
# ----> 1 data.Installs = data.Installs.apply(lambda x: x.replace(',',''))
#
# AttributeError: 'float' object has no attribute 'replace'

# %%
data.Installs = data.Installs.apply(lambda x: x.replace('+',''))

# %%
data.Installs = data.Installs.apply(lambda x: int(x))

# %%
data.Installs.unique()

# %%
sorted_value = sorted(list(data['Installs'].unique()))
sorted_value

# %%
# 카테고리별 install 수

plt.figure(figsize = (10,10))
g = sns.countplot(x='Category',y='Installs',data = data)
g.set_xticklabels(g.get_xticklabels(),rotation=90)
plt.title('Count of app in each category', size=20)

# %%
# 인스톨 - 가격과 리뷰수, c - a,b   
# df.plot.scatter(x='a', y='b', c='c', s=50)
# df.plot.scatter(x='a', y='b', s=df['c'] * 200)

plt.figure(figsize=(40,40))
data.plot.scatter(x='Reviews', y='Installs', c='Price', s=50)
