# %%
df = pd.read_csv("/Users/kimjeongseob/Desktop/Study/0.Project/2. Regression Anlaysis/5. Model tuning/dataset.csv")
df
# Out:
#         player_name  value  follower  shots_total  shots_on  goals_total  \
# 0       A. Anguissa   20.0     67879       0.5541    0.1288       0.0129
# 1        A. Bastoni   31.5    232370       0.3101    0.1128       0.0564
# 2        A. Belotti   32.0    740918       2.8169    1.0539       0.4432
# 3    A. Christensen   24.0    601838       0.3802    0.0613       0.0000
# 4         A. Correa   32.0    652886       1.9735    0.8442       0.2282
# ..              ...    ...       ...          ...       ...          ...
# 454         Y. Atal   20.0   1955121       1.3472    0.5672       0.1654
# 455     Y. Carrasco   22.5    797767       2.6060    0.8687       0.2044
# 456         Y. Mina   20.0   3339896       0.8766    0.3080       0.0711
# 457      Y. Poulsen   24.0    109000       2.0141    0.7524       0.3357
# 458    Y. Tielemans   44.0    282254       1.6978    0.6011       0.1476
#
#      goals_assists  passes_total  passes_key  passes_accuracy  ...  \
# 0           0.0000       22.1879      0.2706           3.2985  ...
# 1           0.0000       40.9924      0.3665          13.7863  ...
# 2           0.0985       12.3215      0.9554           4.0185  ...
# 3           0.0123       58.0206      0.1717          13.4535  ...
# 4           0.2167       23.4885      1.5286           9.1604  ...
# ..             ...           ...         ...              ...  ...
# 454         0.0236       28.5984      0.7800           5.6251  ...
# 455         0.3066       22.6878      1.6863          20.3373  ...
# 456         0.0474       46.6951      0.2843          14.5226  ...
# 457         0.2662       16.8654      1.2038           7.4314  ...
# 458         0.1371       38.4372      1.1705           6.6013  ...
#
#      substitutes_out  substitutes_bench  age_x  height_x  weight_x  rating_x  \
# 0             0.2577             0.5927   25.0     184.0      78.0  2.333333
# 1             0.0564             1.6070   21.0     190.0      75.0  4.777778
# 2             0.0689             0.0689   27.0     181.0      72.0  5.250000
# 3             0.1840             0.7604   24.0     188.0      78.0  6.000000
# 4             0.6731             0.6160   25.0     171.0      70.0  7.000000
# ..               ...                ...    ...       ...       ...       ...
# 454           0.1418             0.3782   24.0     176.0      64.0  3.333333
# 455           0.6643             1.2775   27.0     180.0      71.0  4.857143
# 456           0.0948             0.5449   26.0     195.0      94.0  6.125000
# 457           0.2894             0.5788   26.0     192.0      84.0  6.545455
# 458           0.3058             0.2636   23.0     176.0      72.0  4.384615
#
#      age_y  height_y  weight_y  rating_y
# 0     25.0     184.0      78.0  2.333333
# 1     21.0     190.0      75.0  4.777778
# 2     27.0     181.0      72.0  5.250000
# 3     24.0     188.0      78.0  6.000000
# 4     25.0     171.0      70.0  7.000000
# ..     ...       ...       ...       ...
# 454   24.0     176.0      64.0  3.333333
# 455   27.0     180.0      71.0  4.857143
# 456   26.0     195.0      94.0  6.125000
# 457   26.0     192.0      84.0  6.545455
# 458   23.0     176.0      72.0  4.384615
#
# [459 rows x 39 columns]

# %%
df = df.dropna()

# %%
df
# Out:
#         player_name  value  follower  shots_total  shots_on  goals_total  \
# 0       A. Anguissa   20.0     67879       0.5541    0.1288       0.0129
# 1        A. Bastoni   31.5    232370       0.3101    0.1128       0.0564
# 2        A. Belotti   32.0    740918       2.8169    1.0539       0.4432
# 3    A. Christensen   24.0    601838       0.3802    0.0613       0.0000
# 4         A. Correa   32.0    652886       1.9735    0.8442       0.2282
# ..              ...    ...       ...          ...       ...          ...
# 454         Y. Atal   20.0   1955121       1.3472    0.5672       0.1654
# 455     Y. Carrasco   22.5    797767       2.6060    0.8687       0.2044
# 456         Y. Mina   20.0   3339896       0.8766    0.3080       0.0711
# 457      Y. Poulsen   24.0    109000       2.0141    0.7524       0.3357
# 458    Y. Tielemans   44.0    282254       1.6978    0.6011       0.1476
#
#      goals_assists  passes_total  passes_key  passes_accuracy  ...  \
# 0           0.0000       22.1879      0.2706           3.2985  ...
# 1           0.0000       40.9924      0.3665          13.7863  ...
# 2           0.0985       12.3215      0.9554           4.0185  ...
# 3           0.0123       58.0206      0.1717          13.4535  ...
# 4           0.2167       23.4885      1.5286           9.1604  ...
# ..             ...           ...         ...              ...  ...
# 454         0.0236       28.5984      0.7800           5.6251  ...
# 455         0.3066       22.6878      1.6863          20.3373  ...
# 456         0.0474       46.6951      0.2843          14.5226  ...
# 457         0.2662       16.8654      1.2038           7.4314  ...
# 458         0.1371       38.4372      1.1705           6.6013  ...
#
#      substitutes_out  substitutes_bench  age_x  height_x  weight_x  rating_x  \
# 0             0.2577             0.5927   25.0     184.0      78.0  2.333333
# 1             0.0564             1.6070   21.0     190.0      75.0  4.777778
# 2             0.0689             0.0689   27.0     181.0      72.0  5.250000
# 3             0.1840             0.7604   24.0     188.0      78.0  6.000000
# 4             0.6731             0.6160   25.0     171.0      70.0  7.000000
# ..               ...                ...    ...       ...       ...       ...
# 454           0.1418             0.3782   24.0     176.0      64.0  3.333333
# 455           0.6643             1.2775   27.0     180.0      71.0  4.857143
# 456           0.0948             0.5449   26.0     195.0      94.0  6.125000
# 457           0.2894             0.5788   26.0     192.0      84.0  6.545455
# 458           0.3058             0.2636   23.0     176.0      72.0  4.384615
#
#      age_y  height_y  weight_y  rating_y
# 0     25.0     184.0      78.0  2.333333
# 1     21.0     190.0      75.0  4.777778
# 2     27.0     181.0      72.0  5.250000
# 3     24.0     188.0      78.0  6.000000
# 4     25.0     171.0      70.0  7.000000
# ..     ...       ...       ...       ...
# 454   24.0     176.0      64.0  3.333333
# 455   27.0     180.0      71.0  4.857143
# 456   26.0     195.0      94.0  6.125000
# 457   26.0     192.0      84.0  6.545455
# 458   23.0     176.0      72.0  4.384615
#
# [457 rows x 39 columns]

# %%
df.rename(columns = {'age_x' : 'age'}, inplace = True)
df.rename(columns = {'height_x' : 'height'}, inplace = True)
df.rename(columns = {'weight_x' : 'weight'}, inplace = True)
df.rename(columns = {'rating_x' : 'rating'}, inplace = True)

# %%
df_copy = df.copy()

# %%
df_copy_info = df_copy[['player_name','value','follower','age','rating']]
df_copy_atk = df_copy[['goals_total', 'goals_assists']]
df_copy_def = df_copy[['tackles_blocks','tackles_interceptions']]
df_copy_contribution = df_copy[['duels_won','dribbles_success','fouls_drawn', 'shots_on', 'passes_key']]
df_copy_mistake = df_copy[['fouls_committed','cards_red']]

# %%
df_follower = pd.DataFrame(df_copy.follower)
df_value = pd.DataFrame(df_copy.value)

# %%
df_ttl = pd.concat([df_copy_atk,df_copy_def,df_copy_contribution,df_copy_mistake],axis=1)

# %%
df_ttl = df_ttl.reset_index().drop(columns = 'index')
df_value = df_value.reset_index().drop(columns = 'index')
df_follower = df_follower.reset_index().drop(columns = 'index')
df_follower = df_follower + 10
df_follower.follower = np.log(df_follower.follower)
df_follower.describe()
# Out:
#          follower
# count  457.000000
# mean    13.180120
# std      2.230148
# min      2.302585
# 25%     11.829042
# 50%     13.389173
# 75%     14.529415
# max     19.218669

# %%
df_ttl = df_ttl.drop(columns = 'cards_red')

# %%
df_ttl
# Out:
#      goals_total  goals_assists  tackles_blocks  tackles_interceptions  \
# 0         0.0129         0.0000          0.1417                 0.8504
# 1         0.0564         0.0000          0.7048                 1.1841
# 2         0.4432         0.0985          0.0985                 0.2659
# 3         0.0000         0.0123          0.3802                 1.3368
# 4         0.2282         0.2167          0.1141                 0.9354
# ..           ...            ...             ...                    ...
# 452       0.1654         0.0236          0.2127                 1.8435
# 453       0.2044         0.3066          0.0000                 0.4088
# 454       0.0711         0.0474          0.5686                 0.9950
# 455       0.3357         0.2662          0.0695                 0.3010
# 456       0.1476         0.1371          0.1371                 0.9807
#
#      duels_won  dribbles_success  fouls_drawn  shots_on  passes_key  \
# 0       1.6622            1.1468       0.5283    0.1288      0.2706
# 1       3.0448            0.5075       1.2405    0.1128      0.3665
# 2       5.6830            0.9948       2.8563    1.0539      0.9554
# 3       4.1943            0.1594       0.5641    0.0613      0.1717
# 4       5.0080            2.5439       1.6085    0.8442      1.5286
# ..         ...               ...          ...       ...         ...
# 452     6.3578            3.4507       2.0326    0.5672      0.7800
# 453     5.4165            3.2703       1.1753    0.8687      1.6863
# 454     5.9228            0.1421       0.5686    0.3080      0.2843
# 455     6.6790            0.9260       1.8636    0.7524      1.2038
# 456     4.9141            0.8858       1.4341    0.6011      1.1705
#
#      fouls_committed
# 0             0.7473
# 1             1.2969
# 2             1.7039
# 3             0.5887
# 4             1.6541
# ..               ...
# 452           1.4417
# 453           1.0220
# 454           0.9476
# 455           1.7595
# 456           1.2232
#
# [457 rows x 10 columns]

# %%
df_value
# Out:
#      value
# 0     20.0
# 1     31.5
# 2     32.0
# 3     24.0
# 4     32.0
# ..     ...
# 452   20.0
# 453   22.5
# 454   20.0
# 455   24.0
# 456   44.0
#
# [457 rows x 1 columns]

# %%
df_follower
# Out:
#       follower
# 0    11.125629
# 1    12.356129
# 2    13.515659
# 3    13.307760
# 4    13.389173
# ..         ...
# 452  14.485968
# 453  13.589584
# 454  15.021453
# 455  11.599195
# 456  12.550598
#
# [457 rows x 1 columns]

# %%
dfxy_fol = pd.concat([df_ttl,df_follower],axis=1)

# %%
dfxy_fol
# Out:
#      goals_total  goals_assists  tackles_blocks  tackles_interceptions  \
# 0         0.0129         0.0000          0.1417                 0.8504
# 1         0.0564         0.0000          0.7048                 1.1841
# 2         0.4432         0.0985          0.0985                 0.2659
# 3         0.0000         0.0123          0.3802                 1.3368
# 4         0.2282         0.2167          0.1141                 0.9354
# ..           ...            ...             ...                    ...
# 452       0.1654         0.0236          0.2127                 1.8435
# 453       0.2044         0.3066          0.0000                 0.4088
# 454       0.0711         0.0474          0.5686                 0.9950
# 455       0.3357         0.2662          0.0695                 0.3010
# 456       0.1476         0.1371          0.1371                 0.9807
#
#      duels_won  dribbles_success  fouls_drawn  shots_on  passes_key  \
# 0       1.6622            1.1468       0.5283    0.1288      0.2706
# 1       3.0448            0.5075       1.2405    0.1128      0.3665
# 2       5.6830            0.9948       2.8563    1.0539      0.9554
# 3       4.1943            0.1594       0.5641    0.0613      0.1717
# 4       5.0080            2.5439       1.6085    0.8442      1.5286
# ..         ...               ...          ...       ...         ...
# 452     6.3578            3.4507       2.0326    0.5672      0.7800
# 453     5.4165            3.2703       1.1753    0.8687      1.6863
# 454     5.9228            0.1421       0.5686    0.3080      0.2843
# 455     6.6790            0.9260       1.8636    0.7524      1.2038
# 456     4.9141            0.8858       1.4341    0.6011      1.1705
#
#      fouls_committed   follower
# 0             0.7473  11.125629
# 1             1.2969  12.356129
# 2             1.7039  13.515659
# 3             0.5887  13.307760
# 4             1.6541  13.389173
# ..               ...        ...
# 452           1.4417  14.485968
# 453           1.0220  13.589584
# 454           0.9476  15.021453
# 455           1.7595  11.599195
# 456           1.2232  12.550598
#
# [457 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split

dfX_train_fol, dfX_test_fol, dfy_train_fol, dfy_test_fol = train_test_split(dfxy_fol, df_value, test_size=0.3, random_state=0)

# %%
dfXy_train_fol = pd.concat([dfX_train_fol,dfy_train_fol],axis=1)

# %%
dfXy_train_fol = dfXy_train_fol.reset_index().drop(columns = 'index')

# %%
model_fol = sm.OLS.from_formula('value ~ scale(goals_total)+scale(goals_assists)+scale(tackles_blocks)+scale(tackles_interceptions)+scale(duels_won)+scale(dribbles_success)+scale(fouls_drawn)+scale(shots_on)+scale(passes_key)+scale(fouls_committed)+follower', data = dfXy_train_fol)
result_fol = model_fol.fit()

# %%
print(result_fol.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.343
# Model:                            OLS   Adj. R-squared:                  0.319
# Method:                 Least Squares   F-statistic:                     14.56
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           1.24e-22
# Time:                        15:21:19   Log-Likelihood:                -1322.7
# No. Observations:                 319   AIC:                             2669.
# Df Residuals:                     307   BIC:                             2715.
# Df Model:                          11
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                       -7.0134      5.682     -1.234      0.218     -18.194       4.167
# scale(goals_total)               7.4206      2.187      3.392      0.001       3.116      11.725
# scale(goals_assists)             4.5308      1.560      2.904      0.004       1.461       7.601
# scale(tackles_blocks)            1.3316      1.163      1.145      0.253      -0.956       3.619
# scale(tackles_interceptions)     1.8456      1.260      1.465      0.144      -0.633       4.324
# scale(duels_won)                 1.1300      1.074      1.052      0.294      -0.984       3.244
# scale(dribbles_success)          4.1724      1.297      3.217      0.001       1.620       6.724
# scale(fouls_drawn)               0.4103      1.224      0.335      0.738      -1.997       2.818
# scale(shots_on)                 -2.7037      2.466     -1.096      0.274      -7.556       2.149
# scale(passes_key)               -4.2089      1.696     -2.482      0.014      -7.545      -0.873
# scale(fouls_committed)          -2.7843      1.005     -2.771      0.006      -4.762      -0.807
# follower                         2.9519      0.428      6.901      0.000       2.110       3.794
# ==============================================================================
# Omnibus:                      185.130   Durbin-Watson:                   1.873
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1848.892
# Skew:                           2.216   Prob(JB):                         0.00
# Kurtosis:                      13.930   Cond. No.                         87.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
cv_result_mean = cv_result.mean()

# %%
print(result_fol.summary())
print("검증 성능 : {}".format(cv_result_mean))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.343
# Model:                            OLS   Adj. R-squared:                  0.319
# Method:                 Least Squares   F-statistic:                     14.56
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           1.24e-22
# Time:                        17:05:24   Log-Likelihood:                -1322.7
# No. Observations:                 319   AIC:                             2669.
# Df Residuals:                     307   BIC:                             2715.
# Df Model:                          11
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                       -7.0134      5.682     -1.234      0.218     -18.194       4.167
# scale(goals_total)               7.4206      2.187      3.392      0.001       3.116      11.725
# scale(goals_assists)             4.5308      1.560      2.904      0.004       1.461       7.601
# scale(tackles_blocks)            1.3316      1.163      1.145      0.253      -0.956       3.619
# scale(tackles_interceptions)     1.8456      1.260      1.465      0.144      -0.633       4.324
# scale(duels_won)                 1.1300      1.074      1.052      0.294      -0.984       3.244
# scale(dribbles_success)          4.1724      1.297      3.217      0.001       1.620       6.724
# scale(fouls_drawn)               0.4103      1.224      0.335      0.738      -1.997       2.818
# scale(shots_on)                 -2.7037      2.466     -1.096      0.274      -7.556       2.149
# scale(passes_key)               -4.2089      1.696     -2.482      0.014      -7.545      -0.873
# scale(fouls_committed)          -2.7843      1.005     -2.771      0.006      -4.762      -0.807
# follower                         2.9519      0.428      6.901      0.000       2.110       3.794
# ==============================================================================
# Omnibus:                      185.130   Durbin-Watson:                   1.873
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1848.892
# Skew:                           2.216   Prob(JB):                         0.00
# Kurtosis:                      13.930   Cond. No.                         87.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 검증 성능 : 0.23935937699784943

# %%
from sklearn.base import BaseEstimator, RegressorMixin
import statsmodels.formula.api as smf
import statsmodels.api as sm

class StatsmodelsOLS(BaseEstimator, RegressorMixin):
    def __init__(self, formula):
        self.formula = formula
        self.model = None
        self.data = None
        self.result = None
        
    def fit(self, dfX, dfy):
        self.data = pd.concat([dfX, dfy], axis=1)
        self.model = smf.ols(self.formula, data=self.data)
        self.result = self.model.fit()
        
    def predict(self, new_data):
        return self.result.predict(new_data)

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score

model_fol_c = StatsmodelsOLS('value ~ scale(goals_total)+scale(goals_assists)+scale(tackles_blocks)+scale(tackles_interceptions)+scale(duels_won)+scale(dribbles_success)+scale(fouls_drawn)+scale(shots_on)+scale(passes_key)+scale(fouls_committed)+follower')
cv = KFold(5, shuffle=True, random_state=0)
cv_result = cross_val_score(model_fol_c, dfxy_fol, df_value, scoring="r2", cv=cv)

# %%
# %matplotlib inline

plt.scatter(np.arange(1,6,step=1),cv_result)
plt.title("test score : follower data is included")
# plt.plot(3,0.25,color='green', marker='o',markersize=7)
plt.show()

# %%
cv_result
# Out:
# array([0.16155585, 0.27802338, 0.20795776, 0.30687988, 0.24238001])

# %% [markdown]
# # ridge, lasso, elas

# %% [markdown]
# ridge

# %%
result_ridge = model_fol.fit_regularized(alpha=0.01, L1_wt=0)

# %%
df_test = pd.DataFrame(dfX_test_fol)

pred = result_ridge.predict(df_test)

rss = ((dfy_test_fol.value - pred) ** 2).sum()
tss = ((dfy_test_fol.value - dfy_test_fol.value.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared
# Out:
# 0.19862158464753743

# %%
result_lasso = model_fol.fit_regularized(alpha=0.01, L1_wt=1)

# %%
df_test = pd.DataFrame(dfX_test_fol)

pred = result_lasso.predict(df_test)

rss = ((dfy_test_fol.value - pred) ** 2).sum()
tss = ((dfy_test_fol.value - dfy_test_fol.value.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared
# Out:
# 0.1808080790754384

# %%
result_elas = model_fol.fit_regularized(alpha=0.01, L1_wt=0.5)

# %%
df_test = pd.DataFrame(dfX_test_fol)

pred = result_elas.predict(df_test)

rss = ((dfy_test_fol.value - pred) ** 2).sum()
tss = ((dfy_test_fol.value - dfy_test_fol.value.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared
# Out:
# 0.18524494735232266

# %%
# %matplotlib inline
a = np.arange(0,11,step=1)/10
a

regularized = []

for i in a:
    df_test = pd.DataFrame(dfX_test_fol)

    result_regularized = model_fol.fit_regularized(alpha=0.01, L1_wt=i)
    pred = result_regularized.predict(df_test)

    rss = ((dfy_test_fol.value - pred) ** 2).sum()
    tss = ((dfy_test_fol.value - dfy_test_fol.value.mean()) ** 2).sum()
    rsquared = 1 - rss / tss
    
    regularized.append(rsquared)

# %%
# %matplotlib inline
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111)
ax.set_title('Regularized model', fontdict={'fontsize': 15, 'fontweight': 'medium'})
plt.plot(a,regularized)
plt.plot(a,regularized, 'ro',markersize=10)
plt.xticks(np.arange(0,11,step=1)/10)
plt.axis([-0.03,1.03,0.15,0.25])
ax.set_xlabel('L1 penalty', fontsize=15)
ax.set_ylabel('R_sqaured', fontsize=15)
plt.annotate("Ridge model(0.198)",(0.01,0.199),(0.1,0.199),arrowprops=dict(facecolor='red'),fontsize=20)
plt.annotate("Lasso model(0.181)",(1.0,0.181),(0.7,0.205),arrowprops=dict(facecolor='red'),fontsize=20)
plt.show()

# %% [markdown]
# follower 포함
#
# 1. OLS $R^{2}$ : 0.343 ( + 0.093%p )
# 2. OLS $R^{2}_{adj}$ : 0.319 ( + 0.096%p )
# 3. OLS 검증 성능 : 0.16, 0.28, 0.21, 0.31, 0.24
# 4. 검증 성능(정규화) : 0.181(lasso) ~ 0.198(ridge)
#
# follower 미포함
#
# 1. OLS $R^{2}$ : 0.250
# 2. OLS $R^{2}_{adj}$ : 0.223
# 3. OLS 검증 성능 : 0.02, 0.12, 0.16, 0.20, 0.15
# 4. 검증 성능(정규화) : 0.04(lasso) ~ 0.05(ridge)
