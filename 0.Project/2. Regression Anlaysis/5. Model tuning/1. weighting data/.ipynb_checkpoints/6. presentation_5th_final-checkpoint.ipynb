# %% [markdown]
# # 1. Basic OLS
#
# ### 모든 독립변수, 모든 데이터 투입한 가장 기본적 모델

# %%
from sqlalchemy import create_engine
import pymysql

db_connection_str = 'mysql+pymysql://root:Lwglwk5120!@54.180.4.238/Linear_Regression'
db_connection = create_engine(db_connection_str)

df_sql = pd.read_sql('SELECT * FROM api_football', con=db_connection)

# %%
df_original = df_sql
df_personal_info = df_original[['player_name','position','age','nationality','height','weight','team_name','league','season','rating']]
df_original = df_original.groupby('player_name').sum()
df_original
# Out:
#                     age  height  weight  rating  captain  shots_total  \
# player_name
# A'la Jaffer          75       0       0       0        0            0
# A. Abaz              18     187      76       0        0            0
# A. Abdallah         115     850     340       5        0            0
# A. Abdellaoui       135     935       0       7        0            8
# A. Abdennour        217    1302     595      20        0            4
# ...                 ...     ...     ...     ...      ...          ...
# È˜tefan TÃ¢rnovanu  140    1379     567       0        0            0
# È˜tefÄƒniÅ£Äƒ Sava   17       0       0       0        0            0
# Ðlbert Bogatyrev    75     528     222       0        0            0
# Ð†bragÑ–m SuaÑ–b     63     576     261       0        0            0
# Ð†van GolovkÑ–n      40     360     150       0        0            0
#
#                     shots_on  goals_total  goals_conceded  goals_assists  ...  \
# player_name                                                               ...
# A'la Jaffer                0            2               0              0  ...
# A. Abaz                    0            0               0              0  ...
# A. Abdallah                0            0               0              0  ...
# A. Abdellaoui              1            1               0              0  ...
# A. Abdennour               1            0               0              0  ...
# ...                      ...          ...             ...            ...  ...
# È˜tefan TÃ¢rnovanu         0            0               0              0  ...
# È˜tefÄƒniÅ£Äƒ Sava         0            0               0              0  ...
# Ðlbert Bogatyrev          0            0               0              0  ...
# Ð†bragÑ–m SuaÑ–b           0            0               0              0  ...
# Ð†van GolovkÑ–n            0            0               0              0  ...
#
#                     penalty_commited  penalty_success  penalty_missed  \
# player_name
# A'la Jaffer                        0                0               0
# A. Abaz                            0                0               0
# A. Abdallah                        0                0               0
# A. Abdellaoui                      1                0               0
# A. Abdennour                       1                0               0
# ...                              ...              ...             ...
# È˜tefan TÃ¢rnovanu                 0                0               0
# È˜tefÄƒniÅ£Äƒ Sava                 0                0               0
# Ðlbert Bogatyrev                  0                0               0
# Ð†bragÑ–m SuaÑ–b                   0                0               0
# Ð†van GolovkÑ–n                    0                0               0
#
#                     penalty_saved  games_appearences  games_minutes_played  \
# player_name
# A'la Jaffer                     0                 78                  6552
# A. Abaz                         0                  0                     0
# A. Abdallah                     0                  6                   468
# A. Abdellaoui                   0                 63                  5087
# A. Abdennour                    0                 26                  1942
# ...                           ...                ...                   ...
# È˜tefan TÃ¢rnovanu              0                 23                  1980
# È˜tefÄƒniÅ£Äƒ Sava              0                  6                   231
# Ðlbert Bogatyrev               0                  6                   240
# Ð†bragÑ–m SuaÑ–b                0                  9                   810
# Ð†van GolovkÑ–n                 0                  1                    46
#
#                     games_lineups  substitutes_in  substitutes_out  \
# player_name
# A'la Jaffer                    74               4                8
# A. Abaz                         0               0                0
# A. Abdallah                     5               1                1
# A. Abdellaoui                  57               6                6
# A. Abdennour                   23               3                4
# ...                           ...             ...              ...
# È˜tefan TÃ¢rnovanu             22               1                1
# È˜tefÄƒniÅ£Äƒ Sava              3               3                2
# Ðlbert Bogatyrev               2               4                1
# Ð†bragÑ–m SuaÑ–b                9               0                0
# Ð†van GolovkÑ–n                 1               0                1
#
#                     substitutes_bench
# player_name
# A'la Jaffer                        11
# A. Abaz                             5
# A. Abdallah                        17
# A. Abdellaoui                      11
# A. Abdennour                       36
# ...                               ...
# È˜tefan TÃ¢rnovanu                  9
# È˜tefÄƒniÅ£Äƒ Sava                  0
# Ðlbert Bogatyrev                   6
# Ð†bragÑ–m SuaÑ–b                    1
# Ð†van GolovkÑ–n                     0
#
# [108701 rows x 36 columns]

# %%
db_connection_str = 'mysql+pymysql://root:Lwglwk5120!@54.180.4.238/Linear_Regression'
db_connection = create_engine(db_connection_str)
df0 = pd.read_sql('SELECT * FROM market_instagram', con=db_connection)
df0['value'] = df0['value'].str.replace(pat=r'[â‚¬@m\r]', repl = r' ', regex=True).astype(np.float)
df0
# Out:
#        player_name  value   follower
# 0       C. Ronaldo   60.0  222106900
# 1         L. Messi  112.0  154554857
# 2           Neymar  128.0  139025980
# 3    J. RodrÃ­guez   32.0   45619171
# 4          G. Bale   32.0   43242138
# ..             ...    ...        ...
# 495      J. Mateta   17.5        217
# 496       Emerson1   24.0         90
# 497       Emerson2   18.0          0
# 498    K. Demirbay   19.0          0
# 499     Rodri_city   64.0   11905800
#
# [500 rows x 3 columns]

# %%
# 10~15만 데이터 추가 후 merge결과 : 474명 선수 데이터 출력(몸값, 인스타, 퍼포먼스 데이터)

df_original = pd.merge(df_original, df0, on='player_name', how='inner')
df_original.drop(['height', 'weight','rating', 'captain','age'], axis=1, inplace=True)
df_original
# Out:
#         player_name  shots_total  shots_on  goals_total  goals_conceded  \
# 0       A. Anguissa           43        10            1               0
# 1        A. Bastoni           11         4            2               0
# 2        A. Belotti          286       107           45               0
# 3    A. Christensen           31         5            0               0
# 4         A. Correa          173        74           20               0
# ..              ...          ...       ...          ...             ...
# 469         Y. Atal           57        24            7               0
# 470     Y. Carrasco           51        17            4               0
# 471         Y. Mina           37        13            3               0
# 472      Y. Poulsen          174        65           29               0
# 473    Y. Tielemans          161        57           14               0
#
#      goals_assists  passes_total  passes_key  passes_accuracy  tackles_total  \
# 0                0          1722          21              256             94
# 1                0          1454          13              489             37
# 2               10          1251          97              408             47
# 3                1          4731          14             1097             84
# 4               19          2059         134              803             68
# ..             ...           ...         ...              ...            ...
# 469              1          1210          33              238             67
# 470              6           444          33              398              0
# 471              2          1971          12              613             63
# 472             23          1457         104              642             34
# 473             13          3645         111              626             95
#
#      ...  penalty_missed  penalty_saved  games_appearences  \
# 0    ...               0              0                109
# 1    ...               0              0                 46
# 2    ...               3              0                107
# 3    ...               0              0                 91
# 4    ...               0              0                136
# ..   ...             ...            ...                ...
# 469  ...               1              0                 52
# 470  ...               0              0                 35
# 471  ...               0              0                 50
# 472  ...               0              0                121
# 473  ...               0              0                114
#
#      games_minutes_played  games_lineups  substitutes_in  substitutes_out  \
# 0                    6985             72              37               20
# 1                    3192             33              13                2
# 2                    9138            101               6                7
# 3                    7339             82               9               15
# 4                    7889             85              51               59
# ..                    ...            ...             ...              ...
# 469                  3808             42              10                6
# 470                  1761             17              18               13
# 471                  3799             43               7                4
# 472                  7775             82              39               25
# 473                  8535             98              16               29
#
#      substitutes_bench  value  follower
# 0                   46   20.0     67879
# 1                   57   31.5    232370
# 2                    7   32.0    740918
# 3                   62   24.0    601838
# 4                   54   32.0    652886
# ..                 ...    ...       ...
# 469                 16   20.0   1955121
# 470                 25   22.5    797767
# 471                 23   20.0   3339896
# 472                 50   24.0    109000
# 473                 25   44.0    282254
#
# [474 rows x 34 columns]

# %%
# 선수 별 경기 수 columns 생성
df_original['games_played'] = round(df_original['games_minutes_played'] / 90,4)

# %%
df_original.describe()
# Out:
#        shots_total    shots_on  goals_total  goals_conceded  goals_assists  \
# count   474.000000  474.000000   474.000000      474.000000     474.000000
# mean    121.563291   45.959916    16.812236        4.120253      10.059072
# std     110.715133   47.907863    19.831120       21.811810       9.676845
# min       0.000000    0.000000     0.000000        0.000000       0.000000
# 25%      45.000000   12.000000     3.000000        0.000000       2.000000
# 50%      85.500000   28.500000     9.000000        0.000000       8.000000
# 75%     174.750000   66.000000    22.750000        0.000000      14.000000
# max     657.000000  324.000000   121.000000      174.000000      52.000000
#
#        passes_total  passes_key  passes_accuracy  tackles_total  \
# count    474.000000  474.000000       474.000000     474.000000
# mean    2835.892405   86.472574       623.097046      69.985232
# std     1921.378845   73.567477       256.520627      55.298248
# min        0.000000    0.000000         0.000000       0.000000
# 25%     1383.500000   27.250000       434.250000      31.000000
# 50%     2388.000000   72.000000       632.000000      60.000000
# 75%     4052.250000  127.000000       800.000000      99.750000
# max     9558.000000  418.000000      1816.000000     384.000000
#
#        tackles_blocks  ...  penalty_saved  games_appearences  \
# count      474.000000  ...     474.000000         474.000000
# mean        13.023207  ...       0.105485          93.027426
# std         16.392177  ...       0.651435          38.749443
# min          0.000000  ...       0.000000           0.000000
# 25%          2.000000  ...       0.000000          75.000000
# 50%          7.000000  ...       0.000000          99.000000
# 75%         18.000000  ...       0.000000         116.000000
# max        138.000000  ...       8.000000         422.000000
#
#        games_minutes_played  games_lineups  substitutes_in  substitutes_out  \
# count            474.000000     474.000000      474.000000       474.000000
# mean            7024.694093      78.464135       14.563291        20.462025
# std             3196.602637      36.209570       12.411599        16.656194
# min                0.000000       0.000000        0.000000         0.000000
# 25%             4882.750000      55.250000        5.000000         6.250000
# 50%             7323.000000      83.000000       12.000000        18.000000
# 75%             9134.500000     103.000000       21.000000        30.000000
# max            28111.000000     314.000000      108.000000       130.000000
#
#        substitutes_bench       value      follower  games_played
# count         474.000000  474.000000  4.740000e+02    474.000000
# mean           26.497890   33.608650  3.797876e+06     78.052156
# std            20.500941   20.597351  1.509097e+07     35.517807
# min             0.000000   16.000000  0.000000e+00      0.000000
# 25%            13.000000   20.000000  1.478260e+05     54.252750
# 50%            23.000000   28.000000  6.841665e+05     81.366700
# 75%            36.000000   40.000000  2.078808e+06    101.494425
# max           241.000000  180.000000  2.221069e+08    312.344400
#
# [8 rows x 34 columns]

# %%
# 선수 당 경기수 분포 확인
plt.subplot(221)
sns.distplot(df_original['games_played'])
plt.subplot(222)
sns.boxplot(df_original['games_played'])
plt.show()

# 선수당 경기수 50 미만 제거
df_copy = df_original.copy()
df_copy = df_copy[df_copy['games_played'] >= 50]
df_copy

plt.subplot(221)
sns.distplot(df_copy['games_played'])
plt.subplot(222)
sns.boxplot(df_copy['games_played'])

plt.show()

# %%
# 최종 dataset 생성(df) = 3시즌 간 경기수 50 초과 대상

game_played =pd.DataFrame(df_copy['games_played'])
per_game = round(df_copy[['shots_total', 'shots_on', 'goals_total', 'goals_conceded',
       'goals_assists', 'passes_total', 'passes_key', 'passes_accuracy',
       'tackles_total', 'tackles_blocks', 'tackles_interceptions',
       'duels_total', 'duels_won', 'dribbles_attempts', 'dribbles_success',
       'fouls_drawn', 'fouls_committed', 'cards_yellow', 'cards_yellowred',
       'cards_red', 'penalty_won', 'penalty_commited', 'penalty_success',
       'penalty_missed', 'penalty_saved', 'games_appearences',
       'games_lineups', 'substitutes_in',
       'substitutes_out', 'substitutes_bench']].div(df_copy['games_played'], axis=0),4)

df_copy = pd.concat([df_copy[['player_name','value','follower']], per_game], axis=1)
df_copy = pd.concat([df_copy, game_played], axis=1)
df_copy = df_copy.set_index('player_name')
df_copy
# Out:
#                 value  follower  shots_total  shots_on  goals_total  \
# player_name
# A. Anguissa      20.0     67879       0.5540    0.1288       0.0129
# A. Belotti       32.0    740918       2.8168    1.0538       0.4432
# A. Christensen   24.0    601838       0.3802    0.0613       0.0000
# A. Correa        32.0    652886       1.9736    0.8442       0.2282
# A. Di MarÃ­a     32.0  11513791       3.0823    1.1138       0.4705
# ...               ...       ...          ...       ...          ...
# W. Zaha          44.0   1028085       2.0280    0.7120       0.2373
# Wesley           24.0     57900       0.4836    0.2579       0.3761
# Willian          22.5   8983450       2.5586    0.9795       0.2798
# Y. Poulsen       24.0    109000       2.0141    0.7524       0.3357
# Y. Tielemans     44.0    282254       1.6977    0.6011       0.1476
#
#                 goals_conceded  goals_assists  passes_total  passes_key  \
# player_name
# A. Anguissa                0.0         0.0000       22.1875      0.2706
# A. Belotti                 0.0         0.0985       12.3211      0.9554
# A. Christensen             0.0         0.0123       58.0175      0.1717
# A. Correa                  0.0         0.2168       23.4897      1.5287
# A. Di MarÃ­a               0.0         0.3745       32.2437      2.2277
# ...                        ...            ...           ...         ...
# W. Zaha                    0.0         0.1187       21.4995      1.4779
# Wesley                     0.0         0.0107        4.1158      0.2042
# Willian                    0.0         0.2798       38.4786      3.0083
# Y. Poulsen                 0.0         0.2662       16.8656      1.2039
# Y. Tielemans               0.0         0.1371       38.4359      1.1705
#
#                 passes_accuracy  ...  penalty_commited  penalty_success  \
# player_name                      ...
# A. Anguissa              3.2985  ...            0.0000           0.0000
# A. Belotti               4.0184  ...            0.0000           0.0985
# A. Christensen          13.4528  ...            0.0000           0.0000
# A. Correa                9.1609  ...            0.0114           0.0000
# A. Di MarÃ­a             6.1453  ...            0.0192           0.0096
# ...                         ...  ...               ...              ...
# W. Zaha                  4.2611  ...            0.0000           0.0000
# Wesley                   2.3642  ...            0.0000           0.0000
# Willian                  8.6552  ...            0.0000           0.0500
# Y. Poulsen               7.4315  ...            0.0000           0.0116
# Y. Tielemans             6.6011  ...            0.0000           0.0105
#
#                 penalty_missed  penalty_saved  games_appearences  \
# player_name
# A. Anguissa             0.0000            0.0             1.4044
# A. Belotti              0.0295            0.0             1.0538
# A. Christensen          0.0000            0.0             1.1160
# A. Correa               0.0000            0.0             1.5515
# A. Di MarÃ­a            0.0096            0.0             1.2003
# ...                        ...            ...                ...
# W. Zaha                 0.0000            0.0             1.0248
# Wesley                  0.0107            0.0             1.2143
# Willian                 0.0000            0.0             1.4592
# Y. Poulsen              0.0000            0.0             1.4006
# Y. Tielemans            0.0000            0.0             1.2021
#
#                 games_lineups  substitutes_in  substitutes_out  \
# player_name
# A. Anguissa            0.9277          0.4767           0.2577
# A. Belotti             0.9947          0.0591           0.0689
# A. Christensen         1.0056          0.1104           0.1839
# A. Correa              0.9697          0.5818           0.6731
# A. Di MarÃ­a           1.0754          0.1248           0.5857
# ...                       ...             ...              ...
# W. Zaha                0.9924          0.0324           0.0647
# Wesley                 1.0531          0.1612           0.5158
# Willian                1.0294          0.4298           0.5397
# Y. Poulsen             0.9492          0.4514           0.2894
# Y. Tielemans           1.0334          0.1687           0.3058
#
#                 substitutes_bench  games_played
# player_name
# A. Anguissa                0.5927       77.6111
# A. Belotti                 0.0689      101.5333
# A. Christensen             0.7603       81.5444
# A. Correa                  0.6160       87.6556
# A. Di MarÃ­a               0.2401      104.1444
# ...                           ...           ...
# W. Zaha                    0.0324       92.7000
# Wesley                     0.3116       93.0556
# Willian                    0.5197      100.0556
# Y. Poulsen                 0.5788       86.3889
# Y. Tielemans               0.2636       94.8333
#
# [371 rows x 33 columns]

# %%
# 1. 상수항 결합

import statsmodels.api as sm

x_total= df_copy[['shots_total', 'shots_on', 'goals_total',
       'goals_conceded', 'goals_assists', 'passes_total', 'passes_key',
       'passes_accuracy', 'tackles_total', 'tackles_blocks',
       'tackles_interceptions', 'duels_total', 'duels_won',
       'dribbles_attempts', 'dribbles_success', 'fouls_drawn',
       'fouls_committed', 'cards_yellow', 'cards_yellowred', 'cards_red',
       'penalty_won', 'penalty_commited', 'penalty_success', 'penalty_missed',
       'penalty_saved', 'games_appearences', 'games_played',
       'games_lineups', 'substitutes_in', 'substitutes_out',
       'substitutes_bench','follower']]

X_total = sm.add_constant(x_total)
y_total = pd.DataFrame(df_copy['value'])

# %%
# 2. train / test 분리

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_total, y_total, test_size=0.3, random_state=0)

# %%
# 3. OLS 모델링
# 결과 : 매우 낮은 성능 + 매우 높은 조건수 = 매우 좋지 않은 모델

import statsmodels.api as sm
train_model = sm.OLS(y_train, X_train).fit()
print(train_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.479
# Model:                            OLS   Adj. R-squared:                  0.405
# Method:                 Least Squares   F-statistic:                     6.484
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           2.66e-18
# Time:                        23:00:59   Log-Likelihood:                -1082.9
# No. Observations:                 259   AIC:                             2232.
# Df Residuals:                     226   BIC:                             2349.
# Df Model:                          32
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                   128.3997     76.689      1.674      0.095     -22.717     279.517
# shots_total              -5.0267      5.321     -0.945      0.346     -15.512       5.459
# shots_on                 -4.8542     16.065     -0.302      0.763     -36.511      26.803
# goals_total              93.8629     22.586      4.156      0.000      49.357     138.369
# goals_conceded           13.7809     11.252      1.225      0.222      -8.391      35.953
# goals_assists            -2.8796     27.745     -0.104      0.917     -57.551      51.792
# passes_total              0.2343      0.106      2.210      0.028       0.025       0.443
# passes_key                1.6174      4.055      0.399      0.690      -6.373       9.608
# passes_accuracy           1.3074      0.666      1.964      0.051      -0.004       2.619
# tackles_total             1.3316      2.831      0.470      0.639      -4.247       6.910
# tackles_blocks           -7.4574      9.786     -0.762      0.447     -26.742      11.827
# tackles_interceptions     1.6870      3.939      0.428      0.669      -6.075       9.449
# duels_total               1.2885      1.814      0.710      0.478      -2.286       4.863
# duels_won                -2.2954      3.711     -0.619      0.537      -9.608       5.018
# dribbles_attempts        -5.4973      5.339     -1.030      0.304     -16.017       5.023
# dribbles_success         14.2732      8.422      1.695      0.091      -2.322      30.868
# fouls_drawn              -3.1057      3.052     -1.018      0.310      -9.119       2.908
# fouls_committed          -3.3257      4.120     -0.807      0.420     -11.444       4.793
# cards_yellow             12.9325     18.614      0.695      0.488     -23.748      49.613
# cards_yellowred        -111.6613    173.064     -0.645      0.519    -452.687     229.364
# cards_red               340.8754    187.001      1.823      0.070     -27.614     709.364
# penalty_won             140.2245     68.938      2.034      0.043       4.381     276.068
# penalty_commited       -123.7150    109.580     -1.129      0.260    -339.645      92.215
# penalty_success        -185.5997     48.819     -3.802      0.000    -281.798     -89.402
# penalty_missed         -123.0722    148.052     -0.831      0.407    -414.811     168.666
# penalty_saved          -114.3852    281.359     -0.407      0.685    -668.808     440.038
# games_appearences      2.137e+04   2.43e+04      0.880      0.380   -2.65e+04    6.92e+04
# games_played              0.2346      0.062      3.794      0.000       0.113       0.356
# games_lineups         -2.151e+04   2.43e+04     -0.885      0.377   -6.94e+04    2.64e+04
# substitutes_in        -2.141e+04   2.43e+04     -0.881      0.379   -6.93e+04    2.65e+04
# substitutes_out           8.6243     16.689      0.517      0.606     -24.261      41.510
# substitutes_bench         0.3071     11.275      0.027      0.978     -21.911      22.525
# follower               2.378e-07   1.36e-07      1.747      0.082   -3.05e-08    5.06e-07
# ==============================================================================
# Omnibus:                       69.959   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              171.789
# Skew:                           1.251   Prob(JB):                     4.97e-38
# Kurtosis:                       6.108   Cond. No.                     4.69e+11
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.69e+11. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# 4. 모델 예측 성능 검증 : 매우 낮은 R_squared

pred = train_model.predict(X_test)

rss = ((y_test.value - pred) ** 2).sum()
tss = ((y_test.value - y_test.value.mean())** 2).sum()
rsquared = 1 - rss / tss
rsquared
# Out:
# 0.19554682570188164

# %% [markdown]
# # 사전적 OLS 분석 결과
#
# ### train 성능 : 0.48
#
# ### test 성능 : 0.20
#
# ### 유효한 변수 갯수(5% 유의수준) : 5개(총 변수 : 32개)
#
# ### 상당히 낮은 성능 확인

# %% [markdown]
# # 2. 포지션 별 데이터셋 분리
#
# ### 총 341명의 데이터를 포지션별로 분리
#
# ### 공격수 : 95명 / 수비수 : 95명 / 미드필더 : 151명 으로 분할
#
# ### 분할해서 분석하기로 한 이유 : 포지션 별 중요한 performance feature가 모두 다르기 때문에 모델도 별도로 구성될 것

# %%
atk = pd.read_csv("/Users/kimjeongseob/Desktop/Study/0.Project/2. Regression Anlaysis/5. Model tuning/1. weighting data/0. dataset/1. before/df_atk.csv")
dfd = pd.read_csv("/Users/kimjeongseob/Desktop/Study/0.Project/2. Regression Anlaysis/5. Model tuning/1. weighting data/0. dataset/1. before/df_dfd.csv")
mdf = pd.read_csv("/Users/kimjeongseob/Desktop/Study/0.Project/2. Regression Anlaysis/5. Model tuning/1. weighting data/0. dataset/1. before/df_mdf.csv")

# %%
atk = atk.drop(columns = 'Unnamed: 0')
dfd = dfd.drop(columns = 'Unnamed: 0')
mdf = mdf.drop(columns = 'Unnamed: 0')

# %%
atk.shape, dfd.shape, mdf.shape
# Out:
# ((95, 39), (95, 39), (151, 39))

# %%
col_other = ['player_name','position','age','height','weight','rating','value','follower','games_played']
col_atk = ['goals_total','goals_assists']
col_basic = ['shots_on','passes_key','dribbles_success']
col_dfd = ['tackles_blocks','tackles_interceptions','fouls_drawn','fouls_committed']
col_cont = ['duels_won']

# %%
col_ = col_atk+col_basic+col_dfd+col_cont+['value','follower','age']

# %%
len(col_)
# Out:
# 13

# %%
atk = atk[col_]

# %%
dfd = dfd[col_]
mdf = mdf[col_]

# %%
atk.shape, dfd.shape, mdf.shape
# Out:
# ((95, 13), (95, 13), (151, 13))

# %%
atk
# Out:
#     goals_total  goals_assists  shots_on  passes_key  dribbles_success  \
# 0        0.4432         0.0985    1.0538      0.9554            0.9947
# 1        0.2282         0.2168    0.8442      1.5287            2.5440
# 2        0.5249         0.2261    1.2356      1.5183            0.7188
# 3        0.5279         0.1760    1.3951      1.8978            0.9677
# 4        0.5183         0.2073    1.1863      1.3476            1.3591
# ..          ...            ...       ...         ...               ...
# 90       0.4903         0.1103    1.0052      1.2258            0.5516
# 91       0.5635         0.1690    1.2209      1.1176            0.4132
# 92       0.2373         0.1187    0.7120      1.4779            4.0453
# 93       0.2798         0.2798    0.9795      3.0083            2.8384
# 94       0.3357         0.2662    0.7524      1.2039            0.9260
#
#     tackles_blocks  tackles_interceptions  fouls_drawn  fouls_committed  \
# 0           0.0985                 0.2659       2.8562           1.7039
# 1           0.1141                 0.9355       1.6086           1.6542
# 2           0.0323                 0.4119       1.0499           0.6057
# 3           0.0377                 0.2765       0.9175           0.3393
# 4           0.0576                 0.3686       1.6470           1.6931
# ..             ...                    ...          ...              ...
# 90          0.0858                 0.0858       1.2626           1.1400
# 91          0.0751                 0.1690       1.2397           1.1082
# 92          0.0216                 0.3452       3.0097           1.4671
# 93          0.0300                 0.5297       1.6691           0.6396
# 94          0.0695                 0.3010       1.8637           1.7595
#
#     duels_won  value  follower   age
# 0      5.6829   32.0    740918  27.0
# 1      5.0082   32.0    652886  25.0
# 2      2.8912   96.0  30243196  29.0
# 3      1.9481   30.5    351898  29.0
# 4      5.3097   48.0   3141100  29.0
# ..        ...    ...       ...   ...
# 90     3.0400   24.0    117844  29.0
# 91     3.6252   21.5     48391  28.0
# 92     8.4358   44.0   1028085  28.0
# 93     4.2876   22.5   8983450  32.0
# 94     6.6791   24.0    109000  26.0
#
# [95 rows x 13 columns]

# %%
from sklearn.decomposition import PCA

atk_pca_atk = PCA(n_components=1)
atk_low_atk = atk_pca_atk.fit_transform(atk[col_atk])

# %%
atk_pca_basic = PCA(n_components=1)
atk_low_basic = atk_pca_basic.fit_transform(atk[col_basic])

atk_pca_dfd = PCA(n_components=1)
atk_low_dfd = atk_pca_dfd.fit_transform(atk[col_dfd])

atk_pca_cont = PCA(n_components=1)
atk_low_cont = atk_pca_cont.fit_transform(atk[col_cont])

# %%
from sklearn.decomposition import PCA

dfd_pca_atk = PCA(n_components=1)
dfd_low_atk = dfd_pca_atk.fit_transform(dfd[col_atk])

# %%
dfd_pca_basic = PCA(n_components=1)
dfd_low_basic = dfd_pca_basic.fit_transform(dfd[col_basic])

dfd_pca_dfd = PCA(n_components=1)
dfd_low_dfd = dfd_pca_dfd.fit_transform(dfd[col_dfd])

dfd_pca_cont = PCA(n_components=1)
dfd_low_cont = dfd_pca_cont.fit_transform(dfd[col_cont])

# %%
from sklearn.decomposition import PCA

mdf_pca_atk = PCA(n_components=1)
mdf_low_atk = mdf_pca_atk.fit_transform(mdf[col_atk])

# %%
mdf_pca_basic = PCA(n_components=1)
mdf_low_basic = mdf_pca_basic.fit_transform(mdf[col_basic])

mdf_pca_dfd = PCA(n_components=1)
mdf_low_dfd = mdf_pca_dfd.fit_transform(mdf[col_dfd])

mdf_pca_cont = PCA(n_components=1)
mdf_low_cont = mdf_pca_cont.fit_transform(mdf[col_cont])

# %%
atk_low_atk = pd.DataFrame(atk_low_atk,columns=['pca_atk'])
atk_low_basic = pd.DataFrame(atk_low_basic,columns=['pca_basic'])
atk_low_dfd = pd.DataFrame(atk_low_dfd,columns=['pca_dfd'])
atk_low_cont = pd.DataFrame(atk_low_cont,columns=['pca_cont'])

# %%
atk_pca = pd.concat([atk_low_atk,atk_low_basic,atk_low_dfd,atk_low_cont],axis=1)

# %%
atk_value = pd.DataFrame(atk.value,columns=['value'])
atk_follower = pd.DataFrame(atk.follower,columns=['follower'])
atk_age = pd.DataFrame(atk.age,columns=['age'])

# %%
dfd_low_atk = pd.DataFrame(dfd_low_atk,columns=['pca_atk'])
dfd_low_basic = pd.DataFrame(dfd_low_basic,columns=['pca_basic'])
dfd_low_dfd = pd.DataFrame(dfd_low_dfd,columns=['pca_dfd'])
dfd_low_cont = pd.DataFrame(dfd_low_cont,columns=['pca_cont'])

# %%
dfd_pca = pd.concat([dfd_low_atk,dfd_low_basic,dfd_low_dfd,dfd_low_cont],axis=1)

# %%
dfd_value = pd.DataFrame(dfd.value,columns=['value'])
dfd_follower = pd.DataFrame(dfd.follower,columns=['follower'])
dfd_age = pd.DataFrame(dfd.age,columns=['age'])

# %%
dfd_pca = pd.concat([dfd_pca,dfd_value,dfd_follower,dfd_age],axis=1)
dfd_pca
# Out:
#      pca_atk  pca_basic   pca_dfd  pca_cont  value  follower   age
# 0  -0.076421  -0.673603 -0.307250  0.133549   24.0    601838  24.0
# 1   0.109012   1.078872 -0.046500 -0.495251   28.0    453600  25.0
# 2   0.189416   1.179655  0.475776 -0.588251   54.0   3118407  22.0
# 3  -0.031923  -0.534326 -0.162378  0.504949   60.0    841807  26.0
# 4   0.124776   0.475772 -0.643217 -0.836651   24.0   2696305  26.0
# ..       ...        ...       ...       ...    ...       ...   ...
# 90  0.023141   1.005417  1.483554  0.761749   32.0   1804339  23.0
# 91 -0.059149  -0.438008 -0.008044  0.708149   28.0    417950  24.0
# 92  0.072758   0.095499 -0.484630 -1.708251   24.0   1155895  29.0
# 93 -0.062070  -0.622806 -0.630976 -0.742851   28.0   1737260  26.0
# 94 -0.024270  -0.610622 -0.302780  1.893949   80.0   9310129  29.0
#
# [95 rows x 7 columns]

# %%
mdf_low_atk = pd.DataFrame(mdf_low_atk,columns=['pca_atk'])
mdf_low_basic = pd.DataFrame(mdf_low_basic,columns=['pca_basic'])
mdf_low_dfd = pd.DataFrame(mdf_low_dfd,columns=['pca_dfd'])
mdf_low_cont = pd.DataFrame(mdf_low_cont,columns=['pca_cont'])

# %%
mdf_pca = pd.concat([mdf_low_atk,mdf_low_basic,mdf_low_dfd,mdf_low_cont],axis=1)

# %%
mdf_value = pd.DataFrame(mdf.value,columns=['value'])
mdf_follower = pd.DataFrame(mdf.follower,columns=['follower'])
mdf_age = pd.DataFrame(mdf.age,columns=['age'])

# %%
mdf_pca = pd.concat([mdf_pca,mdf_value,mdf_follower,mdf_age],axis=1)
mdf_pca
# Out:
#       pca_atk  pca_basic   pca_dfd  pca_cont  value  follower   age
# 0   -0.207319  -0.960857 -0.833943 -2.780138   20.0     67879  25.0
# 1    0.383617   0.868692 -0.676076 -2.704238   32.0  11513791  32.0
# 2   -0.032763  -0.453671 -0.849799  0.408462   20.0     46206  27.0
# 3   -0.033089   0.176049  0.513587 -0.653838   20.0     11440  24.0
# 4   -0.011712   1.002298  2.171597  0.746962   24.0   1019540  23.0
# ..        ...        ...       ...       ...    ...       ...   ...
# 146 -0.093769   0.075192 -0.517781 -1.017138   16.0    170526  26.0
# 147 -0.182249  -1.175762  0.587462  0.533062   16.0    820996  27.0
# 148 -0.107986  -0.899193 -0.751104  0.511262   20.0    152427  22.0
# 149 -0.147520  -0.938578 -0.787619  4.338762   36.0    529117  24.0
# 150 -0.017107  -0.498906  0.079624  0.471662   44.0    282254  23.0
#
# [151 rows x 7 columns]

# %%
atk_pca
# Out:
#      pca_atk  pca_basic   pca_dfd  pca_cont
# 0  -0.041326  -0.791196  1.459412  1.521463
# 1  -0.243577   0.834247  0.317542  0.846763
# 2   0.052589  -0.786029 -0.619698 -1.270237
# 3   0.050621  -0.387844 -0.848914 -2.213337
# 4   0.044163  -0.285503  0.341540  1.148263
# ..       ...        ...       ...       ...
# 90  0.006710  -1.078715 -0.235579 -1.121437
# 91  0.085355  -1.233598 -0.265061 -0.536237
# 92 -0.244220   2.155760  1.514933  4.274363
# 93 -0.186002   1.741268 -0.028959  0.126163
# 94 -0.131720  -0.769438  0.564025  2.517663
#
# [95 rows x 4 columns]

# %%
atk_pca = pd.concat([atk_pca,atk_value,atk_follower,atk_age],axis=1)
atk_pca
# Out:
#      pca_atk  pca_basic   pca_dfd  pca_cont  value  follower   age
# 0  -0.041326  -0.791196  1.459412  1.521463   32.0    740918  27.0
# 1  -0.243577   0.834247  0.317542  0.846763   32.0    652886  25.0
# 2   0.052589  -0.786029 -0.619698 -1.270237   96.0  30243196  29.0
# 3   0.050621  -0.387844 -0.848914 -2.213337   30.5    351898  29.0
# 4   0.044163  -0.285503  0.341540  1.148263   48.0   3141100  29.0
# ..       ...        ...       ...       ...    ...       ...   ...
# 90  0.006710  -1.078715 -0.235579 -1.121437   24.0    117844  29.0
# 91  0.085355  -1.233598 -0.265061 -0.536237   21.5     48391  28.0
# 92 -0.244220   2.155760  1.514933  4.274363   44.0   1028085  28.0
# 93 -0.186002   1.741268 -0.028959  0.126163   22.5   8983450  32.0
# 94 -0.131720  -0.769438  0.564025  2.517663   24.0    109000  26.0
#
# [95 rows x 7 columns]

# %%
atk_pca = sm.add_constant(atk_pca)

# %%
atk_pca_x = atk_pca.drop(columns = 'value')
atk_pca_y = atk_pca.value

# %%
from sklearn.model_selection import train_test_split

dfX_train, dfX_test, dfy_train, dfy_test = train_test_split(atk_pca_x, atk_pca_y, test_size=0.3, random_state=0)

# %%
dfy_train = pd.DataFrame(dfy_train)
dfy_test = pd.DataFrame(dfy_test)

# %% [markdown]
# # 2-1. 공격수 대상 OLS 모델 분석
#
# ### 1) Performance별 주성분, age, follower 등 6개 feature 대상
# ### 2) 스케일링 전 분석 결과

# %%
model = sm.OLS(dfy_train,dfX_train)
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.466
# Model:                            OLS   Adj. R-squared:                  0.411
# Method:                 Least Squares   F-statistic:                     8.568
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           1.05e-06
# Time:                        23:03:48   Log-Likelihood:                -300.95
# No. Observations:                  66   AIC:                             615.9
# Df Residuals:                      59   BIC:                             631.2
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         96.7759     25.770      3.755      0.000      45.210     148.342
# pca_atk      101.7718     20.254      5.025      0.000      61.244     142.299
# pca_basic     13.5385      3.593      3.768      0.000       6.349      20.729
# pca_dfd       -4.0530      5.093     -0.796      0.429     -14.245       6.139
# pca_cont       0.3993      2.321      0.172      0.864      -4.245       5.044
# follower    6.742e-08   1.16e-07      0.580      0.564   -1.65e-07       3e-07
# age           -2.0935      0.983     -2.131      0.037      -4.060      -0.127
# ==============================================================================
# Omnibus:                       22.312   Durbin-Watson:                   1.955
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               34.491
# Skew:                           1.262   Prob(JB):                     3.24e-08
# Kurtosis:                       5.485   Cond. No.                     3.06e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.06e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
df_test = pd.DataFrame(dfX_test)

pred = result.predict(df_test)

rss = ((dfy_test.value - pred) ** 2).sum()
tss = ((dfy_test.value - dfy_test.value.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared
# Out:
# 0.26524559557484495

# %% [markdown]
# ridge

# %%
result_ridge = model.fit_regularized(alpha=0.01, L1_wt=0)

# %%
df_test = pd.DataFrame(dfX_test)

pred = result_ridge.predict(df_test)

rss = ((dfy_test.value - pred) ** 2).sum()
tss = ((dfy_test.value - dfy_test.value.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared
# Out:
# 0.29957849305669015

# %% [markdown]
# # 2-2. 공격수 대상 OLS 모델 분석
#
# ### 1) Performance별 주성분, age, follower 등 6개 feature 대상
# ### 2) 스케일링 후 분석 결과

# %% [markdown]
# # 스케일링

# %%
df_train = pd.concat([dfX_train,dfy_train],axis=1)
df_train.head()
# Out:
#     const   pca_atk  pca_basic   pca_dfd  pca_cont  follower   age  value
# 84    1.0  0.059578   0.498076  0.347961  1.812763   7300802  28.0  120.0
# 87    1.0  0.178699  -0.427725 -0.622239 -2.041437    823676  24.0   64.0
# 3     1.0  0.050621  -0.387844 -0.848914 -2.213337    351898  29.0   30.5
# 66    1.0 -0.005085   1.257579  2.095574  1.880063   1052652  27.0   32.0
# 85    1.0  0.056329  -0.890513 -0.210102  1.130763   1691131  23.0   40.0

# %%
import statsmodels.api as sm

model2 = sm.OLS.from_formula('value ~ scale(pca_atk)+scale(pca_basic)+scale(pca_dfd)+\
scale(pca_cont)+np.log(follower)+scale(age)',data = df_train)
result2 = model2.fit()
print(result2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.553
# Model:                            OLS   Adj. R-squared:                  0.507
# Method:                 Least Squares   F-statistic:                     12.15
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           7.66e-09
# Time:                        23:04:17   Log-Likelihood:                -295.09
# No. Observations:                  66   AIC:                             604.2
# Df Residuals:                      59   BIC:                             619.5
# Df Model:                           6
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept          -25.8024     20.534     -1.257      0.214     -66.891      15.286
# scale(pca_atk)      14.5561      3.362      4.330      0.000       7.829      21.283
# scale(pca_basic)     7.7164      3.735      2.066      0.043       0.242      15.191
# scale(pca_dfd)      -1.8745      3.757     -0.499      0.620      -9.391       5.643
# scale(pca_cont)      2.0410      3.790      0.539      0.592      -5.542       9.624
# np.log(follower)     5.1265      1.487      3.446      0.001       2.150       8.103
# scale(age)          -9.4585      3.122     -3.030      0.004     -15.705      -3.212
# ==============================================================================
# Omnibus:                       17.624   Durbin-Watson:                   1.945
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.284
# Skew:                           1.022   Prob(JB):                     3.23e-06
# Kurtosis:                       5.240   Cond. No.                         105.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
df_test = pd.DataFrame(dfX_test)

pred = result2.predict(df_test)

rss = ((dfy_test.value - pred) ** 2).sum()
tss = ((dfy_test.value - dfy_test.value.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared
# Out:
# 0.4378324259994322

# %% [markdown]
# # 스케일링 결과
#
# - train 성능 향상 : 0.46 ---> **0.55 ( + 0.09 )**
# - test 성능 향상 : 0.26 ---> **0.44, ( + 0.18 )**
# - 유효한 변수 갯수 증가(5% 유의수준) : **3개 ---> 4개, follower 변수의 종속변수 영향 확인**

# %% [markdown]
# # 2-3. 공격수 대상 OLS 모델 분석
#
# ### 1) 기저함수를 활용한 다항식 회귀모델 구성

# %% [markdown]
# # 스케일링 + 기저 + 정규화

# %%
import statsmodels.api as sm

model3 = sm.OLS.from_formula('value ~ scale(pca_atk)+scale(pca_basic)\
+np.log(follower)+scale(age)+scale(I(age**2))+scale(I(age**3))+scale(I(age**4))+scale(I(age**5))+scale(I(age**6))',data = df_train)
result3 = model3.fit()
print(result3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.638
# Model:                            OLS   Adj. R-squared:                  0.580
# Method:                 Least Squares   F-statistic:                     10.98
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           1.26e-09
# Time:                        23:04:32   Log-Likelihood:                -288.08
# No. Observations:                  66   AIC:                             596.2
# Df Residuals:                      56   BIC:                             618.1
# Df Model:                           9
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept            -28.5379     19.140     -1.491      0.142     -66.879       9.803
# scale(pca_atk)        13.9959      3.171      4.414      0.000       7.644      20.348
# scale(pca_basic)       6.0576      3.075      1.970      0.054      -0.101      12.217
# np.log(follower)       5.3264      1.387      3.841      0.000       2.548       8.104
# scale(age)          1.323e+06   4.38e+05      3.023      0.004    4.46e+05     2.2e+06
# scale(I(age ** 2)) -6.558e+06   2.18e+06     -3.010      0.004   -1.09e+07   -2.19e+06
# scale(I(age ** 3))  1.315e+07   4.39e+06      2.995      0.004    4.35e+06    2.19e+07
# scale(I(age ** 4)) -1.332e+07   4.47e+06     -2.979      0.004   -2.23e+07   -4.36e+06
# scale(I(age ** 5))  6.822e+06    2.3e+06      2.961      0.004    2.21e+06    1.14e+07
# scale(I(age ** 6)) -1.412e+06    4.8e+05     -2.942      0.005   -2.37e+06    -4.5e+05
# ==============================================================================
# Omnibus:                       13.985   Durbin-Watson:                   1.687
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               16.156
# Skew:                           0.951   Prob(JB):                     0.000310
# Kurtosis:                       4.503   Cond. No.                     3.87e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.58e-12. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
df_test = pd.DataFrame(dfX_test)

pred = result3.predict(df_test)

rss = ((dfy_test.value - pred) ** 2).sum()
tss = ((dfy_test.value - dfy_test.value.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared
# Out:
# 0.41979207766345183

# %%
from IPython.display import Image

# %%
 Image("/Users/kimjeongseob/Desktop/Study/0.Project/2. Regression Anlaysis/5. Model tuning/1. weighting data/0. dataset/3. img/polynomial.png")

# %%
 Image("/Users/kimjeongseob/Desktop/Study/0.Project/2. Regression Anlaysis/5. Model tuning/1. weighting data/0. dataset/3. img/ridge.png")

# %%
 Image("/Users/kimjeongseob/Desktop/Study/0.Project/2. Regression Anlaysis/5. Model tuning/1. weighting data/0. dataset/3. img/lasso.png")

# %%
 Image("/Users/kimjeongseob/Desktop/Study/0.Project/2. Regression Anlaysis/5. Model tuning/1. weighting data/0. dataset/3. img/elas.png")

# %% [markdown]
# # 다항식 회귀모델 분석 결과
#
# - train 성능 향상 : 0.46 ---> 0.55 ---> **0.64, 0.77**
# - test 성능 유지 : 0.26 ---> 0.44 ---> **0.42, 0.50**
# - 유효한 변수 갯수 증가(5% 유의수준) : 3개 ---> 4개 ---> **모든 변수(기저 변수 포함)**, **follower 변수의 종속변수 영향 확인**

# %% [markdown]
# # 2-4. 공격수 대상 OLS 모델 분석
#
# ### 1) 정규화 회귀모델 분석
#     - ridge
#     - lasso
#     - elasticnet

# %%
result_ridge3 = model3.fit_regularized(alpha=0.01, L1_wt=0)

# %%
df_test = pd.DataFrame(dfX_test)

pred = result_ridge3.predict(df_test)

rss = ((dfy_test.value - pred) ** 2).sum()
tss = ((dfy_test.value - dfy_test.value.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared
# Out:
# 0.49242187562980655

# %%
result_lasso3 = model3.fit_regularized(alpha=0.01, L1_wt=1)

# %%
df_test = pd.DataFrame(dfX_test)

pred = result_lasso3.predict(df_test)

rss = ((dfy_test.value - pred) ** 2).sum()
tss = ((dfy_test.value - dfy_test.value.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared
# Out:
# 0.4655103300028077

# %%
result_ela3 = model3.fit_regularized(alpha=0.01, L1_wt=0.5)

# %%
df_test = pd.DataFrame(dfX_test)

pred = result_ela3.predict(df_test)

rss = ((dfy_test.value - pred) ** 2).sum()
tss = ((dfy_test.value - dfy_test.value.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared
# Out:
# 0.4703526692996557

# %%
# %matplotlib inline
a = np.arange(0,11,step=1)/10
a

regularized = []

for i in a:
    df_test = pd.DataFrame(dfX_test)

    result_regularized = model3.fit_regularized(alpha=0.01, L1_wt=i)
    pred = result_regularized.predict(df_test)

    rss = ((dfy_test.value - pred) ** 2).sum()
    tss = ((dfy_test.value - dfy_test.value.mean()) ** 2).sum()
    rsquared = 1 - rss / tss
    
    regularized.append(rsquared)

# %%
# %matplotlib inline
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111)
ax.set_title('Regularized model', fontdict={'fontsize': 15, 'fontweight': 'medium'})
plt.plot(a,regularized)
plt.plot(a,regularized, 'ro',markersize=10)
plt.xticks(np.arange(0,11,step=1)/10)
plt.text(0.305,0.45,'OLS_polynomial : 0.42',fontsize=20,bbox=dict(facecolor='wheat',alpha=0.5))
plt.text(0.34,0.43,'OLS_scaled : 0.44',fontsize=20,bbox=dict(facecolor='wheat',alpha=0.5))
plt.text(0.35,0.41,'OLS_basic : 0.19',fontsize=20,bboxb=dict(facecolor='wheat',alpha=0.5))
plt.axis([-0.03,1.03,0.4,0.5])
ax.set_xlabel('L1 penalty', fontsize=15)
ax.set_ylabel('R_sqaured', fontsize=15)
plt.annotate("Ridge model(0.492)",(0.01,0.492),(0.1,0.49),arrowprops=dict(facecolor='red'),fontsize=20)
plt.annotate("Lasso model(0.465)",(1.0,0.4658),(0.9,0.475),arrowprops=dict(facecolor='red'),fontsize=20)
plt.show()

# %% [markdown]
# # 제한사항
# ```
# 1. 데이터 feature의 한계
# feature 종류의 갯수가 다양하지 못해, 전 포지션의 디테일한 분석에 한계(공격수 대상 분석에만 활용가능)
#
# 2. 데이터 row의 한계
# Market value 데이터 갯수가 많지 않아(최종 : 공격수 95명), model의 train에 한계
#
# 3. 축구에서 transfer market value 자체의 비선형적 구조
# Performance와 market value 간 엄밀한 선형관계 찾기 어려움
#
# ```

# %% [markdown]
# # 개선방향
# ```
# 1. 데이터 보강
# feature 측면( + 수상실적, 보다 다양한 performance stat, market value -> salary중심 )
# row 측면( + 선수 수 보강 )
# 가중치 측면( 학습능력 향상, contribution을 위해 리그별 / 나라별 등 가중치 데이터 확보 )
#
# 2. Machine Learning model 활용
# 축구산업 내 valuation의 비선형적 분석을 위해 classification모델을 활용해 다양한 분석 목표
# (시장가치 저평가 여부 등)
#
# ```
