# %%
atk = pd.read_csv("/Users/kimjeongseob/Desktop/Study/0.Project/2. Regression Anlaysis/5. Model tuning/1. weighting data/0. dataset/1. before/df_atk.csv")
dfd = pd.read_csv("/Users/kimjeongseob/Desktop/Study/0.Project/2. Regression Anlaysis/5. Model tuning/1. weighting data/0. dataset/1. before/df_dfd.csv")
mdf = pd.read_csv("/Users/kimjeongseob/Desktop/Study/0.Project/2. Regression Anlaysis/5. Model tuning/1. weighting data/0. dataset/1. before/df_mdf.csv")

# %%
atk = atk.drop(columns = 'Unnamed: 0')
dfd = dfd.drop(columns = 'Unnamed: 0')
mdf = mdf.drop(columns = 'Unnamed: 0')

# %%
atk
# Out:
#      player_name  position   age  height  weight    rating  value  follower  \
# 0     A. Belotti       4.0  27.0   181.0    72.0  5.250000   32.0    740918
# 1      A. Correa       4.0  25.0   171.0    70.0  7.000000   32.0    652886
# 2   A. Griezmann       4.0  29.0   176.0    73.0  6.666667   96.0  30243196
# 3    A. Kramaric       4.0  29.0   177.0    73.0  6.777778   30.5    351898
# 4   A. Lacazette       4.0  29.0   175.0    73.0  5.750000   48.0   3141100
# ..           ...       ...   ...     ...     ...       ...    ...       ...
# 90      W. JosÃ©       4.0  29.0   189.0    93.0  6.142857   24.0    117844
# 91   W. Weghorst       4.0  28.0   197.0    84.0  6.000000   21.5     48391
# 92       W. Zaha       4.0  28.0   180.0    66.0  3.888889   44.0   1028085
# 93       Willian       4.0  32.0   175.0    77.0  6.153846   22.5   8983450
# 94    Y. Poulsen       4.0  26.0   192.0    84.0  6.545455   24.0    109000
#
# ...

# %%
dfd
# Out:
#        player_name  position   age  height  weight    rating  value  follower  \
# 0   A. Christensen       3.0  24.0   188.0    78.0  6.000000   24.0    601838
# 1      A. Grimaldo       3.0  25.0   171.0    67.0  5.090909   28.0    453600
# 2        A. Hakimi       3.0  22.0   179.0    65.0  7.111111   54.0   3118407
# 3       A. Laporte       3.0  26.0   191.0    86.0  5.466667   60.0    841807
# 4     A. Robertson       3.0  26.0   178.0    64.0  5.916667   24.0   2696305
# ..             ...       ...   ...     ...     ...       ...    ...       ...
# 90   T. HernÃ¡ndez       3.0  23.0   184.0    81.0  6.125000   32.0   1804339
# 91       T. Kehrer       3.0  24.0   186.0    76.0  4.307692   28.0    417950
# 92      T. Meunier       3.0  29.0   190.0    82.0  4.230769   24.0   1155895
# 93    V. LindelÃ¶f       3.0  26.0   187.0    80.0  6.384615   28.0   1737260
# 94     V. van Dijk       3.0  29.0   193.0    92.0  5.133333   80.0   9310129
#
# ...

# %%
mdf
# Out:
#       player_name  position   age  height  weight    rating  value  follower  \
# 0     A. Anguissa       2.0  25.0   184.0    78.0  2.333333   20.0     67879
# 1    A. Di MarÃ­a       2.0  32.0   180.0    75.0  4.833333   32.0  11513791
# 2    A. DoucourÃ©       2.0  27.0   184.0    75.0  4.666667   20.0     46206
# 3      A. Golovin       2.0  24.0   180.0    69.0  4.666667   20.0     11440
# 4        A. Harit       2.0  23.0   180.0    67.0  6.714286   24.0   1019540
# ..            ...       ...   ...     ...     ...       ...    ...       ...
# 146    V. Rongier       2.0  26.0   172.0    66.0  4.100000   16.0    170526
# 147    W. Barrios       2.0  27.0   178.0    74.0  6.000000   16.0    820996
# 148   W. McKennie       2.0  22.0   185.0    84.0  7.000000   20.0    152427
# 149      W. Ndidi       2.0  24.0   183.0    74.0  7.125000   36.0    529117
# 150  Y. Tielemans       2.0  23.0   176.0    72.0  4.384615   44.0    282254
#
# ...

# %%
atk.columns
# Out:
# Index(['player_name', 'position', 'age', 'height', 'weight', 'rating', 'value',
#        'follower', 'shots_total', 'shots_on', 'goals_total', 'goals_conceded',
#        'goals_assists', 'passes_total', 'passes_key', 'passes_accuracy',
#        'tackles_total', 'tackles_blocks', 'tackles_interceptions',
#        'duels_total', 'duels_won', 'dribbles_attempts', 'dribbles_success',
#        'fouls_drawn', 'fouls_committed', 'cards_yellow', 'cards_yellowred',
#        'cards_red', 'penalty_won', 'penalty_commited', 'penalty_success',
#        'penalty_missed', 'penalty_saved', 'games_appearences', 'games_lineups',
#        'substitutes_in', 'substitutes_out', 'substitutes_bench',
#        'games_played'],
#       dtype='object')

# %%
y_vars=[
'player_name','position','value',
'age', 'height', 'weight', 'rating', 'follower', 
'shots_on', 'goals_total', 'goals_assists', 
'passes_key', 'tackles_blocks', 'tackles_interceptions', 'duels_won', 
'dribbles_success', 'fouls_drawn', 'fouls_committed', 
'cards_yellow', 'cards_yellowred', 'cards_red', 'games_played'
]

# %%
for i in atk.columns:
    if i not in y_vars:
        atk = atk.drop(columns = '{}'.format(i))
        dfd = dfd.drop(columns = '{}'.format(i))
        mdf = mdf.drop(columns = '{}'.format(i))
        
atk.columns
# Out:
# Index(['player_name', 'position', 'age', 'height', 'weight', 'rating', 'value',
#        'follower', 'shots_on', 'goals_total', 'goals_assists', 'passes_key',
#        'tackles_blocks', 'tackles_interceptions', 'duels_won',
#        'dribbles_success', 'fouls_drawn', 'fouls_committed', 'cards_yellow',
#        'cards_yellowred', 'cards_red', 'games_played'],
#       dtype='object')

# %%
atk
# Out:
#      player_name  position   age  height  weight    rating  value  follower  \
# 0     A. Belotti       4.0  27.0   181.0    72.0  5.250000   32.0    740918
# 1      A. Correa       4.0  25.0   171.0    70.0  7.000000   32.0    652886
# 2   A. Griezmann       4.0  29.0   176.0    73.0  6.666667   96.0  30243196
# 3    A. Kramaric       4.0  29.0   177.0    73.0  6.777778   30.5    351898
# 4   A. Lacazette       4.0  29.0   175.0    73.0  5.750000   48.0   3141100
# ..           ...       ...   ...     ...     ...       ...    ...       ...
# 90      W. JosÃ©       4.0  29.0   189.0    93.0  6.142857   24.0    117844
# 91   W. Weghorst       4.0  28.0   197.0    84.0  6.000000   21.5     48391
# 92       W. Zaha       4.0  28.0   180.0    66.0  3.888889   44.0   1028085
# 93       Willian       4.0  32.0   175.0    77.0  6.153846   22.5   8983450
# 94    Y. Poulsen       4.0  26.0   192.0    84.0  6.545455   24.0    109000
#
# ...

# %%
dfd
# Out:
#        player_name  position   age  height  weight    rating  value  follower  \
# 0   A. Christensen       3.0  24.0   188.0    78.0  6.000000   24.0    601838
# 1      A. Grimaldo       3.0  25.0   171.0    67.0  5.090909   28.0    453600
# 2        A. Hakimi       3.0  22.0   179.0    65.0  7.111111   54.0   3118407
# 3       A. Laporte       3.0  26.0   191.0    86.0  5.466667   60.0    841807
# 4     A. Robertson       3.0  26.0   178.0    64.0  5.916667   24.0   2696305
# ..             ...       ...   ...     ...     ...       ...    ...       ...
# 90   T. HernÃ¡ndez       3.0  23.0   184.0    81.0  6.125000   32.0   1804339
# 91       T. Kehrer       3.0  24.0   186.0    76.0  4.307692   28.0    417950
# 92      T. Meunier       3.0  29.0   190.0    82.0  4.230769   24.0   1155895
# 93    V. LindelÃ¶f       3.0  26.0   187.0    80.0  6.384615   28.0   1737260
# 94     V. van Dijk       3.0  29.0   193.0    92.0  5.133333   80.0   9310129
#
# ...

# %%
mdf
# Out:
#       player_name  position   age  height  weight    rating  value  follower  \
# 0     A. Anguissa       2.0  25.0   184.0    78.0  2.333333   20.0     67879
# 1    A. Di MarÃ­a       2.0  32.0   180.0    75.0  4.833333   32.0  11513791
# 2    A. DoucourÃ©       2.0  27.0   184.0    75.0  4.666667   20.0     46206
# 3      A. Golovin       2.0  24.0   180.0    69.0  4.666667   20.0     11440
# 4        A. Harit       2.0  23.0   180.0    67.0  6.714286   24.0   1019540
# ..            ...       ...   ...     ...     ...       ...    ...       ...
# 146    V. Rongier       2.0  26.0   172.0    66.0  4.100000   16.0    170526
# 147    W. Barrios       2.0  27.0   178.0    74.0  6.000000   16.0    820996
# 148   W. McKennie       2.0  22.0   185.0    84.0  7.000000   20.0    152427
# 149      W. Ndidi       2.0  24.0   183.0    74.0  7.125000   36.0    529117
# 150  Y. Tielemans       2.0  23.0   176.0    72.0  4.384615   44.0    282254
#
# ...

# %%
atk.columns
# Out:
# Index(['player_name', 'position', 'age', 'height', 'weight', 'rating', 'value',
#        'follower', 'shots_on', 'goals_total', 'goals_assists', 'passes_key',
#        'tackles_blocks', 'tackles_interceptions', 'duels_won',
#        'dribbles_success', 'fouls_drawn', 'fouls_committed', 'cards_yellow',
#        'cards_yellowred', 'cards_red', 'games_played'],
#       dtype='object')

# %%
col_other = ['player_name','position','age','height','weight','rating','value','follower','games_played']
col_atk = ['goals_total','goals_assists']
col_basic = ['shots_on','passes_key','dribbles_success']
col_dfd = ['tackles_blocks','tackles_interceptions','fouls_drawn','fouls_committed','cards_yellow','cards_yellowred','cards_red']
col_cont = ['duels_won']

# %% [markdown]
# ### 1. 공격수 포지션 데이터 가중치 부여
#
# 1. 공격지표 : *0.179
# 2. 수비지표 : *0.467
# 3. 기본지표 : *0.378
# 4. 기여지표 : *0.386

# %%
atkw = atk.copy()
atkw[col_atk] = atkw[col_atk]*0.179

# %%
atkw
# Out:
#      player_name  position   age  height  weight    rating  value  follower  \
# 0     A. Belotti       4.0  27.0   181.0    72.0  5.250000   32.0    740918
# 1      A. Correa       4.0  25.0   171.0    70.0  7.000000   32.0    652886
# 2   A. Griezmann       4.0  29.0   176.0    73.0  6.666667   96.0  30243196
# 3    A. Kramaric       4.0  29.0   177.0    73.0  6.777778   30.5    351898
# 4   A. Lacazette       4.0  29.0   175.0    73.0  5.750000   48.0   3141100
# ..           ...       ...   ...     ...     ...       ...    ...       ...
# 90      W. JosÃ©       4.0  29.0   189.0    93.0  6.142857   24.0    117844
# 91   W. Weghorst       4.0  28.0   197.0    84.0  6.000000   21.5     48391
# 92       W. Zaha       4.0  28.0   180.0    66.0  3.888889   44.0   1028085
# 93       Willian       4.0  32.0   175.0    77.0  6.153846   22.5   8983450
# 94    Y. Poulsen       4.0  26.0   192.0    84.0  6.545455   24.0    109000
#
# ...

# %%
atkw[col_atk]
# Out:
#     goals_total  goals_assists
# 0      0.079333       0.017632
# 1      0.040848       0.038807
# 2      0.093957       0.040472
# 3      0.094494       0.031504
# 4      0.092776       0.037107
# ..          ...            ...
# 90     0.087764       0.019744
# 91     0.100866       0.030251
# 92     0.042477       0.021247
# 93     0.050084       0.050084
# 94     0.060090       0.047650
#
# [95 rows x 2 columns]

# %%
atk[col_atk]
# Out:
#     goals_total  goals_assists
# 0        0.4432         0.0985
# 1        0.2282         0.2168
# 2        0.5249         0.2261
# 3        0.5279         0.1760
# 4        0.5183         0.2073
# ..          ...            ...
# 90       0.4903         0.1103
# 91       0.5635         0.1690
# 92       0.2373         0.1187
# 93       0.2798         0.2798
# 94       0.3357         0.2662
#
# [95 rows x 2 columns]

# %%
atkw[col_dfd] = atkw[col_dfd]*0.467
atkw[col_basic] = atkw[col_basic]*0.378
atkw[col_cont] = atkw[col_cont]*0.386

# %%
atkw[col_dfd]
# Out:
#     tackles_blocks  tackles_interceptions  fouls_drawn  fouls_committed  \
# 0         0.046000               0.124175     1.333845         0.795721
# 1         0.053285               0.436879     0.751216         0.772511
# 2         0.015084               0.192357     0.490303         0.282862
# 3         0.017606               0.129126     0.428473         0.158453
# 4         0.026899               0.172136     0.769149         0.790678
# ..             ...                    ...          ...              ...
# 90        0.040069               0.040069     0.589634         0.532380
# 91        0.035072               0.078923     0.578940         0.517529
# 92        0.010087               0.161208     1.405530         0.685136
# 93        0.014010               0.247370     0.779470         0.298693
# 94        0.032457               0.140567     0.870348         0.821687
#
#     cards_yellow  cards_yellowred  cards_red
# 0       0.050576         0.000000   0.000000
# ...

# %%
atk[col_dfd]
# Out:
#     tackles_blocks  tackles_interceptions  fouls_drawn  fouls_committed  \
# 0           0.0985                 0.2659       2.8562           1.7039
# 1           0.1141                 0.9355       1.6086           1.6542
# 2           0.0323                 0.4119       1.0499           0.6057
# 3           0.0377                 0.2765       0.9175           0.3393
# 4           0.0576                 0.3686       1.6470           1.6931
# ..             ...                    ...          ...              ...
# 90          0.0858                 0.0858       1.2626           1.1400
# 91          0.0751                 0.1690       1.2397           1.1082
# 92          0.0216                 0.3452       3.0097           1.4671
# 93          0.0300                 0.5297       1.6691           0.6396
# 94          0.0695                 0.3010       1.8637           1.7595
#
#     cards_yellow  cards_yellowred  cards_red
# 0         0.1083           0.0000     0.0000
# ...

# %%
atkw[col_basic]
# Out:
#     shots_on  passes_key  dribbles_success
# 0   0.398336    0.361141          0.375997
# 1   0.319108    0.577849          0.961632
# 2   0.467057    0.573917          0.271706
# 3   0.527348    0.717368          0.365791
# 4   0.448421    0.509393          0.513740
# ..       ...         ...               ...
# 90  0.379966    0.463352          0.208505
# 91  0.461500    0.422453          0.156190
# 92  0.269136    0.558646          1.529123
# 93  0.370251    1.137137          1.072915
# 94  0.284407    0.455074          0.350028
#
# [95 rows x 3 columns]

# %%
atk[col_basic]
# Out:
#     shots_on  passes_key  dribbles_success
# 0     1.0538      0.9554            0.9947
# 1     0.8442      1.5287            2.5440
# 2     1.2356      1.5183            0.7188
# 3     1.3951      1.8978            0.9677
# 4     1.1863      1.3476            1.3591
# ..       ...         ...               ...
# 90    1.0052      1.2258            0.5516
# 91    1.2209      1.1176            0.4132
# 92    0.7120      1.4779            4.0453
# 93    0.9795      3.0083            2.8384
# 94    0.7524      1.2039            0.9260
#
# [95 rows x 3 columns]

# %%
atkw[col_cont]
# Out:
#     duels_won
# 0    2.193599
# 1    1.933165
# 2    1.116003
# 3    0.751967
# 4    2.049544
# ..        ...
# 90   1.173440
# 91   1.399327
# 92   3.256219
# 93   1.655014
# 94   2.578133
#
# [95 rows x 1 columns]

# %%
atk[col_cont]
# Out:
#     duels_won
# 0      5.6829
# 1      5.0082
# 2      2.8912
# 3      1.9481
# 4      5.3097
# ..        ...
# 90     3.0400
# 91     3.6252
# 92     8.4358
# 93     4.2876
# 94     6.6791
#
# [95 rows x 1 columns]

# %% [markdown]
# ### 2. 수비 포지션 가중치 부여
#
# 1. 공격지표 : 0.536
# 2. 수비지표 : 0.233
# 3. 기본지표 : 0.331
# 4. 기여지표 : 0.303

# %%
dfdw = dfd.copy()
dfdw[col_atk] = dfdw[col_atk]*0.536
dfdw[col_dfd] = dfdw[col_dfd]*0.233
dfdw[col_basic] = dfdw[col_basic]*0.331
dfdw[col_cont] = dfdw[col_cont]*0.303

# %% [markdown]
# ### 3. 미드 포지션 가중치 부여
#
# 1. 공격지표 : 0.285
# 2. 수비지표 : 0.300
# 3. 기본지표 : 0.291
# 4. 기여지표 : 0.311

# %%
mdfw = mdf.copy()
mdfw[col_atk] = mdfw[col_atk]*0.285
mdfw[col_dfd] = mdfw[col_dfd]*0.300
mdfw[col_basic] = mdfw[col_basic]*0.291
mdfw[col_cont] = mdfw[col_cont]*0.311

# %%
atkw
# Out:
#      player_name  position   age  height  weight    rating  value  follower  \
# 0     A. Belotti       4.0  27.0   181.0    72.0  5.250000   32.0    740918
# 1      A. Correa       4.0  25.0   171.0    70.0  7.000000   32.0    652886
# 2   A. Griezmann       4.0  29.0   176.0    73.0  6.666667   96.0  30243196
# 3    A. Kramaric       4.0  29.0   177.0    73.0  6.777778   30.5    351898
# 4   A. Lacazette       4.0  29.0   175.0    73.0  5.750000   48.0   3141100
# ..           ...       ...   ...     ...     ...       ...    ...       ...
# 90      W. JosÃ©       4.0  29.0   189.0    93.0  6.142857   24.0    117844
# 91   W. Weghorst       4.0  28.0   197.0    84.0  6.000000   21.5     48391
# 92       W. Zaha       4.0  28.0   180.0    66.0  3.888889   44.0   1028085
# 93       Willian       4.0  32.0   175.0    77.0  6.153846   22.5   8983450
# 94    Y. Poulsen       4.0  26.0   192.0    84.0  6.545455   24.0    109000
#
# ...

# %%
dfdw
# Out:
#        player_name  position   age  height  weight    rating  value  follower  \
# 0   A. Christensen       3.0  24.0   188.0    78.0  6.000000   24.0    601838
# 1      A. Grimaldo       3.0  25.0   171.0    67.0  5.090909   28.0    453600
# 2        A. Hakimi       3.0  22.0   179.0    65.0  7.111111   54.0   3118407
# 3       A. Laporte       3.0  26.0   191.0    86.0  5.466667   60.0    841807
# 4     A. Robertson       3.0  26.0   178.0    64.0  5.916667   24.0   2696305
# ..             ...       ...   ...     ...     ...       ...    ...       ...
# 90   T. HernÃ¡ndez       3.0  23.0   184.0    81.0  6.125000   32.0   1804339
# 91       T. Kehrer       3.0  24.0   186.0    76.0  4.307692   28.0    417950
# 92      T. Meunier       3.0  29.0   190.0    82.0  4.230769   24.0   1155895
# 93    V. LindelÃ¶f       3.0  26.0   187.0    80.0  6.384615   28.0   1737260
# 94     V. van Dijk       3.0  29.0   193.0    92.0  5.133333   80.0   9310129
#
# ...

# %%
mdfw
# Out:
#       player_name  position   age  height  weight    rating  value  follower  \
# 0     A. Anguissa       2.0  25.0   184.0    78.0  2.333333   20.0     67879
# 1    A. Di MarÃ­a       2.0  32.0   180.0    75.0  4.833333   32.0  11513791
# 2    A. DoucourÃ©       2.0  27.0   184.0    75.0  4.666667   20.0     46206
# 3      A. Golovin       2.0  24.0   180.0    69.0  4.666667   20.0     11440
# 4        A. Harit       2.0  23.0   180.0    67.0  6.714286   24.0   1019540
# ..            ...       ...   ...     ...     ...       ...    ...       ...
# 146    V. Rongier       2.0  26.0   172.0    66.0  4.100000   16.0    170526
# 147    W. Barrios       2.0  27.0   178.0    74.0  6.000000   16.0    820996
# 148   W. McKennie       2.0  22.0   185.0    84.0  7.000000   20.0    152427
# 149      W. Ndidi       2.0  24.0   183.0    74.0  7.125000   36.0    529117
# 150  Y. Tielemans       2.0  23.0   176.0    72.0  4.384615   44.0    282254
#
# ...

# %%
totalw = pd.concat([atkw,dfdw,mdfw])

# %%
totalw
# Out:
#       player_name  position   age  height  weight    rating  value  follower  \
# 0      A. Belotti       4.0  27.0   181.0    72.0  5.250000   32.0    740918
# 1       A. Correa       4.0  25.0   171.0    70.0  7.000000   32.0    652886
# 2    A. Griezmann       4.0  29.0   176.0    73.0  6.666667   96.0  30243196
# 3     A. Kramaric       4.0  29.0   177.0    73.0  6.777778   30.5    351898
# 4    A. Lacazette       4.0  29.0   175.0    73.0  5.750000   48.0   3141100
# ..            ...       ...   ...     ...     ...       ...    ...       ...
# 146    V. Rongier       2.0  26.0   172.0    66.0  4.100000   16.0    170526
# 147    W. Barrios       2.0  27.0   178.0    74.0  6.000000   16.0    820996
# 148   W. McKennie       2.0  22.0   185.0    84.0  7.000000   20.0    152427
# 149      W. Ndidi       2.0  24.0   183.0    74.0  7.125000   36.0    529117
# 150  Y. Tielemans       2.0  23.0   176.0    72.0  4.384615   44.0    282254
#
# ...

# %%
# %matplotlib inline

sns.pairplot(totalw[col_atk])

# %%
sns.pairplot(totalw[col_basic])

# %%
sns.pairplot(totalw[col_dfd])

# %%
sns.pairplot(totalw[col_cont])

# %% [markdown]
# ### 4. train / test 분리

# %%
totalw_temp = totalw.copy()
totalw_temp = totalw_temp.drop(columns = 'player_name')

# %%
totalw_temp_x = totalw_temp.drop(columns = 'value')
totalw_temp_y = totalw_temp.value

# %%
from sklearn.model_selection import train_test_split

dfX_train, dfX_test, dfy_train, dfy_test = train_test_split(totalw_temp_x, totalw_temp_y, test_size=0.3, random_state=0)

# %%
dfX_train
# Out:
#      position   age  height  weight    rating  follower  shots_on  \
# 34        4.0  26.0   186.0    78.0  6.857143    291718  0.323908
# 49        3.0  26.0   190.0    96.0  6.416667   1500587  0.060540
# 2         3.0  22.0   179.0    65.0  7.111111   3118407  0.131109
# 85        4.0  23.0   190.0    80.0  5.600000   1691131  0.528179
# 84        3.0  29.0   187.0    81.0  6.272727    300512  0.023369
# ..        ...   ...     ...     ...       ...       ...       ...
# 133       2.0  25.0   191.0    76.0  7.000000    470134  0.261202
# 2         2.0  27.0   184.0    75.0  4.666667     46206  0.127574
# 22        3.0  29.0   187.0    72.0  6.000000     17900  0.019066
# 47        4.0  28.0   178.0    85.0  7.222222    176399  0.427253
# 77        3.0  23.0   187.0    70.0  5.600000    316192  0.052464
#
#      goals_total  goals_assists  passes_key  tackles_blocks  \
# 34      0.056081       0.019797    0.365677        0.008593
# ...

# %%
dfX_test
# Out:
#      position   age  height  weight    rating  follower  shots_on  \
# 74        4.0  27.0   190.0    94.0  5.687500   6017371  0.519221
# 6         3.0  27.0   190.0    85.0  5.500000   1242810  0.048988
# 56        4.0  24.0   186.0    91.0  6.857143    137169  0.357701
# 15        4.0  23.0   176.0    71.0  7.100000    194987  0.380155
# 66        3.0  21.0   188.0    89.0  4.454545   4987874  0.093408
# ..        ...   ...     ...     ...       ...       ...       ...
# 26        2.0  23.0   184.0    76.0  4.750000   1087517  0.227882
# 5         4.0  25.0   181.0    76.0  6.615385   5748682  0.430391
# 33        4.0  22.0   185.0    76.0  2.916667    249665  0.256435
# 130       2.0  25.0   175.0    75.0  5.833333   1641709  0.427392
# 8         3.0  28.0   181.0    67.0  5.300000    923192  0.106847
#
#      goals_total  goals_assists  passes_key  tackles_blocks  \
# 74      0.109459       0.026957    0.438820        0.028954
# ...

# %%
dfy_train = pd.DataFrame(dfy_train)
dfy_test = pd.DataFrame(dfy_test)

# %%
dfy_train
# Out:
#      value
# 34    40.0
# 49    32.0
# 2     54.0
# 85    40.0
# 84    25.5
# ..     ...
# 133   64.0
# 2     20.0
# 22    24.0
# 47    40.0
# 77    30.5
#
# [238 rows x 1 columns]

# %%
dfy_test
# Out:
#      value
# 74    68.0
# 6     36.0
# 56    32.0
# 15    24.0
# 66    67.5
# ..     ...
# 26    44.0
# 5     17.5
# 33    24.5
# 130   72.0
# 8     16.0
#
# [103 rows x 1 columns]

# %%
dfX_train_c = sm.add_constant(dfX_train)
dfX_test_c = sm.add_constant(dfX_test)

# %%
model = sm.OLS(dfy_train,dfX_train_c)
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  value   R-squared:                       0.384
# Model:                            OLS   Adj. R-squared:                  0.327
# Method:                 Least Squares   F-statistic:                     6.757
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           2.75e-14
# Time:                        14:44:41   Log-Likelihood:                -1025.4
# No. Observations:                 238   AIC:                             2093.
# Df Residuals:                     217   BIC:                             2166.
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -4.9918     19.826     -0.252      0.801     -44.068      34.084
# ...

# %% [markdown]
# ### 5. 데이터 확인

# %% [markdown]
# ##### 5-1. 원본 데이터

# %%
atk
# Out:
#      player_name  position   age  height  weight    rating  value  follower  \
# 0     A. Belotti       4.0  27.0   181.0    72.0  5.250000   32.0    740918
# 1      A. Correa       4.0  25.0   171.0    70.0  7.000000   32.0    652886
# 2   A. Griezmann       4.0  29.0   176.0    73.0  6.666667   96.0  30243196
# 3    A. Kramaric       4.0  29.0   177.0    73.0  6.777778   30.5    351898
# 4   A. Lacazette       4.0  29.0   175.0    73.0  5.750000   48.0   3141100
# ..           ...       ...   ...     ...     ...       ...    ...       ...
# 90      W. JosÃ©       4.0  29.0   189.0    93.0  6.142857   24.0    117844
# 91   W. Weghorst       4.0  28.0   197.0    84.0  6.000000   21.5     48391
# 92       W. Zaha       4.0  28.0   180.0    66.0  3.888889   44.0   1028085
# 93       Willian       4.0  32.0   175.0    77.0  6.153846   22.5   8983450
# 94    Y. Poulsen       4.0  26.0   192.0    84.0  6.545455   24.0    109000
#
# ...

# %%
dfd
# Out:
#        player_name  position   age  height  weight    rating  value  follower  \
# 0   A. Christensen       3.0  24.0   188.0    78.0  6.000000   24.0    601838
# 1      A. Grimaldo       3.0  25.0   171.0    67.0  5.090909   28.0    453600
# 2        A. Hakimi       3.0  22.0   179.0    65.0  7.111111   54.0   3118407
# 3       A. Laporte       3.0  26.0   191.0    86.0  5.466667   60.0    841807
# 4     A. Robertson       3.0  26.0   178.0    64.0  5.916667   24.0   2696305
# ..             ...       ...   ...     ...     ...       ...    ...       ...
# 90   T. HernÃ¡ndez       3.0  23.0   184.0    81.0  6.125000   32.0   1804339
# 91       T. Kehrer       3.0  24.0   186.0    76.0  4.307692   28.0    417950
# 92      T. Meunier       3.0  29.0   190.0    82.0  4.230769   24.0   1155895
# 93    V. LindelÃ¶f       3.0  26.0   187.0    80.0  6.384615   28.0   1737260
# 94     V. van Dijk       3.0  29.0   193.0    92.0  5.133333   80.0   9310129
#
# ...

# %%
mdf
# Out:
#       player_name  position   age  height  weight    rating  value  follower  \
# 0     A. Anguissa       2.0  25.0   184.0    78.0  2.333333   20.0     67879
# 1    A. Di MarÃ­a       2.0  32.0   180.0    75.0  4.833333   32.0  11513791
# 2    A. DoucourÃ©       2.0  27.0   184.0    75.0  4.666667   20.0     46206
# 3      A. Golovin       2.0  24.0   180.0    69.0  4.666667   20.0     11440
# 4        A. Harit       2.0  23.0   180.0    67.0  6.714286   24.0   1019540
# ..            ...       ...   ...     ...     ...       ...    ...       ...
# 146    V. Rongier       2.0  26.0   172.0    66.0  4.100000   16.0    170526
# 147    W. Barrios       2.0  27.0   178.0    74.0  6.000000   16.0    820996
# 148   W. McKennie       2.0  22.0   185.0    84.0  7.000000   20.0    152427
# 149      W. Ndidi       2.0  24.0   183.0    74.0  7.125000   36.0    529117
# 150  Y. Tielemans       2.0  23.0   176.0    72.0  4.384615   44.0    282254
#
# ...

# %% [markdown]
# ##### 5-2. 가중치 부여 후 포지션 별 데이터

# %%
atkw
# Out:
#      player_name  position   age  height  weight    rating  value  follower  \
# 0     A. Belotti       4.0  27.0   181.0    72.0  5.250000   32.0    740918
# 1      A. Correa       4.0  25.0   171.0    70.0  7.000000   32.0    652886
# 2   A. Griezmann       4.0  29.0   176.0    73.0  6.666667   96.0  30243196
# 3    A. Kramaric       4.0  29.0   177.0    73.0  6.777778   30.5    351898
# 4   A. Lacazette       4.0  29.0   175.0    73.0  5.750000   48.0   3141100
# ..           ...       ...   ...     ...     ...       ...    ...       ...
# 90      W. JosÃ©       4.0  29.0   189.0    93.0  6.142857   24.0    117844
# 91   W. Weghorst       4.0  28.0   197.0    84.0  6.000000   21.5     48391
# 92       W. Zaha       4.0  28.0   180.0    66.0  3.888889   44.0   1028085
# 93       Willian       4.0  32.0   175.0    77.0  6.153846   22.5   8983450
# 94    Y. Poulsen       4.0  26.0   192.0    84.0  6.545455   24.0    109000
#
# ...

# %%
dfdw
# Out:
#        player_name  position   age  height  weight    rating  value  follower  \
# 0   A. Christensen       3.0  24.0   188.0    78.0  6.000000   24.0    601838
# 1      A. Grimaldo       3.0  25.0   171.0    67.0  5.090909   28.0    453600
# 2        A. Hakimi       3.0  22.0   179.0    65.0  7.111111   54.0   3118407
# 3       A. Laporte       3.0  26.0   191.0    86.0  5.466667   60.0    841807
# 4     A. Robertson       3.0  26.0   178.0    64.0  5.916667   24.0   2696305
# ..             ...       ...   ...     ...     ...       ...    ...       ...
# 90   T. HernÃ¡ndez       3.0  23.0   184.0    81.0  6.125000   32.0   1804339
# 91       T. Kehrer       3.0  24.0   186.0    76.0  4.307692   28.0    417950
# 92      T. Meunier       3.0  29.0   190.0    82.0  4.230769   24.0   1155895
# 93    V. LindelÃ¶f       3.0  26.0   187.0    80.0  6.384615   28.0   1737260
# 94     V. van Dijk       3.0  29.0   193.0    92.0  5.133333   80.0   9310129
#
# ...

# %%
mdfw
# Out:
#       player_name  position   age  height  weight    rating  value  follower  \
# 0     A. Anguissa       2.0  25.0   184.0    78.0  2.333333   20.0     67879
# 1    A. Di MarÃ­a       2.0  32.0   180.0    75.0  4.833333   32.0  11513791
# 2    A. DoucourÃ©       2.0  27.0   184.0    75.0  4.666667   20.0     46206
# 3      A. Golovin       2.0  24.0   180.0    69.0  4.666667   20.0     11440
# 4        A. Harit       2.0  23.0   180.0    67.0  6.714286   24.0   1019540
# ..            ...       ...   ...     ...     ...       ...    ...       ...
# 146    V. Rongier       2.0  26.0   172.0    66.0  4.100000   16.0    170526
# 147    W. Barrios       2.0  27.0   178.0    74.0  6.000000   16.0    820996
# 148   W. McKennie       2.0  22.0   185.0    84.0  7.000000   20.0    152427
# 149      W. Ndidi       2.0  24.0   183.0    74.0  7.125000   36.0    529117
# 150  Y. Tielemans       2.0  23.0   176.0    72.0  4.384615   44.0    282254
#
# ...

# %% [markdown]
# ##### 5-3. 가중치 부여 후 concat 전체 데이터

# %%
totalw
# Out:
#       player_name  position   age  height  weight    rating  value  follower  \
# 0      A. Belotti       4.0  27.0   181.0    72.0  5.250000   32.0    740918
# 1       A. Correa       4.0  25.0   171.0    70.0  7.000000   32.0    652886
# 2    A. Griezmann       4.0  29.0   176.0    73.0  6.666667   96.0  30243196
# 3     A. Kramaric       4.0  29.0   177.0    73.0  6.777778   30.5    351898
# 4    A. Lacazette       4.0  29.0   175.0    73.0  5.750000   48.0   3141100
# ..            ...       ...   ...     ...     ...       ...    ...       ...
# 146    V. Rongier       2.0  26.0   172.0    66.0  4.100000   16.0    170526
# 147    W. Barrios       2.0  27.0   178.0    74.0  6.000000   16.0    820996
# 148   W. McKennie       2.0  22.0   185.0    84.0  7.000000   20.0    152427
# 149      W. Ndidi       2.0  24.0   183.0    74.0  7.125000   36.0    529117
# 150  Y. Tielemans       2.0  23.0   176.0    72.0  4.384615   44.0    282254
#
# ...

# %% [markdown]
# ##### 5-4. OLS를 위한 train/test 분리
#
#     - X 데이터는 상수항 추가( ' _c ' )

# %%
dfX_train_c
# Out:
#      const  position   age  height  weight    rating  follower  shots_on  \
# 34     1.0       4.0  26.0   186.0    78.0  6.857143    291718  0.323908
# 49     1.0       3.0  26.0   190.0    96.0  6.416667   1500587  0.060540
# 2      1.0       3.0  22.0   179.0    65.0  7.111111   3118407  0.131109
# 85     1.0       4.0  23.0   190.0    80.0  5.600000   1691131  0.528179
# 84     1.0       3.0  29.0   187.0    81.0  6.272727    300512  0.023369
# ..     ...       ...   ...     ...     ...       ...       ...       ...
# 133    1.0       2.0  25.0   191.0    76.0  7.000000    470134  0.261202
# 2      1.0       2.0  27.0   184.0    75.0  4.666667     46206  0.127574
# 22     1.0       3.0  29.0   187.0    72.0  6.000000     17900  0.019066
# 47     1.0       4.0  28.0   178.0    85.0  7.222222    176399  0.427253
# 77     1.0       3.0  23.0   187.0    70.0  5.600000    316192  0.052464
#
#      goals_total  goals_assists  ...  tackles_blocks  tackles_interceptions  \
# ...

# %%
dfX_test_c
# Out:
#      const  position   age  height  weight    rating  follower  shots_on  \
# 74     1.0       4.0  27.0   190.0    94.0  5.687500   6017371  0.519221
# 6      1.0       3.0  27.0   190.0    85.0  5.500000   1242810  0.048988
# 56     1.0       4.0  24.0   186.0    91.0  6.857143    137169  0.357701
# 15     1.0       4.0  23.0   176.0    71.0  7.100000    194987  0.380155
# 66     1.0       3.0  21.0   188.0    89.0  4.454545   4987874  0.093408
# ..     ...       ...   ...     ...     ...       ...       ...       ...
# 26     1.0       2.0  23.0   184.0    76.0  4.750000   1087517  0.227882
# 5      1.0       4.0  25.0   181.0    76.0  6.615385   5748682  0.430391
# 33     1.0       4.0  22.0   185.0    76.0  2.916667    249665  0.256435
# 130    1.0       2.0  25.0   175.0    75.0  5.833333   1641709  0.427392
# 8      1.0       3.0  28.0   181.0    67.0  5.300000    923192  0.106847
#
#      goals_total  goals_assists  ...  tackles_blocks  tackles_interceptions  \
# ...

# %%
dfy_train
# Out:
#      value
# 34    40.0
# 49    32.0
# 2     54.0
# 85    40.0
# 84    25.5
# ..     ...
# 133   64.0
# 2     20.0
# 22    24.0
# 47    40.0
# 77    30.5
#
# [238 rows x 1 columns]

# %%
dfy_test
# Out:
#      value
# 74    68.0
# 6     36.0
# 56    32.0
# 15    24.0
# 66    67.5
# ..     ...
# 26    44.0
# 5     17.5
# 33    24.5
# 130   72.0
# 8     16.0
#
# [103 rows x 1 columns]

# %% [markdown]
# ### 6. 데이터 추출
#
# - atkw
# - dfdw
# - mdfw
# - totalw
# - dfX_train_c
# - dfX_test_c
# - dfy_train
# - dfy_test

# %%
# atkw.to_csv('atkw.csv')
# dfdw.to_csv('dfdw.csv')
# mdfw.to_csv('mdfw.csv')
# totalw.to_csv('totalw.csv')
# dfX_train_c.to_csv('dfX_train_c.csv')
# dfX_test_c.to_csv('dfX_test_c.csv')
# dfy_train.to_csv('dfy_train.csv')
# dfy_test.to_csv('dfy_test.csv')

# %% [markdown]
# ### 7. test 성능 확인(basic)

# %% [markdown]
# #### 1) Kfold

# %%
from sklearn.base import BaseEstimator, RegressorMixin
import statsmodels.formula.api as smf
import statsmodels.api as sm

class StatsmodelsOLS(BaseEstimator, RegressorMixin):
    def __init__(self, formula):
        self.formula = formula
        self.model = None
        self.data = None
        self.result = None
        
    def fit(self, dfX, dfy):
        self.data = pd.concat([dfX, dfy], axis=1)
        self.model = smf.ols(self.formula, data=self.data)
        self.result = self.model.fit()
        
    def predict(self, new_data):
        return self.result.predict(new_data)

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score

model_basic = StatsmodelsOLS("value ~ " + "+".join(dfX_test_c.columns))
cv = KFold(5, shuffle=True, random_state=0)
cross_val_score(model_basic, dfX_test_c, dfy_test, scoring="r2", cv=cv)
# Out:
# array([ 0.08849576,  0.11973155, -0.10027639,  0.55267401, -0.86932741])

# %% [markdown]
# ### 8. card 제외 및 스케일링 진행 후 OLS

# %%
totalw_del_card = totalw_temp.drop(columns =['cards_yellow','cards_yellowred','cards_red'])
totalw_del_card
# Out:
#      position   age  height  weight    rating  value  follower  shots_on  \
# 0         4.0  27.0   181.0    72.0  5.250000   32.0    740918  0.398336
# 1         4.0  25.0   171.0    70.0  7.000000   32.0    652886  0.319108
# 2         4.0  29.0   176.0    73.0  6.666667   96.0  30243196  0.467057
# 3         4.0  29.0   177.0    73.0  6.777778   30.5    351898  0.527348
# 4         4.0  29.0   175.0    73.0  5.750000   48.0   3141100  0.448421
# ..        ...   ...     ...     ...       ...    ...       ...       ...
# 146       2.0  26.0   172.0    66.0  4.100000   16.0    170526  0.128709
# 147       2.0  27.0   178.0    74.0  6.000000   16.0    820996  0.012920
# 148       2.0  22.0   185.0    84.0  7.000000   20.0    152427  0.093615
# 149       2.0  24.0   183.0    74.0  7.125000   36.0    529117  0.064020
# 150       2.0  23.0   176.0    72.0  4.384615   44.0    282254  0.174920
#
#      goals_total  goals_assists  passes_key  tackles_blocks  \
# ...

# %%
plt.plot(totalw_del_card.describe().loc['std'])
plt.xticks(rotation = 90)
plt.show()

# %%
totalw_del_card.describe().loc['std']
# Out:
# position                 8.345543e-01
# age                      3.113959e+00
# height                   1.525603e+01
# weight                   1.084367e+01
# rating                   1.155695e+00
# value                    2.194507e+01
# follower                 1.742675e+07
# shots_on                 1.864029e-01
# goals_total              3.712751e-02
# goals_assists            2.915092e-02
# passes_key               2.428612e-01
# tackles_blocks           4.094602e-02
# tackles_interceptions    1.372888e-01
# duels_won                5.250011e-01
# dribbles_success         3.026620e-01
# fouls_drawn              3.034729e-01
# fouls_committed          1.903759e-01
# games_played             1.957599e+01
# Name: std, dtype: float64

# %%
# a_ = set(totalw_del_card.columns)
# col_notscale = set(['player_name','age'])
# col_scale = a_ - col_notscale

# %%
# col_scale

# %%
follower = pd.DataFrame(totalw_del_card.follower)
follower
# Out:
#      follower
# 0      740918
# 1      652886
# 2    30243196
# 3      351898
# 4     3141100
# ..        ...
# 146    170526
# 147    820996
# 148    152427
# 149    529117
# 150    282254
#
# [341 rows x 1 columns]

# %%
# follower 만 스케일링 진행 (로버스트로)

from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()
follower_scaled = scaler.fit_transform(follower)

# %%
follower_scaled = pd.DataFrame(follower_scaled,columns = ['follower_scaled'])
follower_scaled.mean()
# Out:
# follower_scaled    1.603889
# dtype: float64

# %%
follower_scaled.std()
# Out:
# follower_scaled    7.383952
# dtype: float64

# %%
follower_scaled
# Out:
#      follower_scaled
# 0           0.021841
# 1          -0.015459
# 2          12.522356
# 3          -0.142992
# 4           1.038831
# ..               ...
# 336        -0.219842
# 337         0.055771
# 338        -0.227510
# 339        -0.067902
# 340        -0.172501
#
# [341 rows x 1 columns]

# %%
# 스케일링된 팔로워 추가

totalw_del_card.follower
# Out:
# 0        740918
# 1        652886
# 2      30243196
# 3        351898
# 4       3141100
#          ...
# 146      170526
# 147      820996
# 148      152427
# 149      529117
# 150      282254
# Name: follower, Length: 341, dtype: int64

# %%
totalw_del_card = totalw_del_card.reset_index().drop(columns ='index')
totalw_del_card
# Out:
#      position   age  height  weight    rating  value  follower  shots_on  \
# 0         4.0  27.0   181.0    72.0  5.250000   32.0    740918  0.398336
# 1         4.0  25.0   171.0    70.0  7.000000   32.0    652886  0.319108
# 2         4.0  29.0   176.0    73.0  6.666667   96.0  30243196  0.467057
# 3         4.0  29.0   177.0    73.0  6.777778   30.5    351898  0.527348
# 4         4.0  29.0   175.0    73.0  5.750000   48.0   3141100  0.448421
# ..        ...   ...     ...     ...       ...    ...       ...       ...
# 336       2.0  26.0   172.0    66.0  4.100000   16.0    170526  0.128709
# 337       2.0  27.0   178.0    74.0  6.000000   16.0    820996  0.012920
# 338       2.0  22.0   185.0    84.0  7.000000   20.0    152427  0.093615
# 339       2.0  24.0   183.0    74.0  7.125000   36.0    529117  0.064020
# 340       2.0  23.0   176.0    72.0  4.384615   44.0    282254  0.174920
#
#      goals_total  goals_assists  passes_key  tackles_blocks  \
# ...

# %%
follower_scaled
# Out:
#      follower_scaled
# 0           0.021841
# 1          -0.015459
# 2          12.522356
# 3          -0.142992
# 4           1.038831
# ..               ...
# 336        -0.219842
# 337         0.055771
# 338        -0.227510
# 339        -0.067902
# 340        -0.172501
#
# [341 rows x 1 columns]

# %%
totalw_scaled = pd.concat([totalw_del_card,follower_scaled], axis=1)
totalw_scaled = totalw_scaled.drop(columns = 'follower')
totalw_scaled
# Out:
#      position   age  height  weight    rating  value  shots_on  goals_total  \
# 0         4.0  27.0   181.0    72.0  5.250000   32.0  0.398336     0.079333
# 1         4.0  25.0   171.0    70.0  7.000000   32.0  0.319108     0.040848
# 2         4.0  29.0   176.0    73.0  6.666667   96.0  0.467057     0.093957
# 3         4.0  29.0   177.0    73.0  6.777778   30.5  0.527348     0.094494
# 4         4.0  29.0   175.0    73.0  5.750000   48.0  0.448421     0.092776
# ..        ...   ...     ...     ...       ...    ...       ...          ...
# 336       2.0  26.0   172.0    66.0  4.100000   16.0  0.128709     0.017584
# 337       2.0  27.0   178.0    74.0  6.000000   16.0  0.012920     0.012654
# 338       2.0  22.0   185.0    84.0  7.000000   20.0  0.093615     0.018325
# 339       2.0  24.0   183.0    74.0  7.125000   36.0  0.064020     0.014250
# 340       2.0  23.0   176.0    72.0  4.384615   44.0  0.174920     0.042066
#
# ...

# %%
totalw_scaled_X = totalw_scaled.drop(columns = 'value')
totalw_scaled_y = totalw_scaled.value

# %%
from sklearn.model_selection import train_test_split

dfX_train_scaled, dfX_test_scaled, dfy_train_scaled, dfy_test_scaled = train_test_split(totalw_scaled_X, totalw_scaled_y, test_size=0.3, random_state=0)

# %%
dfy_train_scaled = pd.DataFrame(dfy_train_scaled)
dfy_test_scaled = pd.DataFrame(dfy_test_scaled)

# %%
dfX_train_scaled_c = sm.add_constant(dfX_train_scaled)
dfX_test_scaled_c = sm.add_constant(dfX_test_scaled)
# Out:
#      const  position   age  height  weight    rating  shots_on  goals_total  \
# 34     1.0       4.0  26.0   186.0    78.0  6.857143  0.323908     0.056081
# 144    1.0       3.0  26.0   190.0    96.0  6.416667  0.060540     0.021815
# 97     1.0       3.0  22.0   179.0    65.0  7.111111  0.131109     0.099053
# 85     1.0       4.0  23.0   190.0    80.0  5.600000  0.528179     0.096499
# 179    1.0       3.0  29.0   187.0    81.0  6.272727  0.023369     0.007558
# ..     ...       ...   ...     ...     ...       ...       ...          ...
# 323    1.0       2.0  25.0   191.0    76.0  7.000000  0.261202     0.072304
# 192    1.0       2.0  27.0   184.0    75.0  4.666667  0.127574     0.043462
# 117    1.0       3.0  29.0   187.0    72.0  6.000000  0.019066     0.005146
# 47     1.0       4.0  28.0   178.0    85.0  7.222222  0.427253     0.072262
# 172    1.0       3.0  23.0   187.0    70.0  5.600000  0.052464     0.047168
#
# ...

# %%
model_scaled = sm.OLS(dfy_train_scaled,dfX_train_scaled_c)
result_scaled = model_scaled.fit()
print(result_scaled.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  value   R-squared:                       0.377
# Model:                            OLS   Adj. R-squared:                  0.329
# Method:                 Least Squares   F-statistic:                     7.846
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           3.32e-15
# Time:                        15:25:42   Log-Likelihood:                -1026.7
# No. Observations:                 238   AIC:                             2089.
# Df Residuals:                     220   BIC:                             2152.
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -5.7467     19.605     -0.293      0.770     -44.385      32.891
# ...

# %%
# # non performance데이터 : position, age, height, weight, rating 빼고 진행

# dfX_train_scaled_c = dfX_train_scaled_c.drop(columns=['position', 'age', 'height', 'weight', 'rating'])
# dfX_test_scaled_c = dfX_test_scaled_c.drop(columns=['position', 'age', 'height', 'weight', 'rating'])

# %%
model_scaled = sm.OLS(dfy_train_scaled,dfX_train_scaled_c)
result_scaled = model_scaled.fit()
print(result_scaled.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  value   R-squared:                       0.318
# Model:                            OLS   Adj. R-squared:                  0.282
# Method:                 Least Squares   F-statistic:                     8.752
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           1.18e-13
# Time:                        15:31:45   Log-Likelihood:                -1037.5
# No. Observations:                 238   AIC:                             2101.
# Df Residuals:                     225   BIC:                             2146.
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                   -11.2965      8.968     -1.260      0.209     -28.969       6.376
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = dfX_train_scaled_c
vif["VIF Factor"] = [variance_inflation_factor(
    dfX_train_scaled_c.values, i) for i in range(dfX_train_scaled_c.shape[1])]
vif["features"] = dfX_train_scaled_c.columns
vif
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-219-bd2066ff8270> in <module>
#       3 vif = dfX_train_scaled_c
#       4 vif["VIF Factor"] = [variance_inflation_factor(
# ----> 5     dfX_train_scaled_c.values, i) for i in range(dfX_train_scaled_c.shape[1])]
#       6 vif["features"] = dfX_train_scaled_c.columns
#       7 vif
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# -> 3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
# ...

# %%
plt.scatter(totalw.age,totalw.value)

# %%
totalw[totalw.value>100]
# Out:
#      player_name  position   age  height  weight    rating  value   follower  \
# 46    K. MbappÃ©       4.0  22.0   178.0    73.0  4.875000  180.0   40807990
# 51      L. Messi       4.0  33.0   170.0    72.0  8.222222  112.0  154554857
# 63      M. Salah       4.0  28.0   175.0    71.0  6.153846  120.0   38661405
# 68        Neymar       4.0  28.0   175.0    68.0  5.416667  128.0  139025980
# 77   R. Sterling       4.0  26.0   170.0    69.0  6.692308  128.0    7015127
# 84      S. ManÃ©       4.0  28.0   175.0    69.0  5.538462  120.0    7300802
# 72     J. Sancho       2.0  20.0   180.0    76.0  4.166667  117.0    4253514
# 76  K. De Bruyne       2.0  29.0   181.0    68.0  7.083333  120.0   11099793
#
#     shots_on  goals_total  ...  tackles_blocks  tackles_interceptions  \
# 46  0.628236     0.148749  ...        0.000000               0.077615
# 51  1.023246     0.176476  ...        0.000000               0.097556
# ...

# %% [markdown]
# # 새로 시작
#
# - totalw : weight 준 것으로

# %%
# col_other = ['player_name','position','age','height','weight','rating','value','follower','games_played']
# col_atk = ['goals_total','goals_assists']
# col_basic = ['shots_on','passes_key','dribbles_success']
# col_dfd = ['tackles_blocks','tackles_interceptions','fouls_drawn','fouls_committed','cards_yellow','cards_yellowred','cards_red']
# col_cont = ['duels_won']

# %%
# follower 제거
# totalw.value > 100 제거
# 공격력 지표 / 수비력지표 / 기본 / 기여지표 별 PC 추출 -> 모델 구성
# OLS 실시

# %%
totalw
# Out:
#       player_name  position   age  height  weight    rating  value  follower  \
# 0      A. Belotti       4.0  27.0   181.0    72.0  5.250000   32.0    740918
# 1       A. Correa       4.0  25.0   171.0    70.0  7.000000   32.0    652886
# 2    A. Griezmann       4.0  29.0   176.0    73.0  6.666667   96.0  30243196
# 3     A. Kramaric       4.0  29.0   177.0    73.0  6.777778   30.5    351898
# 4    A. Lacazette       4.0  29.0   175.0    73.0  5.750000   48.0   3141100
# ..            ...       ...   ...     ...     ...       ...    ...       ...
# 146    V. Rongier       2.0  26.0   172.0    66.0  4.100000   16.0    170526
# 147    W. Barrios       2.0  27.0   178.0    74.0  6.000000   16.0    820996
# 148   W. McKennie       2.0  22.0   185.0    84.0  7.000000   20.0    152427
# 149      W. Ndidi       2.0  24.0   183.0    74.0  7.125000   36.0    529117
# 150  Y. Tielemans       2.0  23.0   176.0    72.0  4.384615   44.0    282254
#
# ...

# %%
ttlw = totalw.drop(columns = ['cards_yellow','cards_yellowred','cards_red','follower'])
ttlw = ttlw[ttlw.value<=100]
ttlw
# Out:
#       player_name  position   age  height  weight    rating  value  shots_on  \
# 0      A. Belotti       4.0  27.0   181.0    72.0  5.250000   32.0  0.398336
# 1       A. Correa       4.0  25.0   171.0    70.0  7.000000   32.0  0.319108
# 2    A. Griezmann       4.0  29.0   176.0    73.0  6.666667   96.0  0.467057
# 3     A. Kramaric       4.0  29.0   177.0    73.0  6.777778   30.5  0.527348
# 4    A. Lacazette       4.0  29.0   175.0    73.0  5.750000   48.0  0.448421
# ..            ...       ...   ...     ...     ...       ...    ...       ...
# 146    V. Rongier       2.0  26.0   172.0    66.0  4.100000   16.0  0.128709
# 147    W. Barrios       2.0  27.0   178.0    74.0  6.000000   16.0  0.012920
# 148   W. McKennie       2.0  22.0   185.0    84.0  7.000000   20.0  0.093615
# 149      W. Ndidi       2.0  24.0   183.0    74.0  7.125000   36.0  0.064020
# 150  Y. Tielemans       2.0  23.0   176.0    72.0  4.384615   44.0  0.174920
#
# ...

# %%
col_atk
# Out:
# ['goals_total', 'goals_assists']

# %%
col_dfd
# Out:
# ['tackles_blocks', 'tackles_interceptions', 'fouls_drawn', 'fouls_committed']

# %%
col_basic
# Out:
# ['shots_on', 'passes_key', 'dribbles_success']

# %%
col_cont
# Out:
# ['duels_won']

# %% [markdown]
# ```
# pca1 = PCA(n_components=1)
# X_low = pca1.fit_transform(X)
# X2 = pca1.inverse_transform(X_low)
# ```

# %%
from sklearn.decomposition import PCA

# %%
# 공격지표 pca 구하기 : atk_low

pca_atk = PCA(n_components = 1)
atk_low = pca_atk.fit_transform(ttlw[col_atk])
atk_low[:5]
# Out:
# array([[ 0.01671205],
#        [-0.00964134],
#        [ 0.03944314],
#        [ 0.03624027],
#        [ 0.03698101]])

# %%
# 수비지표 pca 구하기 : dfd_low

pca_dfd = PCA(n_components = 1)
dfd_low = pca_dfd.fit_transform(ttlw[col_dfd])
dfd_low[:5]
# Out:
# array([[ 1.02002653],
#        [ 0.45756892],
#        [ 0.03762587],
#        [-0.06562659],
#        [ 0.51219583]])

# %%
# basic pca 구하기 : basic_low

pca_basic = PCA(n_components = 1)
basic_low = pca_basic.fit_transform(ttlw[col_basic])
basic_low[:5]
# Out:
# array([[0.04333119],
#        [0.56852824],
#        [0.11774744],
#        [0.29208064],
#        [0.24858691]])

# %%
# 기여 pca 구하기 : cont_low

pca_cont = PCA(n_components = 1)
cont_low = pca_cont.fit_transform(ttlw[col_cont])
cont_low[:5]
# Out:
# array([[ 0.80040972],
#        [ 0.53997552],
#        [-0.27718648],
#        [-0.64122308],
#        [ 0.65635452]])

# %%
atk_low = pd.DataFrame(atk_low)
basic_low = pd.DataFrame(basic_low)
cont_low = pd.DataFrame(cont_low)
dfd_low = pd.DataFrame(dfd_low)

# %%
pcaset.drop(columns='1')
# Out:
#             0         0         0         0
# 0    0.016712  0.043331  0.800410  1.020027
# 1   -0.009641  0.568528  0.539976  0.457569
# 2    0.039443  0.117747 -0.277186  0.037626
# 3    0.036240  0.292081 -0.641223 -0.065627
# 4    0.036981  0.248587  0.656355  0.512196
# ..        ...       ...       ...       ...
# 328 -0.032339  0.026298 -0.327984 -0.109746
# 329 -0.051312 -0.343225  0.154129  0.198541
# 330 -0.034821 -0.254995  0.147349 -0.133506
# 331 -0.043991 -0.270389  1.337701 -0.178806
# 332 -0.008422 -0.133138  0.135033  0.009012
#
# [333 rows x 4 columns]

# %%
valset = ttlw.value
pcaset = pd.concat([atk_low,basic_low,cont_low,dfd_low],axis=1)
pcaset.columns = ['atk','basic','cont','dfd']

# %%
pcaset
# Out:
#           atk     basic      cont       dfd
# 0    0.016712  0.043331  0.800410  1.020027
# 1   -0.009641  0.568528  0.539976  0.457569
# 2    0.039443  0.117747 -0.277186  0.037626
# 3    0.036240  0.292081 -0.641223 -0.065627
# 4    0.036981  0.248587  0.656355  0.512196
# ..        ...       ...       ...       ...
# 328 -0.032339  0.026298 -0.327984 -0.109746
# 329 -0.051312 -0.343225  0.154129  0.198541
# 330 -0.034821 -0.254995  0.147349 -0.133506
# 331 -0.043991 -0.270389  1.337701 -0.178806
# 332 -0.008422 -0.133138  0.135033  0.009012
#
# [333 rows x 4 columns]

# %%
# valset = pd.DataFrame(valset)
# valset = valset.reset_index()

# %%
valset = valset.drop(columns = ['level_0','index'])

# %%
valset
# Out:
#      value
# 0     32.0
# 1     32.0
# 2     96.0
# 3     30.5
# 4     48.0
# ..     ...
# 328   16.0
# 329   16.0
# 330   20.0
# 331   36.0
# 332   44.0
#
# [333 rows x 1 columns]

# %%
pcaset_c = sm.add_constant(pcaset)
pcaset_c
# Out:
#      const       atk     basic      cont       dfd
# 0      1.0  0.016712  0.043331  0.800410  1.020027
# 1      1.0 -0.009641  0.568528  0.539976  0.457569
# 2      1.0  0.039443  0.117747 -0.277186  0.037626
# 3      1.0  0.036240  0.292081 -0.641223 -0.065627
# 4      1.0  0.036981  0.248587  0.656355  0.512196
# ..     ...       ...       ...       ...       ...
# 328    1.0 -0.032339  0.026298 -0.327984 -0.109746
# 329    1.0 -0.051312 -0.343225  0.154129  0.198541
# 330    1.0 -0.034821 -0.254995  0.147349 -0.133506
# 331    1.0 -0.043991 -0.270389  1.337701 -0.178806
# 332    1.0 -0.008422 -0.133138  0.135033  0.009012
#
# [333 rows x 5 columns]

# %%
dfX_train, dfX_test, dfy_train, dfy_test = train_test_split(pcaset_c, valset, test_size=0.3, random_state=0)

# %%
model = sm.OLS(dfy_train,dfX_train)
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  value   R-squared:                       0.082
# Model:                            OLS   Adj. R-squared:                  0.066
# Method:                 Least Squares   F-statistic:                     5.088
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           0.000604
# Time:                        16:31:21   Log-Likelihood:                -977.71
# No. Observations:                 233   AIC:                             1965.
# Df Residuals:                     228   BIC:                             1983.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         32.6086      1.070     30.481      0.000      30.501      34.716
# ...

# %%
model.endog.shape
# Out:
# (238,)

# %%
model.exog.shape
# Out:
# (238, 21)

# %%
dfX_train
# Out:
#      const       atk     basic      cont       dfd
# 159    1.0 -0.026844 -0.473108 -0.224064 -0.264137
# 150    1.0 -0.010456 -0.134725  0.009367 -0.246110
# 106    1.0 -0.010891 -0.198936 -0.679564 -0.410328
# 214    1.0  0.014718  0.394126  0.758993 -0.033661
# 90     1.0  0.010129  0.060548 -0.312934 -0.298821
# ..     ...       ...       ...       ...       ...
# 323    1.0 -0.027664 -0.370462  0.541915  0.115638
# 192    1.0  0.051368 -0.002687 -0.120484  0.048011
# 117    1.0 -0.018800 -0.456815 -0.372595 -0.351517
# 47     1.0  0.006071  0.668092  0.267537  0.256268
# 172    1.0 -0.009746 -0.132036 -0.146769 -0.169441
#
# [233 rows x 5 columns]

# %%
dfy_train
# Out:
#      value
# 70    24.0
# 61    24.0
# 17    52.0
# 30    32.0
# 1     28.0
# ..     ...
# 141   17.5
# 8     25.5
# 28    20.0
# 48    29.5
# 83    40.0
#
# [233 rows x 1 columns]

# %%
plt.scatter(valset.value,basic_low)

# %%
_basic = pd.concat([valset,basic_low],axis = 1)
_basic
# Out:
#      value         0
# 0     32.0  0.043331
# 1     32.0  0.568528
# 2     96.0  0.117747
# 3     30.5  0.292081
# 4     48.0  0.248587
# ..     ...       ...
# 328   16.0  0.026298
# 329   16.0 -0.343225
# 330   20.0 -0.254995
# 331   36.0 -0.270389
# 332   44.0 -0.133138
#
# [333 rows x 2 columns]

# %%
_basic.corr()
# Out:
#           value         0
# value  1.000000  0.173389
# 0      0.173389  1.000000

# %%
_atk = pd.concat([valset,atk_low],axis = 1)
_atk
# Out:
#      value         0
# 0     32.0  0.016712
# 1     32.0 -0.009641
# 2     96.0  0.039443
# 3     30.5  0.036240
# 4     48.0  0.036981
# ..     ...       ...
# 328   16.0 -0.032339
# 329   16.0 -0.051312
# 330   20.0 -0.034821
# 331   36.0 -0.043991
# 332   44.0 -0.008422
#
# [333 rows x 2 columns]

# %%
_atk.corr()
# Out:
#           value         0
# value  1.000000  0.227296
# 0      0.227296  1.000000

# %%
_ttl = pd.concat([pcaset,valset],axis=1)
sns.pairplot(_ttl)

# %% [markdown]
# logit 적용 -> np.log 적용 -> OLS

# %%
pcaset_log_before = np.abs(pcaset)
pcaset_log_before
pcaset_log = np.log(pcaset)
pcaset_log
# Out:
#           atk     basic      cont       dfd
# 0   -4.091625 -3.138883 -0.222632  0.019829
# 1         NaN -0.564704 -0.616231 -0.781828
# 2   -3.232895 -2.139213       NaN -3.280063
# 3   -3.317584 -1.230725       NaN       NaN
# 4   -3.297351 -1.391963 -0.421054 -0.669048
# ..        ...       ...       ...       ...
# 328       NaN -3.638260       NaN       NaN
# 329       NaN       NaN -1.869968 -1.616760
# 330       NaN       NaN -1.914953       NaN
# 331       NaN       NaN  0.290953       NaN
# 332       NaN       NaN -2.002234 -4.709214
#
# [333 rows x 4 columns]

# %%
pcaset_logit = pcaset.copy()
pcaset_logit
# Out:
#           atk     basic      cont       dfd
# 0    0.016712  0.043331  0.800410  1.020027
# 1   -0.009641  0.568528  0.539976  0.457569
# 2    0.039443  0.117747 -0.277186  0.037626
# 3    0.036240  0.292081 -0.641223 -0.065627
# 4    0.036981  0.248587  0.656355  0.512196
# ..        ...       ...       ...       ...
# 328 -0.032339  0.026298 -0.327984 -0.109746
# 329 -0.051312 -0.343225  0.154129  0.198541
# 330 -0.034821 -0.254995  0.147349 -0.133506
# 331 -0.043991 -0.270389  1.337701 -0.178806
# 332 -0.008422 -0.133138  0.135033  0.009012
#
# [333 rows x 4 columns]

# %%
plt.hist(pcaset.atk)
# Out:
# (array([38., 62., 63., 45., 46., 41., 17., 10.,  6.,  5.]),
#  array([-0.06012966, -0.04269464, -0.02525963, -0.00782461,  0.0096104 ,
#          0.02704541,  0.04448043,  0.06191544,  0.07935045,  0.09678547,
#          0.11422048]),
#  <a list of 10 Patch objects>)

# %%
pred = 1/(1+np.exp(-pred))
pcaset_logit.basic = 1/(1+np.exp(-pcaset_logit.basic))
pcaset_logit.cont = 1/(1+np.exp(-pcaset_logit.cont))
pcaset_logit.dfd = 1/(1+np.exp(-pcaset_logit.dfd))

# %%
pcaset_logit
# Out:
#           atk     basic      cont       dfd
# 0    0.504178  0.510831  0.690062  0.734978
# 1    0.497590  0.638424  0.631807  0.612437
# 2    0.509860  0.529403  0.431144  0.509405
# 3    0.509059  0.572505  0.344970  0.483599
# 4    0.509244  0.561829  0.658441  0.625321
# ..        ...       ...       ...       ...
# 328  0.491916  0.506574  0.418731  0.472591
# 329  0.487175  0.415026  0.538456  0.549473
# 330  0.491296  0.436594  0.536771  0.466673
# 331  0.489004  0.432812  0.792112  0.455417
# 332  0.497895  0.466764  0.533707  0.502253
#
# [333 rows x 4 columns]

# %%
pcaset_logit_log = np.log(pcaset_logit)

# %%
sns.pairplot(pcaset_logit_log)

# %%
pcaset_logit_log
pcaset_logit_log_c = sm.add_constant(pcaset_logit_log)
# Out:
#      const       atk     basic      cont       dfd
# 0      1.0 -0.684826 -0.671716 -0.370974 -0.307915
# 1      1.0 -0.697979 -0.448753 -0.459172 -0.490309
# 2      1.0 -0.673620 -0.636006 -0.841314 -0.674511
# 3      1.0 -0.675191 -0.557733 -1.064297 -0.726499
# 4      1.0 -0.674828 -0.576558 -0.417880 -0.469490
# ..     ...       ...       ...       ...       ...
# 328    1.0 -0.709448 -0.680085 -0.870526 -0.749525
# 329    1.0 -0.719132 -0.879413 -0.619049 -0.598796
# 330    1.0 -0.710709 -0.828751 -0.622184 -0.762127
# 331    1.0 -0.715384 -0.837453 -0.233053 -0.786541
# 332    1.0 -0.697367 -0.761930 -0.627908 -0.688651
#
# [333 rows x 5 columns]

# %%
valset = pd.DataFrame(valset).reset_index()

# %%
valset = valset.drop(columns = 'index')
valset
# Out:
#      value
# 0     32.0
# 1     32.0
# 2     96.0
# 3     30.5
# 4     48.0
# ..     ...
# 328   16.0
# 329   16.0
# 330   20.0
# 331   36.0
# 332   44.0
#
# [333 rows x 1 columns]

# %%
dfX_train_log, dfX_test_log, dfy_train_log, dfy_test_log = train_test_split(pcaset_logit_log_c, valset, test_size=0.3, random_state=0)

# %%
dfX_train_log = dfX_train_log.reset_index()
dfX_train_log = dfX_train_log.drop(columns='index')

# %%
dfy_train_log = dfy_train_log.reset_index().drop(columns='index')

# %%
dfy_train_log
# Out:
#      value
# 0     24.0
# 1     24.0
# 2     52.0
# 3     32.0
# 4     28.0
# ..     ...
# 228   17.5
# 229   25.5
# 230   20.0
# 231   29.5
# 232   40.0
#
# [233 rows x 1 columns]

# %%
dfX_train_log = dfX_train_log.drop(columns='level_0')

# %%
model_log = sm.OLS(dfy_train_log,dfX_train_log)
result_log = model_log.fit()
print(result_log.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  value   R-squared:                       0.077
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     4.757
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):            0.00105
# Time:                        16:59:31   Log-Likelihood:                -978.33
# No. Observations:                 233   AIC:                             1967.
# Df Residuals:                     228   BIC:                             1984.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        182.9610     53.124      3.444      0.001      78.284     287.638
# ...

# %% [markdown]
# 1. basic column 제거
# 2. 전체 scaling

# %%
pcaset_logit_log = pcaset_logit_log.drop(columns ='basic')
pcaset_logit_log
# Out:
#           atk      cont       dfd
# 0   -0.684826 -0.370974 -0.307915
# 1   -0.697979 -0.459172 -0.490309
# 2   -0.673620 -0.841314 -0.674511
# 3   -0.675191 -1.064297 -0.726499
# 4   -0.674828 -0.417880 -0.469490
# ..        ...       ...       ...
# 328 -0.709448 -0.870526 -0.749525
# 329 -0.719132 -0.619049 -0.598796
# 330 -0.710709 -0.622184 -0.762127
# 331 -0.715384 -0.233053 -0.786541
# 332 -0.697367 -0.627908 -0.688651
#
# [333 rows x 3 columns]

# %%
from patsy import dmatrix 

dm = dmatrix("center(atk)+ center(cont) + center(dfd)", pcaset_logit_log)
dm
# Out:
# DesignMatrix with shape (333, 4)
#   Intercept  center(atk)  center(cont)  center(dfd)
#           1      0.00849       0.35382      0.39813
#           1     -0.00466       0.26562      0.21573
#           1      0.01970      -0.11652      0.03153
#           1      0.01813      -0.33951     -0.02046
#           1      0.01849       0.30691      0.23655
#           1      0.01580       0.23597      0.15664
#           1      0.02430      -0.23117      0.13771
#           1      0.01251       0.33023      0.22071
#           1      0.01220       0.26616      0.32949
#           1      0.04120      -0.24079      0.09700
#           1     -0.00479       0.16575      0.17195
#           1      0.04512      -0.04494      0.10130
#           1     -0.00443      -0.55592     -0.07033
#           1      0.00690       0.02985      0.15111
#           1     -0.00181       0.12847      0.33780
#           1      0.00757       0.55651      0.22246
# ...

# %%
df = pd.DataFrame(dm)
df.columns = ['bias','atk','cont','dfd']
df.describe()
# Out:
#         bias           atk          cont           dfd
# count  333.0  3.330000e+02  3.330000e+02  3.330000e+02
# mean     1.0  3.167303e-17 -1.166901e-18  2.667202e-17
# std      0.0  1.844418e-02  2.407172e-01  1.499243e-01
# min      1.0 -3.034521e-02 -8.901680e-01 -2.540902e-01
# 25%      1.0 -1.482350e-02 -1.390813e-01 -1.239085e-01
# 50%      1.0 -3.189286e-03  1.194143e-02 -2.260390e-02
# 75%      1.0  1.303325e-02  1.452519e-01  1.072450e-01
# max      1.0  5.565184e-02  6.539693e-01  4.690581e-01

# %%
dfX_train, dfX_test, dfy_train, dfy_test = train_test_split(df, valset, test_size=0.3, random_state=0)

# %%
model = sm.OLS(dfy_train,dfX_train)
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  value   R-squared:                       0.076
# Model:                            OLS   Adj. R-squared:                  0.063
# Method:                 Least Squares   F-statistic:                     6.239
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           0.000434
# Time:                        17:07:35   Log-Likelihood:                -978.52
# No. Observations:                 233   AIC:                             1965.
# Df Residuals:                     229   BIC:                             1979.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# bias          32.6484      1.070     30.519      0.000      30.541      34.756
# ...

# %%
df.corr()
# Out:
#       bias       atk      cont       dfd
# bias   NaN       NaN       NaN       NaN
# atk    NaN  1.000000  0.022661  0.340038
# cont   NaN  0.022661  1.000000  0.547025
# dfd    NaN  0.340038  0.547025  1.000000
