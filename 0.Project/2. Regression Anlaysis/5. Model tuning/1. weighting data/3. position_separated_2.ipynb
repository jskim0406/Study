# %% [markdown]
# # 작업 데이터 받기

# %%
df_pos = pd.read_csv('df_pos.csv', encoding='utf-8-sig', index_col=0)

# %%
df_pos
# Out:
#         player_name  position        age      height     weight    rating  \
# 0       A. Anguissa  2.000000  25.000000  184.000000  78.000000  2.333333
# 1        A. Belotti  4.000000  27.000000  181.000000  72.000000  5.250000
# 2    A. Christensen  3.000000  24.000000  188.000000  78.000000  6.000000
# 3         A. Correa  4.000000  25.000000  171.000000  70.000000  7.000000
# 4      A. Di MarÃ­a  2.000000  32.000000  180.000000  75.000000  4.833333
# ..              ...       ...        ...         ...        ...       ...
# 366         W. Zaha  4.000000  28.000000  180.000000  66.000000  3.888889
# 367          Wesley  3.769231  23.076923  188.230769  86.769231  1.615385
# 368         Willian  4.000000  32.000000  175.000000  77.000000  6.153846
# 369      Y. Poulsen  4.000000  26.000000  192.000000  84.000000  6.545455
# 370    Y. Tielemans  2.000000  23.000000  176.000000  72.000000  4.384615
#
#      value  follower  shots_total  shots_on  goals_total  goals_conceded  \
# 0     20.0     67879       0.5540    0.1288       0.0129             0.0
# 1     32.0    740918       2.8168    1.0538       0.4432             0.0
# 2     24.0    601838       0.3802    0.0613       0.0000             0.0
# 3     32.0    652886       1.9736    0.8442       0.2282             0.0
# 4     32.0  11513791       3.0823    1.1138       0.4705             0.0
# ..     ...       ...          ...       ...          ...             ...
# 366   44.0   1028085       2.0280    0.7120       0.2373             0.0
# 367   24.0     57900       0.4836    0.2579       0.3761             0.0
# 368   22.5   8983450       2.5586    0.9795       0.2798             0.0
# 369   24.0    109000       2.0141    0.7524       0.3357             0.0
# 370   44.0    282254       1.6977    0.6011       0.1476             0.0
#
#      goals_assists  passes_total  passes_key  passes_accuracy  tackles_total  \
# 0           0.0000       22.1875      0.2706           3.2985         1.2112
# 1           0.0985       12.3211      0.9554           4.0184         0.4629
# 2           0.0123       58.0175      0.1717          13.4528         1.0301
# 3           0.2168       23.4897      1.5287           9.1609         0.7758
# 4           0.3745       32.2437      2.2277           6.1453         0.4321
# ..             ...           ...         ...              ...            ...
# 366         0.1187       21.4995      1.4779           4.2611         1.1758
# 367         0.0107        4.1158      0.2042           2.3642         0.1397
# 368         0.2798       38.4786      3.0083           8.6552         0.7696
# 369         0.2662       16.8656      1.2039           7.4315         0.3936
# 370         0.1371       38.4359      1.1705           6.6011         1.0018
#
#      tackles_blocks  tackles_interceptions  duels_total  duels_won  \
# 0            0.1417                 0.8504       3.4402     1.6621
# 1            0.0985                 0.2659      12.3211     5.6829
# 2            0.3802                 1.3367       6.4627     4.1940
# 3            0.1141                 0.9355      12.5833     5.0082
# 4            0.0480                 0.4225       4.3785     1.7380
# ..              ...                    ...          ...        ...
# 366          0.0216                 0.3452      18.3819     8.4358
# 367          0.0215                 0.0430       0.9994     0.4299
# 368          0.0300                 0.5297       8.1555     4.2876
# 369          0.0695                 0.3010      14.2611     6.6791
# 370          0.1371                 0.9807       9.6907     4.9139
#
#      dribbles_attempts  dribbles_success  fouls_drawn  fouls_committed  \
# 0               1.4431            1.1467       0.5283           0.7473
# 1               1.9304            0.9947       2.8562           1.7039
# 2               0.1594            0.1594       0.5641           0.5886
# 3               4.4378            2.5440       1.6086           1.6542
# 4               3.2455            1.6804       0.6433           0.4225
# ..                 ...               ...          ...              ...
# 366             7.0011            4.0453       3.0097           1.4671
# 367             0.3224            0.1612       0.2794           0.5803
# 368             4.0677            2.8384       1.6691           0.6396
# 369             1.9563            0.9260       1.8637           1.7595
# 370             1.5079            0.8858       1.4341           1.2232
#
#      cards_yellow  cards_yellowred  cards_red  penalty_won  penalty_commited  \
# 0          0.1804           0.0129     0.0000       0.0000            0.0000
# 1          0.1083           0.0000     0.0000       0.0394            0.0000
# 2          0.0981           0.0000     0.0000       0.0000            0.0000
# 3          0.2738           0.0114     0.0114       0.0114            0.0114
# 4          0.0960           0.0000     0.0000       0.0096            0.0192
# ..            ...              ...        ...          ...               ...
# 366        0.2050           0.0108     0.0000       0.1187            0.0000
# 367        0.1612           0.0000     0.0107       0.0000            0.0000
# 368        0.0800           0.0000     0.0000       0.0500            0.0000
# 369        0.1042           0.0000     0.0000       0.0463            0.0000
# 370        0.1582           0.0000     0.0000       0.0000            0.0000
#
#      penalty_success  penalty_missed  penalty_saved  games_appearences  \
# 0             0.0000          0.0000            0.0             1.4044
# 1             0.0985          0.0295            0.0             1.0538
# 2             0.0000          0.0000            0.0             1.1160
# 3             0.0000          0.0000            0.0             1.5515
# 4             0.0096          0.0096            0.0             1.2003
# ..               ...             ...            ...                ...
# 366           0.0000          0.0000            0.0             1.0248
# 367           0.0000          0.0107            0.0             1.2143
# 368           0.0500          0.0000            0.0             1.4592
# 369           0.0116          0.0000            0.0             1.4006
# 370           0.0105          0.0000            0.0             1.2021
#
#      games_lineups  substitutes_in  substitutes_out  substitutes_bench  \
# 0           0.9277          0.4767           0.2577             0.5927
# 1           0.9947          0.0591           0.0689             0.0689
# 2           1.0056          0.1104           0.1839             0.7603
# 3           0.9697          0.5818           0.6731             0.6160
# 4           1.0754          0.1248           0.5857             0.2401
# ..             ...             ...              ...                ...
# 366         0.9924          0.0324           0.0647             0.0324
# 367         1.0531          0.1612           0.5158             0.3116
# 368         1.0294          0.4298           0.5397             0.5197
# 369         0.9492          0.4514           0.2894             0.5788
# 370         1.0334          0.1687           0.3058             0.2636
#
#      games_played
# 0         77.6111
# 1        101.5333
# 2         81.5444
# 3         87.6556
# 4        104.1444
# ..            ...
# 366       92.7000
# 367       93.0556
# 368      100.0556
# 369       86.3889
# 370       94.8333
#
# [371 rows x 39 columns]

# %% [markdown]
# # Position Rounding

# %%
df_pos.position = df_pos.position.round()

# %%
df_pos.position.unique()
# Out:
# array([2., 4., 3., 1.])

# %%
df_atk = df_pos[df_pos.position == 4]
df_atk
# Out:
#       player_name  position        age      height     weight    rating  \
# 1      A. Belotti       4.0  27.000000  181.000000  72.000000  5.250000
# 3       A. Correa       4.0  25.000000  171.000000  70.000000  7.000000
# 7    A. Griezmann       4.0  29.000000  176.000000  73.000000  6.666667
# 12    A. Kramaric       4.0  29.000000  177.000000  73.000000  6.777778
# 13   A. Lacazette       4.0  29.000000  175.000000  73.000000  5.750000
# ..            ...       ...        ...         ...        ...       ...
# 365   W. Weghorst       4.0  28.000000  197.000000  84.000000  6.000000
# 366       W. Zaha       4.0  28.000000  180.000000  66.000000  3.888889
# 367        Wesley       4.0  23.076923  188.230769  86.769231  1.615385
# 368       Willian       4.0  32.000000  175.000000  77.000000  6.153846
# 369    Y. Poulsen       4.0  26.000000  192.000000  84.000000  6.545455
#
#      value  follower  shots_total  shots_on  goals_total  goals_conceded  \
# 1     32.0    740918       2.8168    1.0538       0.4432             0.0
# 3     32.0    652886       1.9736    0.8442       0.2282             0.0
# 7     96.0  30243196       2.6247    1.2356       0.5249             0.0
# 12    30.5    351898       3.3557    1.3951       0.5279             0.0
# 13    48.0   3141100       2.7988    1.1863       0.5183             0.0
# ..     ...       ...          ...       ...          ...             ...
# 365   21.5     48391       2.6578    1.2209       0.5635             0.0
# 366   44.0   1028085       2.0280    0.7120       0.2373             0.0
# 367   24.0     57900       0.4836    0.2579       0.3761             0.0
# 368   22.5   8983450       2.5586    0.9795       0.2798             0.0
# 369   24.0    109000       2.0141    0.7524       0.3357             0.0
#
#      goals_assists  passes_total  passes_key  passes_accuracy  tackles_total  \
# 1           0.0985       12.3211      0.9554           4.0184         0.4629
# 3           0.2168       23.4897      1.5287           9.1609         0.7758
# 7           0.2261       29.6070      1.5183           6.7839         0.4684
# 12          0.1760       27.3481      1.8978           8.9485         0.0880
# 13          0.2073       20.6629      1.3476           8.6383         1.1633
# ..             ...           ...         ...              ...            ...
# 365         0.1690       16.9331      1.1176           3.6346         0.4038
# 366         0.1187       21.4995      1.4779           4.2611         1.1758
# 367         0.0107        4.1158      0.2042           2.3642         0.1397
# 368         0.2798       38.4786      3.0083           8.6552         0.7696
# 369         0.2662       16.8656      1.2039           7.4315         0.3936
#
#      tackles_blocks  tackles_interceptions  duels_total  duels_won  \
# 1            0.0985                 0.2659      12.3211     5.6829
# 3            0.1141                 0.9355      12.5833     5.0082
# 7            0.0323                 0.4119       6.5174     2.8912
# 12           0.0377                 0.2765       5.5048     1.9481
# 13           0.0576                 0.3686      12.9460     5.3097
# ..              ...                    ...          ...        ...
# 365          0.0751                 0.1690       7.6824     3.6252
# 366          0.0216                 0.3452      18.3819     8.4358
# 367          0.0215                 0.0430       0.9994     0.4299
# 368          0.0300                 0.5297       8.1555     4.2876
# 369          0.0695                 0.3010      14.2611     6.6791
#
#      dribbles_attempts  dribbles_success  fouls_drawn  fouls_committed  \
# 1               1.9304            0.9947       2.8562           1.7039
# 3               4.4378            2.5440       1.6086           1.6542
# 7               1.3083            0.7188       1.0499           0.6057
# 12              1.9103            0.9677       0.9175           0.3393
# 13              2.2229            1.3591       1.6470           1.6931
# ..                 ...               ...          ...              ...
# 365             0.8171            0.4132       1.2397           1.1082
# 366             7.0011            4.0453       3.0097           1.4671
# 367             0.3224            0.1612       0.2794           0.5803
# 368             4.0677            2.8384       1.6691           0.6396
# 369             1.9563            0.9260       1.8637           1.7595
#
#      cards_yellow  cards_yellowred  cards_red  penalty_won  penalty_commited  \
# 1          0.1083           0.0000     0.0000       0.0394            0.0000
# 3          0.2738           0.0114     0.0114       0.0114            0.0114
# 7          0.1696           0.0000     0.0081       0.0162            0.0000
# 12         0.1005           0.0000     0.0000       0.0000            0.0000
# 13         0.1267           0.0000     0.0115       0.0230            0.0000
# ..            ...              ...        ...          ...               ...
# 365        0.1784           0.0094     0.0000       0.0282            0.0094
# 366        0.2050           0.0108     0.0000       0.1187            0.0000
# 367        0.1612           0.0000     0.0107       0.0000            0.0000
# 368        0.0800           0.0000     0.0000       0.0500            0.0000
# 369        0.1042           0.0000     0.0000       0.0463            0.0000
#
#      penalty_success  penalty_missed  penalty_saved  games_appearences  \
# 1             0.0985          0.0295            0.0             1.0538
# 3             0.0000          0.0000            0.0             1.5515
# 7             0.0485          0.0000            0.0             1.1064
# 12            0.1131          0.0251            0.0             1.1814
# 13            0.0346          0.0000            0.0             1.3015
# ..               ...             ...            ...                ...
# 365           0.0939          0.0094            0.0             1.0331
# 366           0.0000          0.0000            0.0             1.0248
# 367           0.0000          0.0107            0.0             1.2143
# 368           0.0500          0.0000            0.0             1.4592
# 369           0.0116          0.0000            0.0             1.4006
#
#      games_lineups  substitutes_in  substitutes_out  substitutes_bench  \
# 1           0.9947          0.0591           0.0689             0.0689
# 3           0.9697          0.5818           0.6731             0.6160
# 7           1.0418          0.0646           0.3634             0.0969
# 12          0.9677          0.2137           0.2262             0.2639
# 13          1.0136          0.2879           0.4953             0.4262
# ..             ...             ...              ...                ...
# 365         1.0049          0.0282           0.1221             0.0282
# 366         0.9924          0.0324           0.0647             0.0324
# 367         1.0531          0.1612           0.5158             0.3116
# 368         1.0294          0.4298           0.5397             0.5197
# 369         0.9492          0.4514           0.2894             0.5788
#
#      games_played
# 1        101.5333
# 3         87.6556
# 7        123.8222
# 12        79.5667
# 13        86.8222
# ..            ...
# 365      106.4778
# 366       92.7000
# 367       93.0556
# 368      100.0556
# 369       86.3889
#
# [97 rows x 39 columns]

# %%
df_atk.reset_index(drop=True)
# Out:
#      player_name  position        age      height     weight    rating  value  \
# 0     A. Belotti       4.0  27.000000  181.000000  72.000000  5.250000   32.0
# 1      A. Correa       4.0  25.000000  171.000000  70.000000  7.000000   32.0
# 2   A. Griezmann       4.0  29.000000  176.000000  73.000000  6.666667   96.0
# 3    A. Kramaric       4.0  29.000000  177.000000  73.000000  6.777778   30.5
# 4   A. Lacazette       4.0  29.000000  175.000000  73.000000  5.750000   48.0
# ..           ...       ...        ...         ...        ...       ...    ...
# 92   W. Weghorst       4.0  28.000000  197.000000  84.000000  6.000000   21.5
# 93       W. Zaha       4.0  28.000000  180.000000  66.000000  3.888889   44.0
# 94        Wesley       4.0  23.076923  188.230769  86.769231  1.615385   24.0
# 95       Willian       4.0  32.000000  175.000000  77.000000  6.153846   22.5
# 96    Y. Poulsen       4.0  26.000000  192.000000  84.000000  6.545455   24.0
#
#     follower  shots_total  shots_on  goals_total  goals_conceded  \
# 0     740918       2.8168    1.0538       0.4432             0.0
# 1     652886       1.9736    0.8442       0.2282             0.0
# 2   30243196       2.6247    1.2356       0.5249             0.0
# 3     351898       3.3557    1.3951       0.5279             0.0
# 4    3141100       2.7988    1.1863       0.5183             0.0
# ..       ...          ...       ...          ...             ...
# 92     48391       2.6578    1.2209       0.5635             0.0
# 93   1028085       2.0280    0.7120       0.2373             0.0
# 94     57900       0.4836    0.2579       0.3761             0.0
# 95   8983450       2.5586    0.9795       0.2798             0.0
# 96    109000       2.0141    0.7524       0.3357             0.0
#
#     goals_assists  passes_total  passes_key  passes_accuracy  tackles_total  \
# 0          0.0985       12.3211      0.9554           4.0184         0.4629
# 1          0.2168       23.4897      1.5287           9.1609         0.7758
# 2          0.2261       29.6070      1.5183           6.7839         0.4684
# 3          0.1760       27.3481      1.8978           8.9485         0.0880
# 4          0.2073       20.6629      1.3476           8.6383         1.1633
# ..            ...           ...         ...              ...            ...
# 92         0.1690       16.9331      1.1176           3.6346         0.4038
# 93         0.1187       21.4995      1.4779           4.2611         1.1758
# 94         0.0107        4.1158      0.2042           2.3642         0.1397
# 95         0.2798       38.4786      3.0083           8.6552         0.7696
# 96         0.2662       16.8656      1.2039           7.4315         0.3936
#
#     tackles_blocks  tackles_interceptions  duels_total  duels_won  \
# 0           0.0985                 0.2659      12.3211     5.6829
# 1           0.1141                 0.9355      12.5833     5.0082
# 2           0.0323                 0.4119       6.5174     2.8912
# 3           0.0377                 0.2765       5.5048     1.9481
# 4           0.0576                 0.3686      12.9460     5.3097
# ..             ...                    ...          ...        ...
# 92          0.0751                 0.1690       7.6824     3.6252
# 93          0.0216                 0.3452      18.3819     8.4358
# 94          0.0215                 0.0430       0.9994     0.4299
# 95          0.0300                 0.5297       8.1555     4.2876
# 96          0.0695                 0.3010      14.2611     6.6791
#
#     dribbles_attempts  dribbles_success  fouls_drawn  fouls_committed  \
# 0              1.9304            0.9947       2.8562           1.7039
# 1              4.4378            2.5440       1.6086           1.6542
# 2              1.3083            0.7188       1.0499           0.6057
# 3              1.9103            0.9677       0.9175           0.3393
# 4              2.2229            1.3591       1.6470           1.6931
# ..                ...               ...          ...              ...
# 92             0.8171            0.4132       1.2397           1.1082
# 93             7.0011            4.0453       3.0097           1.4671
# 94             0.3224            0.1612       0.2794           0.5803
# 95             4.0677            2.8384       1.6691           0.6396
# 96             1.9563            0.9260       1.8637           1.7595
#
#     cards_yellow  cards_yellowred  cards_red  penalty_won  penalty_commited  \
# 0         0.1083           0.0000     0.0000       0.0394            0.0000
# 1         0.2738           0.0114     0.0114       0.0114            0.0114
# 2         0.1696           0.0000     0.0081       0.0162            0.0000
# 3         0.1005           0.0000     0.0000       0.0000            0.0000
# 4         0.1267           0.0000     0.0115       0.0230            0.0000
# ..           ...              ...        ...          ...               ...
# 92        0.1784           0.0094     0.0000       0.0282            0.0094
# 93        0.2050           0.0108     0.0000       0.1187            0.0000
# 94        0.1612           0.0000     0.0107       0.0000            0.0000
# 95        0.0800           0.0000     0.0000       0.0500            0.0000
# 96        0.1042           0.0000     0.0000       0.0463            0.0000
#
#     penalty_success  penalty_missed  penalty_saved  games_appearences  \
# 0            0.0985          0.0295            0.0             1.0538
# 1            0.0000          0.0000            0.0             1.5515
# 2            0.0485          0.0000            0.0             1.1064
# 3            0.1131          0.0251            0.0             1.1814
# 4            0.0346          0.0000            0.0             1.3015
# ..              ...             ...            ...                ...
# 92           0.0939          0.0094            0.0             1.0331
# 93           0.0000          0.0000            0.0             1.0248
# 94           0.0000          0.0107            0.0             1.2143
# 95           0.0500          0.0000            0.0             1.4592
# 96           0.0116          0.0000            0.0             1.4006
#
#     games_lineups  substitutes_in  substitutes_out  substitutes_bench  \
# 0          0.9947          0.0591           0.0689             0.0689
# 1          0.9697          0.5818           0.6731             0.6160
# 2          1.0418          0.0646           0.3634             0.0969
# 3          0.9677          0.2137           0.2262             0.2639
# 4          1.0136          0.2879           0.4953             0.4262
# ..            ...             ...              ...                ...
# 92         1.0049          0.0282           0.1221             0.0282
# 93         0.9924          0.0324           0.0647             0.0324
# 94         1.0531          0.1612           0.5158             0.3116
# 95         1.0294          0.4298           0.5397             0.5197
# 96         0.9492          0.4514           0.2894             0.5788
#
#     games_played
# 0       101.5333
# 1        87.6556
# 2       123.8222
# 3        79.5667
# 4        86.8222
# ..           ...
# 92      106.4778
# 93       92.7000
# 94       93.0556
# 95      100.0556
# 96       86.3889
#
# [97 rows x 39 columns]

# %% [markdown]
# # 상관관계 확인

# %%
df_atk.corr()[df_atk.corr() > 0.7].to_csv('df_atk_corr.csv', encoding='utf-8-sig')
df_atk.corr()[df_atk.corr() > 0.7]
# Out:
#                        position  age    height    weight  rating  value  \
# position                    NaN  NaN       NaN       NaN     NaN    NaN
# age                         NaN  1.0       NaN       NaN     NaN    NaN
# height                      NaN  NaN  1.000000  0.777958     NaN    NaN
# weight                      NaN  NaN  0.777958  1.000000     NaN    NaN
# rating                      NaN  NaN       NaN       NaN     1.0    NaN
# value                       NaN  NaN       NaN       NaN     NaN    1.0
# follower                    NaN  NaN       NaN       NaN     NaN    NaN
# shots_total                 NaN  NaN       NaN       NaN     NaN    NaN
# shots_on                    NaN  NaN       NaN       NaN     NaN    NaN
# goals_total                 NaN  NaN       NaN       NaN     NaN    NaN
# goals_conceded              NaN  NaN       NaN       NaN     NaN    NaN
# goals_assists               NaN  NaN       NaN       NaN     NaN    NaN
# passes_total                NaN  NaN       NaN       NaN     NaN    NaN
# passes_key                  NaN  NaN       NaN       NaN     NaN    NaN
# passes_accuracy             NaN  NaN       NaN       NaN     NaN    NaN
# tackles_total               NaN  NaN       NaN       NaN     NaN    NaN
# tackles_blocks              NaN  NaN       NaN       NaN     NaN    NaN
# tackles_interceptions       NaN  NaN       NaN       NaN     NaN    NaN
# duels_total                 NaN  NaN       NaN       NaN     NaN    NaN
# duels_won                   NaN  NaN       NaN       NaN     NaN    NaN
# dribbles_attempts           NaN  NaN       NaN       NaN     NaN    NaN
# dribbles_success            NaN  NaN       NaN       NaN     NaN    NaN
# fouls_drawn                 NaN  NaN       NaN       NaN     NaN    NaN
# fouls_committed             NaN  NaN       NaN       NaN     NaN    NaN
# cards_yellow                NaN  NaN       NaN       NaN     NaN    NaN
# cards_yellowred             NaN  NaN       NaN       NaN     NaN    NaN
# cards_red                   NaN  NaN       NaN       NaN     NaN    NaN
# penalty_won                 NaN  NaN       NaN       NaN     NaN    NaN
# penalty_commited            NaN  NaN       NaN       NaN     NaN    NaN
# penalty_success             NaN  NaN       NaN       NaN     NaN    NaN
# penalty_missed              NaN  NaN       NaN       NaN     NaN    NaN
# penalty_saved               NaN  NaN       NaN       NaN     NaN    NaN
# games_appearences           NaN  NaN       NaN       NaN     NaN    NaN
# games_lineups               NaN  NaN       NaN       NaN     NaN    NaN
# substitutes_in              NaN  NaN       NaN       NaN     NaN    NaN
# substitutes_out             NaN  NaN       NaN       NaN     NaN    NaN
# substitutes_bench           NaN  NaN       NaN       NaN     NaN    NaN
# games_played                NaN  NaN       NaN       NaN     NaN    NaN
#
#                        follower  shots_total  shots_on  goals_total  \
# position                    NaN          NaN       NaN          NaN
# age                         NaN          NaN       NaN          NaN
# height                      NaN          NaN       NaN          NaN
# weight                      NaN          NaN       NaN          NaN
# rating                      NaN          NaN       NaN          NaN
# value                       NaN          NaN       NaN          NaN
# follower                    1.0          NaN       NaN          NaN
# shots_total                 NaN     1.000000  0.919116          NaN
# shots_on                    NaN     0.919116  1.000000     0.823953
# goals_total                 NaN          NaN  0.823953     1.000000
# goals_conceded              NaN          NaN       NaN          NaN
# goals_assists               NaN          NaN       NaN          NaN
# passes_total                NaN          NaN       NaN          NaN
# passes_key                  NaN          NaN       NaN          NaN
# passes_accuracy             NaN          NaN       NaN          NaN
# tackles_total               NaN          NaN       NaN          NaN
# tackles_blocks              NaN          NaN       NaN          NaN
# tackles_interceptions       NaN          NaN       NaN          NaN
# duels_total                 NaN          NaN       NaN          NaN
# duels_won                   NaN          NaN       NaN          NaN
# dribbles_attempts           NaN          NaN       NaN          NaN
# dribbles_success            NaN          NaN       NaN          NaN
# fouls_drawn                 NaN          NaN       NaN          NaN
# fouls_committed             NaN          NaN       NaN          NaN
# cards_yellow                NaN          NaN       NaN          NaN
# cards_yellowred             NaN          NaN       NaN          NaN
# cards_red                   NaN          NaN       NaN          NaN
# penalty_won                 NaN          NaN       NaN          NaN
# penalty_commited            NaN          NaN       NaN          NaN
# penalty_success             NaN          NaN       NaN          NaN
# penalty_missed              NaN          NaN       NaN          NaN
# penalty_saved               NaN          NaN       NaN          NaN
# games_appearences           NaN          NaN       NaN          NaN
# games_lineups               NaN          NaN       NaN          NaN
# substitutes_in              NaN          NaN       NaN          NaN
# substitutes_out             NaN          NaN       NaN          NaN
# substitutes_bench           NaN          NaN       NaN          NaN
# games_played                NaN          NaN       NaN          NaN
#
#                        goals_conceded  goals_assists  passes_total  \
# position                          NaN            NaN           NaN
# age                               NaN            NaN           NaN
# height                            NaN            NaN           NaN
# weight                            NaN            NaN           NaN
# rating                            NaN            NaN           NaN
# value                             NaN            NaN           NaN
# follower                          NaN            NaN           NaN
# shots_total                       NaN            NaN           NaN
# shots_on                          NaN            NaN           NaN
# goals_total                       NaN            NaN           NaN
# goals_conceded                    NaN            NaN           NaN
# goals_assists                     NaN       1.000000      0.709068
# passes_total                      NaN       0.709068      1.000000
# passes_key                        NaN       0.720840      0.860205
# passes_accuracy                   NaN            NaN           NaN
# tackles_total                     NaN            NaN           NaN
# tackles_blocks                    NaN            NaN           NaN
# tackles_interceptions             NaN            NaN           NaN
# duels_total                       NaN            NaN           NaN
# duels_won                         NaN            NaN           NaN
# dribbles_attempts                 NaN            NaN           NaN
# dribbles_success                  NaN            NaN           NaN
# fouls_drawn                       NaN            NaN           NaN
# fouls_committed                   NaN            NaN           NaN
# cards_yellow                      NaN            NaN           NaN
# cards_yellowred                   NaN            NaN           NaN
# cards_red                         NaN            NaN           NaN
# penalty_won                       NaN            NaN           NaN
# penalty_commited                  NaN            NaN           NaN
# penalty_success                   NaN            NaN           NaN
# penalty_missed                    NaN            NaN           NaN
# penalty_saved                     NaN            NaN           NaN
# games_appearences                 NaN            NaN           NaN
# games_lineups                     NaN            NaN           NaN
# substitutes_in                    NaN            NaN           NaN
# substitutes_out                   NaN            NaN           NaN
# substitutes_bench                 NaN            NaN           NaN
# games_played                      NaN            NaN           NaN
#
#                        passes_key  passes_accuracy  tackles_total  \
# position                      NaN              NaN            NaN
# age                           NaN              NaN            NaN
# height                        NaN              NaN            NaN
# weight                        NaN              NaN            NaN
# rating                        NaN              NaN            NaN
# value                         NaN              NaN            NaN
# follower                      NaN              NaN            NaN
# shots_total                   NaN              NaN            NaN
# shots_on                      NaN              NaN            NaN
# goals_total                   NaN              NaN            NaN
# goals_conceded                NaN              NaN            NaN
# goals_assists            0.720840              NaN            NaN
# passes_total             0.860205              NaN            NaN
# passes_key               1.000000              NaN            NaN
# passes_accuracy               NaN              1.0            NaN
# tackles_total                 NaN              NaN            1.0
# tackles_blocks                NaN              NaN            NaN
# tackles_interceptions         NaN              NaN            NaN
# duels_total                   NaN              NaN            NaN
# duels_won                     NaN              NaN            NaN
# dribbles_attempts             NaN              NaN            NaN
# dribbles_success              NaN              NaN            NaN
# fouls_drawn                   NaN              NaN            NaN
# fouls_committed               NaN              NaN            NaN
# cards_yellow                  NaN              NaN            NaN
# cards_yellowred               NaN              NaN            NaN
# cards_red                     NaN              NaN            NaN
# penalty_won                   NaN              NaN            NaN
# penalty_commited              NaN              NaN            NaN
# penalty_success               NaN              NaN            NaN
# penalty_missed                NaN              NaN            NaN
# penalty_saved                 NaN              NaN            NaN
# games_appearences             NaN              NaN            NaN
# games_lineups                 NaN              NaN            NaN
# substitutes_in                NaN              NaN            NaN
# substitutes_out               NaN              NaN            NaN
# substitutes_bench             NaN              NaN            NaN
# games_played                  NaN              NaN            NaN
#
#                        tackles_blocks  tackles_interceptions  duels_total  \
# position                          NaN                    NaN          NaN
# age                               NaN                    NaN          NaN
# height                            NaN                    NaN          NaN
# weight                            NaN                    NaN          NaN
# rating                            NaN                    NaN          NaN
# value                             NaN                    NaN          NaN
# follower                          NaN                    NaN          NaN
# shots_total                       NaN                    NaN          NaN
# shots_on                          NaN                    NaN          NaN
# goals_total                       NaN                    NaN          NaN
# goals_conceded                    NaN                    NaN          NaN
# goals_assists                     NaN                    NaN          NaN
# passes_total                      NaN                    NaN          NaN
# passes_key                        NaN                    NaN          NaN
# passes_accuracy                   NaN                    NaN          NaN
# tackles_total                     NaN                    NaN          NaN
# tackles_blocks                    1.0                    NaN          NaN
# tackles_interceptions             NaN                    1.0          NaN
# duels_total                       NaN                    NaN     1.000000
# duels_won                         NaN                    NaN     0.957882
# dribbles_attempts                 NaN                    NaN          NaN
# dribbles_success                  NaN                    NaN          NaN
# fouls_drawn                       NaN                    NaN          NaN
# fouls_committed                   NaN                    NaN          NaN
# cards_yellow                      NaN                    NaN          NaN
# cards_yellowred                   NaN                    NaN          NaN
# cards_red                         NaN                    NaN          NaN
# penalty_won                       NaN                    NaN          NaN
# penalty_commited                  NaN                    NaN          NaN
# penalty_success                   NaN                    NaN          NaN
# penalty_missed                    NaN                    NaN          NaN
# penalty_saved                     NaN                    NaN          NaN
# games_appearences                 NaN                    NaN          NaN
# games_lineups                     NaN                    NaN          NaN
# substitutes_in                    NaN                    NaN          NaN
# substitutes_out                   NaN                    NaN          NaN
# substitutes_bench                 NaN                    NaN          NaN
# games_played                      NaN                    NaN          NaN
#
#                        duels_won  dribbles_attempts  dribbles_success  \
# position                     NaN                NaN               NaN
# age                          NaN                NaN               NaN
# height                       NaN                NaN               NaN
# weight                       NaN                NaN               NaN
# rating                       NaN                NaN               NaN
# value                        NaN                NaN               NaN
# follower                     NaN                NaN               NaN
# shots_total                  NaN                NaN               NaN
# shots_on                     NaN                NaN               NaN
# goals_total                  NaN                NaN               NaN
# goals_conceded               NaN                NaN               NaN
# goals_assists                NaN                NaN               NaN
# passes_total                 NaN                NaN               NaN
# passes_key                   NaN                NaN               NaN
# passes_accuracy              NaN                NaN               NaN
# tackles_total                NaN                NaN               NaN
# tackles_blocks               NaN                NaN               NaN
# tackles_interceptions        NaN                NaN               NaN
# duels_total             0.957882                NaN               NaN
# duels_won               1.000000                NaN               NaN
# dribbles_attempts            NaN           1.000000          0.977212
# dribbles_success             NaN           0.977212          1.000000
# fouls_drawn                  NaN                NaN               NaN
# fouls_committed              NaN                NaN               NaN
# cards_yellow                 NaN                NaN               NaN
# cards_yellowred              NaN                NaN               NaN
# cards_red                    NaN                NaN               NaN
# penalty_won                  NaN                NaN               NaN
# penalty_commited             NaN                NaN               NaN
# penalty_success              NaN                NaN               NaN
# penalty_missed               NaN                NaN               NaN
# penalty_saved                NaN                NaN               NaN
# games_appearences            NaN                NaN               NaN
# games_lineups                NaN                NaN               NaN
# substitutes_in               NaN                NaN               NaN
# substitutes_out              NaN                NaN               NaN
# substitutes_bench            NaN                NaN               NaN
# games_played                 NaN                NaN               NaN
#
#                        fouls_drawn  fouls_committed  cards_yellow  \
# position                       NaN              NaN           NaN
# age                            NaN              NaN           NaN
# height                         NaN              NaN           NaN
# weight                         NaN              NaN           NaN
# rating                         NaN              NaN           NaN
# value                          NaN              NaN           NaN
# follower                       NaN              NaN           NaN
# shots_total                    NaN              NaN           NaN
# shots_on                       NaN              NaN           NaN
# goals_total                    NaN              NaN           NaN
# goals_conceded                 NaN              NaN           NaN
# goals_assists                  NaN              NaN           NaN
# passes_total                   NaN              NaN           NaN
# passes_key                     NaN              NaN           NaN
# passes_accuracy                NaN              NaN           NaN
# tackles_total                  NaN              NaN           NaN
# tackles_blocks                 NaN              NaN           NaN
# tackles_interceptions          NaN              NaN           NaN
# duels_total                    NaN              NaN           NaN
# duels_won                      NaN              NaN           NaN
# dribbles_attempts              NaN              NaN           NaN
# dribbles_success               NaN              NaN           NaN
# fouls_drawn                    1.0              NaN           NaN
# fouls_committed                NaN              1.0           NaN
# cards_yellow                   NaN              NaN           1.0
# cards_yellowred                NaN              NaN           NaN
# cards_red                      NaN              NaN           NaN
# penalty_won                    NaN              NaN           NaN
# penalty_commited               NaN              NaN           NaN
# penalty_success                NaN              NaN           NaN
# penalty_missed                 NaN              NaN           NaN
# penalty_saved                  NaN              NaN           NaN
# games_appearences              NaN              NaN           NaN
# games_lineups                  NaN              NaN           NaN
# substitutes_in                 NaN              NaN           NaN
# substitutes_out                NaN              NaN           NaN
# substitutes_bench              NaN              NaN           NaN
# games_played                   NaN              NaN           NaN
#
#                        cards_yellowred  cards_red  penalty_won  \
# position                           NaN        NaN          NaN
# age                                NaN        NaN          NaN
# height                             NaN        NaN          NaN
# weight                             NaN        NaN          NaN
# rating                             NaN        NaN          NaN
# value                              NaN        NaN          NaN
# follower                           NaN        NaN          NaN
# shots_total                        NaN        NaN          NaN
# shots_on                           NaN        NaN          NaN
# goals_total                        NaN        NaN          NaN
# goals_conceded                     NaN        NaN          NaN
# goals_assists                      NaN        NaN          NaN
# passes_total                       NaN        NaN          NaN
# passes_key                         NaN        NaN          NaN
# passes_accuracy                    NaN        NaN          NaN
# tackles_total                      NaN        NaN          NaN
# tackles_blocks                     NaN        NaN          NaN
# tackles_interceptions              NaN        NaN          NaN
# duels_total                        NaN        NaN          NaN
# duels_won                          NaN        NaN          NaN
# dribbles_attempts                  NaN        NaN          NaN
# dribbles_success                   NaN        NaN          NaN
# fouls_drawn                        NaN        NaN          NaN
# fouls_committed                    NaN        NaN          NaN
# cards_yellow                       NaN        NaN          NaN
# cards_yellowred                    1.0        NaN          NaN
# cards_red                          NaN        1.0          NaN
# penalty_won                        NaN        NaN          1.0
# penalty_commited                   NaN        NaN          NaN
# penalty_success                    NaN        NaN          NaN
# penalty_missed                     NaN        NaN          NaN
# penalty_saved                      NaN        NaN          NaN
# games_appearences                  NaN        NaN          NaN
# games_lineups                      NaN        NaN          NaN
# substitutes_in                     NaN        NaN          NaN
# substitutes_out                    NaN        NaN          NaN
# substitutes_bench                  NaN        NaN          NaN
# games_played                       NaN        NaN          NaN
#
#                        penalty_commited  penalty_success  penalty_missed  \
# position                            NaN              NaN             NaN
# age                                 NaN              NaN             NaN
# height                              NaN              NaN             NaN
# weight                              NaN              NaN             NaN
# rating                              NaN              NaN             NaN
# value                               NaN              NaN             NaN
# follower                            NaN              NaN             NaN
# shots_total                         NaN              NaN             NaN
# shots_on                            NaN              NaN             NaN
# goals_total                         NaN              NaN             NaN
# goals_conceded                      NaN              NaN             NaN
# goals_assists                       NaN              NaN             NaN
# passes_total                        NaN              NaN             NaN
# passes_key                          NaN              NaN             NaN
# passes_accuracy                     NaN              NaN             NaN
# tackles_total                       NaN              NaN             NaN
# tackles_blocks                      NaN              NaN             NaN
# tackles_interceptions               NaN              NaN             NaN
# duels_total                         NaN              NaN             NaN
# duels_won                           NaN              NaN             NaN
# dribbles_attempts                   NaN              NaN             NaN
# dribbles_success                    NaN              NaN             NaN
# fouls_drawn                         NaN              NaN             NaN
# fouls_committed                     NaN              NaN             NaN
# cards_yellow                        NaN              NaN             NaN
# cards_yellowred                     NaN              NaN             NaN
# cards_red                           NaN              NaN             NaN
# penalty_won                         NaN              NaN             NaN
# penalty_commited                    1.0              NaN             NaN
# penalty_success                     NaN              1.0             NaN
# penalty_missed                      NaN              NaN             1.0
# penalty_saved                       NaN              NaN             NaN
# games_appearences                   NaN              NaN             NaN
# games_lineups                       NaN              NaN             NaN
# substitutes_in                      NaN              NaN             NaN
# substitutes_out                     NaN              NaN             NaN
# substitutes_bench                   NaN              NaN             NaN
# games_played                        NaN              NaN             NaN
#
#                        penalty_saved  games_appearences  games_lineups  \
# position                         NaN                NaN            NaN
# age                              NaN                NaN            NaN
# height                           NaN                NaN            NaN
# weight                           NaN                NaN            NaN
# rating                           NaN                NaN            NaN
# value                            NaN                NaN            NaN
# follower                         NaN                NaN            NaN
# shots_total                      NaN                NaN            NaN
# shots_on                         NaN                NaN            NaN
# goals_total                      NaN                NaN            NaN
# goals_conceded                   NaN                NaN            NaN
# goals_assists                    NaN                NaN            NaN
# passes_total                     NaN                NaN            NaN
# passes_key                       NaN                NaN            NaN
# passes_accuracy                  NaN                NaN            NaN
# tackles_total                    NaN                NaN            NaN
# tackles_blocks                   NaN                NaN            NaN
# tackles_interceptions            NaN                NaN            NaN
# duels_total                      NaN                NaN            NaN
# duels_won                        NaN                NaN            NaN
# dribbles_attempts                NaN                NaN            NaN
# dribbles_success                 NaN                NaN            NaN
# fouls_drawn                      NaN                NaN            NaN
# fouls_committed                  NaN                NaN            NaN
# cards_yellow                     NaN                NaN            NaN
# cards_yellowred                  NaN                NaN            NaN
# cards_red                        NaN                NaN            NaN
# penalty_won                      NaN                NaN            NaN
# penalty_commited                 NaN                NaN            NaN
# penalty_success                  NaN                NaN            NaN
# penalty_missed                   NaN                NaN            NaN
# penalty_saved                    NaN                NaN            NaN
# games_appearences                NaN           1.000000            NaN
# games_lineups                    NaN                NaN            1.0
# substitutes_in                   NaN           0.986265            NaN
# substitutes_out                  NaN                NaN            NaN
# substitutes_bench                NaN           0.945942            NaN
# games_played                     NaN                NaN            NaN
#
#                        substitutes_in  substitutes_out  substitutes_bench  \
# position                          NaN              NaN                NaN
# age                               NaN              NaN                NaN
# height                            NaN              NaN                NaN
# weight                            NaN              NaN                NaN
# rating                            NaN              NaN                NaN
# value                             NaN              NaN                NaN
# follower                          NaN              NaN                NaN
# shots_total                       NaN              NaN                NaN
# shots_on                          NaN              NaN                NaN
# goals_total                       NaN              NaN                NaN
# goals_conceded                    NaN              NaN                NaN
# goals_assists                     NaN              NaN                NaN
# passes_total                      NaN              NaN                NaN
# passes_key                        NaN              NaN                NaN
# passes_accuracy                   NaN              NaN                NaN
# tackles_total                     NaN              NaN                NaN
# tackles_blocks                    NaN              NaN                NaN
# tackles_interceptions             NaN              NaN                NaN
# duels_total                       NaN              NaN                NaN
# duels_won                         NaN              NaN                NaN
# dribbles_attempts                 NaN              NaN                NaN
# dribbles_success                  NaN              NaN                NaN
# fouls_drawn                       NaN              NaN                NaN
# fouls_committed                   NaN              NaN                NaN
# cards_yellow                      NaN              NaN                NaN
# cards_yellowred                   NaN              NaN                NaN
# cards_red                         NaN              NaN                NaN
# penalty_won                       NaN              NaN                NaN
# penalty_commited                  NaN              NaN                NaN
# penalty_success                   NaN              NaN                NaN
# penalty_missed                    NaN              NaN                NaN
# penalty_saved                     NaN              NaN                NaN
# games_appearences            0.986265              NaN           0.945942
# games_lineups                     NaN              NaN                NaN
# substitutes_in               1.000000              NaN           0.956530
# substitutes_out                   NaN              1.0                NaN
# substitutes_bench            0.956530              NaN           1.000000
# games_played                      NaN              NaN                NaN
#
#                        games_played
# position                        NaN
# age                             NaN
# height                          NaN
# weight                          NaN
# rating                          NaN
# value                           NaN
# follower                        NaN
# shots_total                     NaN
# shots_on                        NaN
# goals_total                     NaN
# goals_conceded                  NaN
# goals_assists                   NaN
# passes_total                    NaN
# passes_key                      NaN
# passes_accuracy                 NaN
# tackles_total                   NaN
# tackles_blocks                  NaN
# tackles_interceptions           NaN
# duels_total                     NaN
# duels_won                       NaN
# dribbles_attempts               NaN
# dribbles_success                NaN
# fouls_drawn                     NaN
# fouls_committed                 NaN
# cards_yellow                    NaN
# cards_yellowred                 NaN
# cards_red                       NaN
# penalty_won                     NaN
# penalty_commited                NaN
# penalty_success                 NaN
# penalty_missed                  NaN
# penalty_saved                   NaN
# games_appearences               NaN
# games_lineups                   NaN
# substitutes_in                  NaN
# substitutes_out                 NaN
# substitutes_bench               NaN
# games_played                    1.0

# %%
pd.read_csv('df_atk_corrc.csv', encoding='utf-8-sig', index_col=0)
# Out:
#                      height    weight  shots_total  shots_on  goals_total  \
# height             1.000000  0.778017          NaN       NaN          NaN
# weight             0.778017  1.000000          NaN       NaN          NaN
# shots_total             NaN       NaN     1.000000  0.914266          NaN
# shots_on                NaN       NaN     0.914266  1.000000     0.836092
# goals_total             NaN       NaN          NaN  0.836092     1.000000
# goals_assists           NaN       NaN          NaN       NaN          NaN
# passes_total            NaN       NaN          NaN       NaN          NaN
# passes_key              NaN       NaN          NaN       NaN          NaN
# duels_total             NaN       NaN          NaN       NaN          NaN
# duels_won               NaN       NaN          NaN       NaN          NaN
# dribbles_attempts       NaN       NaN          NaN       NaN          NaN
# dribbles_success        NaN       NaN          NaN       NaN          NaN
# games_appearences       NaN       NaN          NaN       NaN          NaN
# substitutes_in          NaN       NaN          NaN       NaN          NaN
# substitutes_bench       NaN       NaN          NaN       NaN          NaN
#
#                    goals_assists  passes_total  passes_key  duels_total  \
# height                       NaN           NaN         NaN          NaN
# weight                       NaN           NaN         NaN          NaN
# shots_total                  NaN           NaN         NaN          NaN
# shots_on                     NaN           NaN         NaN          NaN
# goals_total                  NaN           NaN         NaN          NaN
# goals_assists           1.000000           NaN    0.716906          NaN
# passes_total                 NaN      1.000000    0.853508          NaN
# passes_key              0.716906      0.853508    1.000000          NaN
# duels_total                  NaN           NaN         NaN     1.000000
# duels_won                    NaN           NaN         NaN     0.955737
# dribbles_attempts            NaN           NaN         NaN          NaN
# dribbles_success             NaN           NaN         NaN          NaN
# games_appearences            NaN           NaN         NaN          NaN
# substitutes_in               NaN           NaN         NaN          NaN
# substitutes_bench            NaN           NaN         NaN          NaN
#
#                    duels_won  dribbles_attempts  dribbles_success  \
# height                   NaN                NaN               NaN
# weight                   NaN                NaN               NaN
# shots_total              NaN                NaN               NaN
# shots_on                 NaN                NaN               NaN
# goals_total              NaN                NaN               NaN
# goals_assists            NaN                NaN               NaN
# passes_total             NaN                NaN               NaN
# passes_key               NaN                NaN               NaN
# duels_total         0.955737                NaN               NaN
# duels_won           1.000000                NaN               NaN
# dribbles_attempts        NaN           1.000000          0.976587
# dribbles_success         NaN           0.976587          1.000000
# games_appearences        NaN                NaN               NaN
# substitutes_in           NaN                NaN               NaN
# substitutes_bench        NaN                NaN               NaN
#
#                    games_appearences  substitutes_in  substitutes_bench
# height                           NaN             NaN                NaN
# weight                           NaN             NaN                NaN
# shots_total                      NaN             NaN                NaN
# shots_on                         NaN             NaN                NaN
# goals_total                      NaN             NaN                NaN
# goals_assists                    NaN             NaN                NaN
# passes_total                     NaN             NaN                NaN
# passes_key                       NaN             NaN                NaN
# duels_total                      NaN             NaN                NaN
# duels_won                        NaN             NaN                NaN
# dribbles_attempts                NaN             NaN                NaN
# dribbles_success                 NaN             NaN                NaN
# games_appearences           1.000000        0.986520           0.947216
# substitutes_in              0.986520        1.000000           0.959352
# substitutes_bench           0.947216        0.959352           1.000000

# %% [markdown]
# # 높은 상관관계를 보이는 feature들
# 1. height, weight
# 2. shots_total, shots_on, goals_total
# 3. passes_key, passes_total, goals_assists
# 4. duels_total, duels_won
# 5. dribbles_attempts, dribbles_success
# 6. games_appearences, substitutes_in, substitutes_bench

# %%
df_pos = df_atk

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler

# %%
# 1. height, weight PCA
df_pos_hw = df_pos[['height', 'weight']]
df_pos_hw = StandardScaler().fit_transform(df_pos_hw)
df_pos_pca_hw = pd.DataFrame(data = PCA(n_components=1).fit_transform(df_pos_hw), columns=['hw'])
df_pos_pca_hw['hw'] = MinMaxScaler().fit_transform(df_pos_pca_hw)
df_pos_pca_hw
# Out:
#           hw
# 0   0.135092
# 1   0.172989
# 2   0.144042
# 3   0.141252
# 4   0.146832
# ..       ...
# 92  0.030463
# 93  0.167877
# 94  0.041084
# 95  0.126835
# 96  0.044413
#
# [97 rows x 1 columns]

# %%
# 2. shots_on, shots_total and goals_total PCA
df_pos_sotgt = df_pos[['shots_on', 'shots_total', 'goals_total']]
df_pos_sotgt = StandardScaler().fit_transform(df_pos_sotgt)
df_pos_pca_sg = pd.DataFrame(data = PCA(n_components=1).fit_transform(df_pos_sotgt), columns=['shotsOnTotal_goalsTotal'])
df_pos_pca_sg['shotsOnTotal_goalsTotal'] = MinMaxScaler().fit_transform(df_pos_pca_sg)
df_pos_pca_sg
# Out:
#     shotsOnTotal_goalsTotal
# 0                  0.410180
# 1                  0.258458
# 2                  0.449352
# 3                  0.522966
# 4                  0.451450
# ..                      ...
# 92                 0.460795
# 93                 0.244692
# 94                 0.114543
# 95                 0.333166
# 96                 0.279174
#
# [97 rows x 1 columns]

# %%
# 3. passes_key, passes_total, goals_assists PCA
df_pos_pktga = df_pos[['passes_key', 'passes_total', 'goals_assists']]
df_pos_pktga = StandardScaler().fit_transform(df_pos_pktga)
df_pos_pca_pktga = pd.DataFrame(data = PCA(n_components=1).fit_transform(df_pos_pktga), columns=['passesKeyTotal_goalsAssists'])
df_pos_pca_pktga['passesKeyTotal_goalsAssists'] = MinMaxScaler().fit_transform(df_pos_pca_pktga)
df_pos_pca_pktga
# Out:
#     passesKeyTotal_goalsAssists
# 0                      0.247653
# 1                      0.495514
# 2                      0.546876
# 3                      0.538682
# 4                      0.444267
# ..                          ...
# 92                     0.357580
# 93                     0.397444
# 94                     0.023259
# 95                     0.842611
# 96                     0.444154
#
# [97 rows x 1 columns]

# %%
# 4. duels_total, duels_won PCA
df_pos_duels = df_pos[['duels_total', 'duels_won']]
df_pos_duels = StandardScaler().fit_transform(df_pos_duels)
df_pos_pca_duels = pd.DataFrame(data = PCA(n_components=1).fit_transform(df_pos_duels), columns=['duelsWonTotal'])
df_pos_pca_duels['duelsWonTotal'] = MinMaxScaler().fit_transform(df_pos_pca_duels)
df_pos_pca_duels
# Out:
#     duelsWonTotal
# 0        0.556537
# 1        0.529304
# 2        0.281113
# 3        0.210466
# 4        0.552810
# ..            ...
# 92       0.345001
# 93       0.836112
# 94       0.028809
# 95       0.388996
# 96       0.651724
#
# [97 rows x 1 columns]

# %%
# 5. dribbles_attempts, dribbles_success PCA
df_pos_dribbles = df_pos[['dribbles_attempts', 'dribbles_success']]
df_pos_dribbles = StandardScaler().fit_transform(df_pos_dribbles)
df_pos_pca_dribbles = pd.DataFrame(data = PCA(n_components=1).fit_transform(df_pos_dribbles), columns=['dribblesAtmptsSuc'])
df_pos_pca_dribbles['dribblesAtmptsSuc'] = MinMaxScaler().fit_transform(df_pos_pca_dribbles)
df_pos_pca_dribbles
# Out:
#     dribblesAtmptsSuc
# 0            0.177385
# 1            0.477339
# 2            0.113115
# 3            0.173616
# 4            0.229560
# ..                ...
# 92           0.054158
# 93           0.776258
# 94           0.000000
# 95           0.482005
# 96           0.172558
#
# [97 rows x 1 columns]

# %%
# 6. games_appearences, substitutes_in, substitutes_bench PCA
df_pos_gasub = df_pos[['games_appearences', 'substitutes_in', 'substitutes_bench']]
df_pos_gasub = StandardScaler().fit_transform(df_pos_gasub)
df_pos_pca_gasub = pd.DataFrame(data = PCA(n_components=1).fit_transform(df_pos_gasub), columns=['gamesAppearance_sub'])
df_pos_pca_gasub['gamesAppearance_sub'] = MinMaxScaler().fit_transform(df_pos_pca_gasub)
df_pos_pca_gasub
# Out:
#     gamesAppearance_sub
# 0              0.030469
# 1              0.542955
# 2              0.060079
# 3              0.182433
# 4              0.295547
# ..                  ...
# 92             0.001575
# 93             0.000774
# 94             0.188988
# 95             0.430106
# 96             0.428896
#
# [97 rows x 1 columns]

# %% [markdown]
# # PCA Feature Table

# %%
df_pca = pd.concat([df_pos_pca_hw, df_pos_pca_sg, df_pos_pca_pktga, df_pos_pca_duels, 
                    df_pos_pca_dribbles, df_pos_pca_gasub], axis=1)
df_pca
# Out:
#           hw  shotsOnTotal_goalsTotal  passesKeyTotal_goalsAssists  \
# 0   0.135092                 0.410180                     0.247653
# 1   0.172989                 0.258458                     0.495514
# 2   0.144042                 0.449352                     0.546876
# 3   0.141252                 0.522966                     0.538682
# 4   0.146832                 0.451450                     0.444267
# ..       ...                      ...                          ...
# 92  0.030463                 0.460795                     0.357580
# 93  0.167877                 0.244692                     0.397444
# 94  0.041084                 0.114543                     0.023259
# 95  0.126835                 0.333166                     0.842611
# 96  0.044413                 0.279174                     0.444154
#
#     duelsWonTotal  dribblesAtmptsSuc  gamesAppearance_sub
# 0        0.556537           0.177385             0.030469
# 1        0.529304           0.477339             0.542955
# 2        0.281113           0.113115             0.060079
# 3        0.210466           0.173616             0.182433
# 4        0.552810           0.229560             0.295547
# ..            ...                ...                  ...
# 92       0.345001           0.054158             0.001575
# 93       0.836112           0.776258             0.000774
# 94       0.028809           0.000000             0.188988
# 95       0.388996           0.482005             0.430106
# 96       0.651724           0.172558             0.428896
#
# [97 rows x 6 columns]

# %%
df_pca.corr()[df_pca.corr() > 0.7]
# Out:
#                               hw  shotsOnTotal_goalsTotal  \
# hw                           1.0                      NaN
# shotsOnTotal_goalsTotal      NaN                      1.0
# passesKeyTotal_goalsAssists  NaN                      NaN
# duelsWonTotal                NaN                      NaN
# dribblesAtmptsSuc            NaN                      NaN
# gamesAppearance_sub          NaN                      NaN
#
#                              passesKeyTotal_goalsAssists  duelsWonTotal  \
# hw                                                   NaN            NaN
# shotsOnTotal_goalsTotal                              NaN            NaN
# passesKeyTotal_goalsAssists                          1.0            NaN
# duelsWonTotal                                        NaN            1.0
# dribblesAtmptsSuc                                    NaN            NaN
# gamesAppearance_sub                                  NaN            NaN
#
#                              dribblesAtmptsSuc  gamesAppearance_sub
# hw                                         NaN                  NaN
# shotsOnTotal_goalsTotal                    NaN                  NaN
# passesKeyTotal_goalsAssists                NaN                  NaN
# duelsWonTotal                              NaN                  NaN
# dribblesAtmptsSuc                          1.0                  NaN
# gamesAppearance_sub                        NaN                  1.0

# %% [markdown]
# # PCA feature들과 그 외 feature들의 OLS 확인

# %%
pca_cols = ['height', 'weight', 'shots_total', 'shots_on', 'goals_total', 'passes_key', 'passes_total', 'goals_assists', 'duels_total', 'duels_won', 'dribbles_attempts', 'dribbles_success', 'games_appearences', 'substitutes_in', 'substitutes_bench']
npca_cols = df_pos.columns.tolist()
npca_features = [item for item in npca_cols if item not in pca_cols]

# %%
df_ols = pd.concat([df_pos[npca_features].reset_index(drop=True), df_pca.reset_index(drop=True)], axis=1)
df_ols = df_ols.drop('player_name', axis=1)
df_ols
# Out:
#     position        age    rating  value  follower  goals_conceded  \
# 0        4.0  27.000000  5.250000   32.0    740918             0.0
# 1        4.0  25.000000  7.000000   32.0    652886             0.0
# 2        4.0  29.000000  6.666667   96.0  30243196             0.0
# 3        4.0  29.000000  6.777778   30.5    351898             0.0
# 4        4.0  29.000000  5.750000   48.0   3141100             0.0
# ..       ...        ...       ...    ...       ...             ...
# 92       4.0  28.000000  6.000000   21.5     48391             0.0
# 93       4.0  28.000000  3.888889   44.0   1028085             0.0
# 94       4.0  23.076923  1.615385   24.0     57900             0.0
# 95       4.0  32.000000  6.153846   22.5   8983450             0.0
# 96       4.0  26.000000  6.545455   24.0    109000             0.0
#
#     passes_accuracy  tackles_total  tackles_blocks  tackles_interceptions  \
# 0            4.0184         0.4629          0.0985                 0.2659
# 1            9.1609         0.7758          0.1141                 0.9355
# 2            6.7839         0.4684          0.0323                 0.4119
# 3            8.9485         0.0880          0.0377                 0.2765
# 4            8.6383         1.1633          0.0576                 0.3686
# ..              ...            ...             ...                    ...
# 92           3.6346         0.4038          0.0751                 0.1690
# 93           4.2611         1.1758          0.0216                 0.3452
# 94           2.3642         0.1397          0.0215                 0.0430
# 95           8.6552         0.7696          0.0300                 0.5297
# 96           7.4315         0.3936          0.0695                 0.3010
#
#     fouls_drawn  fouls_committed  cards_yellow  cards_yellowred  cards_red  \
# 0        2.8562           1.7039        0.1083           0.0000     0.0000
# 1        1.6086           1.6542        0.2738           0.0114     0.0114
# 2        1.0499           0.6057        0.1696           0.0000     0.0081
# 3        0.9175           0.3393        0.1005           0.0000     0.0000
# 4        1.6470           1.6931        0.1267           0.0000     0.0115
# ..          ...              ...           ...              ...        ...
# 92       1.2397           1.1082        0.1784           0.0094     0.0000
# 93       3.0097           1.4671        0.2050           0.0108     0.0000
# 94       0.2794           0.5803        0.1612           0.0000     0.0107
# 95       1.6691           0.6396        0.0800           0.0000     0.0000
# 96       1.8637           1.7595        0.1042           0.0000     0.0000
#
#     penalty_won  penalty_commited  penalty_success  penalty_missed  \
# 0        0.0394            0.0000           0.0985          0.0295
# 1        0.0114            0.0114           0.0000          0.0000
# 2        0.0162            0.0000           0.0485          0.0000
# 3        0.0000            0.0000           0.1131          0.0251
# 4        0.0230            0.0000           0.0346          0.0000
# ..          ...               ...              ...             ...
# 92       0.0282            0.0094           0.0939          0.0094
# 93       0.1187            0.0000           0.0000          0.0000
# 94       0.0000            0.0000           0.0000          0.0107
# 95       0.0500            0.0000           0.0500          0.0000
# 96       0.0463            0.0000           0.0116          0.0000
#
#     penalty_saved  games_lineups  substitutes_out  games_played        hw  \
# 0             0.0         0.9947           0.0689      101.5333  0.135092
# 1             0.0         0.9697           0.6731       87.6556  0.172989
# 2             0.0         1.0418           0.3634      123.8222  0.144042
# 3             0.0         0.9677           0.2262       79.5667  0.141252
# 4             0.0         1.0136           0.4953       86.8222  0.146832
# ..            ...            ...              ...           ...       ...
# 92            0.0         1.0049           0.1221      106.4778  0.030463
# 93            0.0         0.9924           0.0647       92.7000  0.167877
# 94            0.0         1.0531           0.5158       93.0556  0.041084
# 95            0.0         1.0294           0.5397      100.0556  0.126835
# 96            0.0         0.9492           0.2894       86.3889  0.044413
#
#     shotsOnTotal_goalsTotal  passesKeyTotal_goalsAssists  duelsWonTotal  \
# 0                  0.410180                     0.247653       0.556537
# 1                  0.258458                     0.495514       0.529304
# 2                  0.449352                     0.546876       0.281113
# 3                  0.522966                     0.538682       0.210466
# 4                  0.451450                     0.444267       0.552810
# ..                      ...                          ...            ...
# 92                 0.460795                     0.357580       0.345001
# 93                 0.244692                     0.397444       0.836112
# 94                 0.114543                     0.023259       0.028809
# 95                 0.333166                     0.842611       0.388996
# 96                 0.279174                     0.444154       0.651724
#
#     dribblesAtmptsSuc  gamesAppearance_sub
# 0            0.177385             0.030469
# 1            0.477339             0.542955
# 2            0.113115             0.060079
# 3            0.173616             0.182433
# 4            0.229560             0.295547
# ..                ...                  ...
# 92           0.054158             0.001575
# 93           0.776258             0.000774
# 94           0.000000             0.188988
# 95           0.482005             0.430106
# 96           0.172558             0.428896
#
# [97 rows x 29 columns]

# %% [markdown]
# # Drop 0 array - goals_conceded, penalty_saved

# %%
df_ols = df_ols.drop(['goals_conceded', 'penalty_saved', 'position'], axis=1)

# %%
df_ols.describe()
# Out:
#              age     rating       value      follower  passes_accuracy  \
# count  97.000000  97.000000   97.000000  9.700000e+01        97.000000
# mean   26.343577   5.619472   42.618557  1.025031e+07         7.225846
# std     3.429584   1.336405   29.784362  3.123112e+07         2.403319
# min    21.000000   1.615385   16.000000  2.170000e+02         2.364200
# 25%    23.000000   4.833333   22.500000  1.725910e+05         5.618700
# 50%    26.000000   5.909091   32.000000  8.105720e+05         6.972900
# 75%    29.000000   6.666667   52.000000  6.510041e+06         8.638300
# max    35.000000   8.222222  180.000000  2.221069e+08        14.405500
#
#        tackles_total  tackles_blocks  tackles_interceptions  fouls_drawn  \
# count      97.000000       97.000000              97.000000    97.000000
# mean        0.493836        0.045160               0.378538     1.504666
# std         0.289592        0.040231               0.222234     0.718100
# min         0.088000        0.000000               0.043000     0.053800
# 25%         0.291400        0.017900               0.223500     0.931900
# 50%         0.428000        0.033500               0.330900     1.445000
# 75%         0.645900        0.061300               0.523700     1.809100
# max         1.522100        0.226200               1.278300     3.890500
#
#        fouls_committed  cards_yellow  cards_yellowred  cards_red  penalty_won  \
# count        97.000000     97.000000        97.000000  97.000000    97.000000
# mean          1.081376      0.132977         0.002418   0.004511     0.036384
# std           0.458367      0.068077         0.005498   0.008103     0.027210
# min           0.197400      0.009000         0.000000   0.000000     0.000000
# 25%           0.702500      0.088300         0.000000   0.000000     0.016200
# 50%           0.995100      0.116700         0.000000   0.000000     0.029600
# 75%           1.430400      0.170000         0.000000   0.009200     0.051600
# max           2.147400      0.323000         0.025900   0.037400     0.118700
#
#        penalty_commited  penalty_success  penalty_missed  games_lineups  \
# count         97.000000        97.000000       97.000000      97.000000
# mean           0.001646         0.047635        0.012269       1.005377
# std            0.004144         0.049158        0.013025       0.036354
# min            0.000000         0.000000        0.000000       0.879900
# 25%            0.000000         0.009200        0.000000       0.990200
# 50%            0.000000         0.034800        0.010300       1.005200
# 75%            0.000000         0.071300        0.020100       1.031400
# max            0.018800         0.223300        0.058500       1.079900
#
#        substitutes_out  games_played         hw  shotsOnTotal_goalsTotal  \
# count        97.000000     97.000000  97.000000                97.000000
# mean          0.387452     88.700230   0.144011                 0.437942
# std           0.153759     19.173289   0.139507                 0.163285
# min           0.025100     50.466700   0.000000                 0.000000
# 25%           0.284400     78.466700   0.086728                 0.330349
# 50%           0.394900     89.877800   0.131254                 0.425288
# 75%           0.501600    101.211100   0.161829                 0.519016
# max           0.776800    128.755600   1.000000                 1.000000
#
#        passesKeyTotal_goalsAssists  duelsWonTotal  dribblesAtmptsSuc  \
# count                    97.000000      97.000000          97.000000
# mean                      0.457267       0.409203           0.290756
# std                       0.193506       0.172634           0.178383
# min                       0.000000       0.000000           0.000000
# 25%                       0.316075       0.310624           0.170131
# 50%                       0.444267       0.401547           0.269119
# 75%                       0.546876       0.514526           0.395081
# max                       1.000000       1.000000           1.000000
#
#        gamesAppearance_sub
# count            97.000000
# mean              0.235239
# std               0.184541
# min               0.000000
# 25%               0.105245
# 50%               0.188988
# 75%               0.320653
# max               1.000000

# %% [markdown]
# # OLS - 1차

# %%
from sklearn.model_selection import train_test_split

#df_ols = df_out_14_2_5
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.771
# Model:                            OLS   Adj. R-squared:                  0.632
# Method:                 Least Squares   F-statistic:                     5.525
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           7.71e-07
# Time:                        17:23:35   Log-Likelihood:                -276.09
# No. Observations:                  67   AIC:                             604.2
# Df Residuals:                      41   BIC:                             661.5
# Df Model:                          25
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                             42.6493      2.328     18.319      0.000      37.947      47.351
# scale(age)                           -17.7339      3.808     -4.657      0.000     -25.425     -10.043
# scale(rating)                         -1.3977      3.948     -0.354      0.725      -9.372       6.576
# scale(follower)                        7.5459      4.063      1.857      0.070      -0.659      15.751
# scale(passes_accuracy)                 7.1491      4.639      1.541      0.131      -2.220      16.519
# scale(tackles_total)                  13.0886      4.838      2.706      0.010       3.319      22.859
# scale(tackles_blocks)                  1.2809      3.268      0.392      0.697      -5.319       7.881
# scale(tackles_interceptions)          -8.9206      3.494     -2.553      0.015     -15.977      -1.864
# scale(fouls_drawn)                     8.1728      5.256      1.555      0.128      -2.442      18.788
# scale(fouls_committed)               -15.0598      6.804     -2.213      0.032     -28.800      -1.320
# scale(cards_yellow)                    6.8485      4.032      1.699      0.097      -1.294      14.991
# scale(cards_yellowred)                -0.4221      3.211     -0.131      0.896      -6.907       6.063
# scale(cards_red)                       4.7011      2.843      1.654      0.106      -1.040      10.442
# scale(penalty_won)                     4.2063      3.573      1.177      0.246      -3.010      11.423
# scale(penalty_commited)                2.2738      2.750      0.827      0.413      -3.279       7.827
# scale(penalty_success)                -5.6032      4.000     -1.401      0.169     -13.682       2.476
# scale(penalty_missed)                 -1.2813      3.322     -0.386      0.702      -7.990       5.428
# scale(games_lineups)                 -18.8690      5.491     -3.436      0.001     -29.959      -7.779
# scale(substitutes_out)                17.8384      5.567      3.204      0.003       6.596      29.081
# scale(games_played)                   14.1475      4.228      3.346      0.002       5.610      22.685
# scale(hw)                             -3.8328      3.406     -1.125      0.267     -10.712       3.046
# scale(shotsOnTotal_goalsTotal)        18.1050      5.616      3.224      0.002       6.764      29.446
# scale(passesKeyTotal_goalsAssists)     3.6216      4.533      0.799      0.429      -5.532      12.775
# scale(duelsWonTotal)                   0.1868      4.584      0.041      0.968      -9.071       9.445
# scale(dribblesAtmptsSuc)              -5.4744      6.214     -0.881      0.383     -18.024       7.075
# scale(gamesAppearance_sub)           -24.5773      6.514     -3.773      0.001     -37.733     -11.422
# ==============================================================================
# Omnibus:                        6.377   Durbin-Watson:                   2.321
# Prob(Omnibus):                  0.041   Jarque-Bera (JB):                8.918
# Skew:                           0.252   Prob(JB):                       0.0116
# Kurtosis:                       4.714   Cond. No.                         9.90
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
# 모델 성능 : -0.09278507082254392

# %% [markdown]
# # OLS - 2차

# %%
df_ols_1 = df_ols.drop(['duelsWonTotal'], axis=1)
len(df_ols.columns), len(df_ols_1.columns)
# Out:
# (26, 25)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_1
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())




##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.771
# Model:                            OLS   Adj. R-squared:                  0.640
# Method:                 Least Squares   F-statistic:                     5.895
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           3.09e-07
# Time:                        18:00:15   Log-Likelihood:                -276.09
# No. Observations:                  67   AIC:                             602.2
# Df Residuals:                      42   BIC:                             657.3
# Df Model:                          24
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                             42.6493      2.300     18.541      0.000      38.007      47.291
# scale(age)                           -17.7119      3.725     -4.755      0.000     -25.230     -10.194
# scale(rating)                         -1.3583      3.782     -0.359      0.721      -8.991       6.274
# scale(follower)                        7.5467      4.014      1.880      0.067      -0.554      15.647
# scale(passes_accuracy)                 7.1167      4.516      1.576      0.123      -1.998      16.231
# scale(tackles_total)                  13.1014      4.770      2.747      0.009       3.476      22.727
# scale(tackles_blocks)                  1.3109      3.146      0.417      0.679      -5.037       7.659
# scale(tackles_interceptions)          -8.9163      3.451     -2.584      0.013     -15.881      -1.952
# scale(fouls_drawn)                     8.1758      5.193      1.574      0.123      -2.304      18.656
# scale(fouls_committed)               -14.9543      6.217     -2.406      0.021     -27.500      -2.409
# scale(cards_yellow)                    6.8032      3.829      1.777      0.083      -0.924      14.531
# scale(cards_yellowred)                -0.4044      3.144     -0.129      0.898      -6.749       5.940
# scale(cards_red)                       4.7119      2.797      1.685      0.099      -0.932      10.356
# scale(penalty_won)                     4.2178      3.519      1.198      0.237      -2.885      11.320
# scale(penalty_commited)                2.2421      2.605      0.861      0.394      -3.016       7.500
# scale(penalty_success)                -5.5878      3.935     -1.420      0.163     -13.528       2.353
# scale(penalty_missed)                 -1.2882      3.278     -0.393      0.696      -7.903       5.327
# scale(games_lineups)                 -18.8617      5.423     -3.478      0.001     -29.805      -7.918
# scale(substitutes_out)                17.8353      5.500      3.243      0.002       6.737      28.934
# scale(games_played)                   14.1567      4.171      3.394      0.002       5.739      22.574
# scale(hw)                             -3.8164      3.342     -1.142      0.260     -10.561       2.928
# scale(shotsOnTotal_goalsTotal)        18.0753      5.502      3.285      0.002       6.972      29.178
# scale(passesKeyTotal_goalsAssists)     3.5878      4.403      0.815      0.420      -5.298      12.473
# scale(dribblesAtmptsSuc)              -5.3440      5.263     -1.015      0.316     -15.965       5.277
# scale(gamesAppearance_sub)           -24.5386      6.368     -3.854      0.000     -37.389     -11.688
# ==============================================================================
# Omnibus:                        6.374   Durbin-Watson:                   2.322
# Prob(Omnibus):                  0.041   Jarque-Bera (JB):                8.845
# Skew:                           0.258   Prob(JB):                       0.0120
# Kurtosis:                       4.704   Cond. No.                         9.41
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : -0.0721374138855686

# %% [markdown]
# # OLS - 3차

# %%
df_ols_2 = df_ols_1.drop(['cards_yellowred'], axis=1)
len(df_ols_1.columns), len(df_ols_2.columns)
# Out:
# (25, 24)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_2
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())




##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.771
# Model:                            OLS   Adj. R-squared:                  0.649
# Method:                 Least Squares   F-statistic:                     6.294
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           1.21e-07
# Time:                        18:00:42   Log-Likelihood:                -276.11
# No. Observations:                  67   AIC:                             600.2
# Df Residuals:                      43   BIC:                             653.1
# Df Model:                          23
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                             42.6493      2.274     18.756      0.000      38.064      47.235
# scale(age)                           -17.6875      3.677     -4.810      0.000     -25.104     -10.271
# scale(rating)                         -1.2696      3.676     -0.345      0.731      -8.683       6.144
# scale(follower)                        7.5719      3.963      1.911      0.063      -0.420      15.564
# scale(passes_accuracy)                 7.0657      4.447      1.589      0.119      -1.903      16.034
# scale(tackles_total)                  12.9954      4.644      2.798      0.008       3.630      22.361
# scale(tackles_blocks)                  1.3448      3.099      0.434      0.666      -4.904       7.594
# scale(tackles_interceptions)          -8.8452      3.367     -2.627      0.012     -15.636      -2.055
# scale(fouls_drawn)                     8.0630      5.060      1.594      0.118      -2.141      18.267
# scale(fouls_committed)               -14.8935      6.127     -2.431      0.019     -27.250      -2.537
# scale(cards_yellow)                    6.6464      3.588      1.852      0.071      -0.590      13.883
# scale(cards_red)                       4.7603      2.739      1.738      0.089      -0.764      10.285
# scale(penalty_won)                     4.3828      3.240      1.353      0.183      -2.150      10.916
# scale(penalty_commited)                2.2164      2.568      0.863      0.393      -2.962       7.395
# scale(penalty_success)                -5.6985      3.795     -1.501      0.141     -13.352       1.955
# scale(penalty_missed)                 -1.1767      3.125     -0.377      0.708      -7.479       5.125
# scale(games_lineups)                 -18.7076      5.228     -3.578      0.001     -29.251      -8.165
# scale(substitutes_out)                17.7620      5.407      3.285      0.002       6.858      28.666
# scale(games_played)                   14.1950      4.113      3.452      0.001       5.901      22.489
# scale(hw)                             -3.7215      3.222     -1.155      0.254     -10.220       2.776
# scale(shotsOnTotal_goalsTotal)        18.0415      5.432      3.321      0.002       7.086      28.997
# scale(passesKeyTotal_goalsAssists)     3.6983      4.269      0.866      0.391      -4.910      12.307
# scale(dribblesAtmptsSuc)              -5.4536      5.134     -1.062      0.294     -15.807       4.900
# scale(gamesAppearance_sub)           -24.3608      6.144     -3.965      0.000     -36.752     -11.970
# ==============================================================================
# Omnibus:                        6.403   Durbin-Watson:                   2.327
# Prob(Omnibus):                  0.041   Jarque-Bera (JB):                8.852
# Skew:                           0.264   Prob(JB):                       0.0120
# Kurtosis:                       4.701   Cond. No.                         9.23
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : -0.06546073281508324

# %% [markdown]
# # OLS - 4차

# %%
df_ols_3 = df_ols_2.drop(['rating'], axis=1)
len(df_ols_2.columns), len(df_ols_3.columns)
# Out:
# (24, 23)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_3
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())




##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.770
# Model:                            OLS   Adj. R-squared:                  0.656
# Method:                 Least Squares   F-statistic:                     6.709
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           4.77e-08
# Time:                        18:01:08   Log-Likelihood:                -276.20
# No. Observations:                  67   AIC:                             598.4
# Df Residuals:                      44   BIC:                             649.1
# Df Model:                          22
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                             42.6493      2.251     18.947      0.000      38.113      47.186
# scale(age)                           -17.8013      3.626     -4.910      0.000     -25.109     -10.494
# scale(follower)                        7.6460      3.917      1.952      0.057      -0.249      15.541
# scale(passes_accuracy)                 6.3397      3.880      1.634      0.109      -1.479      14.158
# scale(tackles_total)                  13.1520      4.575      2.875      0.006       3.931      22.373
# scale(tackles_blocks)                  1.4223      3.059      0.465      0.644      -4.743       7.588
# scale(tackles_interceptions)          -9.0664      3.272     -2.770      0.008     -15.662      -2.471
# scale(fouls_drawn)                     7.9853      5.004      1.596      0.118      -2.099      18.070
# scale(fouls_committed)               -15.2277      5.990     -2.542      0.015     -27.299      -3.157
# scale(cards_yellow)                    6.7000      3.549      1.888      0.066      -0.452      13.852
# scale(cards_red)                       4.9301      2.668      1.848      0.071      -0.446      10.307
# scale(penalty_won)                     4.4980      3.190      1.410      0.166      -1.931      10.927
# scale(penalty_commited)                2.0435      2.493      0.820      0.417      -2.981       7.068
# scale(penalty_success)                -5.7196      3.757     -1.523      0.135     -13.291       1.851
# scale(penalty_missed)                 -1.1359      3.091     -0.367      0.715      -7.366       5.094
# scale(games_lineups)                 -18.4657      5.129     -3.601      0.001     -28.802      -8.130
# scale(substitutes_out)                17.5579      5.321      3.300      0.002       6.835      28.281
# scale(games_played)                   13.6668      3.779      3.616      0.001       6.050      21.283
# scale(hw)                             -3.5887      3.167     -1.133      0.263      -9.971       2.794
# scale(shotsOnTotal_goalsTotal)        17.7287      5.302      3.344      0.002       7.042      28.415
# scale(passesKeyTotal_goalsAssists)     3.7820      4.219      0.896      0.375      -4.720      12.285
# scale(dribblesAtmptsSuc)              -5.4506      5.082     -1.072      0.289     -15.693       4.792
# scale(gamesAppearance_sub)           -24.1361      6.048     -3.991      0.000     -36.326     -11.946
# ==============================================================================
# Omnibus:                        6.572   Durbin-Watson:                   2.323
# Prob(Omnibus):                  0.037   Jarque-Bera (JB):                9.044
# Skew:                           0.285   Prob(JB):                       0.0109
# Kurtosis:                       4.707   Cond. No.                         9.04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : -0.0068713450466384

# %% [markdown]
# # OLS - 5차

# %%
df_ols_4 = df_ols_3.drop(['penalty_missed'], axis=1)
len(df_ols_3.columns), len(df_ols_4.columns)
# Out:
# (23, 22)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_4
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())




##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.770
# Model:                            OLS   Adj. R-squared:                  0.662
# Method:                 Least Squares   F-statistic:                     7.160
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           1.84e-08
# Time:                        18:01:47   Log-Likelihood:                -276.30
# No. Observations:                  67   AIC:                             596.6
# Df Residuals:                      45   BIC:                             645.1
# Df Model:                          21
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                             42.6493      2.229     19.132      0.000      38.159      47.139
# scale(age)                           -17.8359      3.590     -4.969      0.000     -25.066     -10.606
# scale(follower)                        8.0219      3.745      2.142      0.038       0.479      15.565
# scale(passes_accuracy)                 6.2106      3.826      1.623      0.112      -1.496      13.917
# scale(tackles_total)                  13.1080      4.529      2.894      0.006       3.985      22.231
# scale(tackles_blocks)                  1.5528      3.009      0.516      0.608      -4.508       7.614
# scale(tackles_interceptions)          -9.1502      3.233     -2.830      0.007     -15.662      -2.639
# scale(fouls_drawn)                     7.7494      4.914      1.577      0.122      -2.149      17.648
# scale(fouls_committed)               -15.3400      5.924     -2.589      0.013     -27.271      -3.409
# scale(cards_yellow)                    6.8147      3.501      1.947      0.058      -0.236      13.866
# scale(cards_red)                       4.8000      2.619      1.833      0.073      -0.474      10.074
# scale(penalty_won)                     4.9251      2.942      1.674      0.101      -1.000      10.851
# scale(penalty_commited)                2.0202      2.468      0.818      0.417      -2.951       6.992
# scale(penalty_success)                -6.0751      3.595     -1.690      0.098     -13.315       1.165
# scale(games_lineups)                 -18.6505      5.055     -3.690      0.001     -28.831      -8.470
# scale(substitutes_out)                17.9491      5.163      3.477      0.001       7.551      28.347
# scale(games_played)                   13.7300      3.739      3.672      0.001       6.200      21.261
# scale(hw)                             -3.5023      3.128     -1.120      0.269      -9.802       2.797
# scale(shotsOnTotal_goalsTotal)        17.2404      5.084      3.391      0.001       7.002      27.479
# scale(passesKeyTotal_goalsAssists)     3.8891      4.168      0.933      0.356      -4.506      12.284
# scale(dribblesAtmptsSuc)              -5.4014      5.031     -1.074      0.289     -15.535       4.732
# scale(gamesAppearance_sub)           -24.2417      5.983     -4.052      0.000     -36.292     -12.191
# ==============================================================================
# Omnibus:                        7.026   Durbin-Watson:                   2.293
# Prob(Omnibus):                  0.030   Jarque-Bera (JB):                9.553
# Skew:                           0.337   Prob(JB):                      0.00842
# Kurtosis:                       4.723   Cond. No.                         8.85
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : -0.006340515475998754

# %%
# OLS - 6차

# %%
df_ols_5 = df_ols_4.drop(['tackles_blocks'], axis=1)
len(df_ols_4.columns), len(df_ols_5.columns)
# Out:
# (22, 21)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_5
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())




##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.768
# Model:                            OLS   Adj. R-squared:                  0.668
# Method:                 Least Squares   F-statistic:                     7.626
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           7.28e-09
# Time:                        18:02:27   Log-Likelihood:                -276.50
# No. Observations:                  67   AIC:                             595.0
# Df Residuals:                      46   BIC:                             641.3
# Df Model:                          20
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                             42.6493      2.211     19.286      0.000      38.198      47.101
# scale(age)                           -17.4862      3.497     -5.001      0.000     -24.525     -10.447
# scale(follower)                        8.3890      3.647      2.300      0.026       1.047      15.731
# scale(passes_accuracy)                 6.4189      3.774      1.701      0.096      -1.179      14.017
# scale(tackles_total)                  12.8890      4.473      2.881      0.006       3.884      21.894
# scale(tackles_interceptions)          -9.2021      3.206     -2.871      0.006     -15.655      -2.750
# scale(fouls_drawn)                     7.6855      4.874      1.577      0.122      -2.124      17.495
# scale(fouls_committed)               -14.0752      5.350     -2.631      0.012     -24.844      -3.306
# scale(cards_yellow)                    6.3351      3.348      1.892      0.065      -0.405      13.075
# scale(cards_red)                       4.8727      2.594      1.879      0.067      -0.348      10.094
# scale(penalty_won)                     4.6808      2.880      1.625      0.111      -1.117      10.479
# scale(penalty_commited)                2.0046      2.448      0.819      0.417      -2.924       6.933
# scale(penalty_success)                -6.0577      3.566     -1.699      0.096     -13.235       1.120
# scale(games_lineups)                 -18.8191      5.004     -3.761      0.000     -28.891      -8.747
# scale(substitutes_out)                17.8158      5.115      3.483      0.001       7.520      28.112
# scale(games_played)                   13.2622      3.598      3.686      0.001       6.019      20.505
# scale(hw)                             -3.2024      3.049     -1.050      0.299      -9.339       2.934
# scale(shotsOnTotal_goalsTotal)        16.7093      4.938      3.384      0.001       6.769      26.650
# scale(passesKeyTotal_goalsAssists)     4.0010      4.129      0.969      0.338      -4.311      12.313
# scale(dribblesAtmptsSuc)              -5.6745      4.963     -1.143      0.259     -15.665       4.316
# scale(gamesAppearance_sub)           -24.4121      5.926     -4.119      0.000     -36.341     -12.483
# ==============================================================================
# Omnibus:                        7.399   Durbin-Watson:                   2.338
# Prob(Omnibus):                  0.025   Jarque-Bera (JB):                9.389
# Skew:                           0.410   Prob(JB):                      0.00914
# Kurtosis:                       4.640   Cond. No.                         8.62
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.005360268981847138

# %%
# OLS - 7차

# %%
df_ols_6 = df_ols_5.drop(['penalty_commited'], axis=1)
len(df_ols_5.columns), len(df_ols_6.columns)
# Out:
# (21, 20)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_6
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())




##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.765
# Model:                            OLS   Adj. R-squared:                  0.670
# Method:                 Least Squares   F-statistic:                     8.049
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           3.36e-09
# Time:                        18:04:27   Log-Likelihood:                -276.99
# No. Observations:                  67   AIC:                             594.0
# Df Residuals:                      47   BIC:                             638.1
# Df Model:                          19
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                             42.6493      2.204     19.354      0.000      38.216      47.082
# scale(age)                           -17.2457      3.472     -4.967      0.000     -24.231     -10.260
# scale(follower)                        8.4722      3.633      2.332      0.024       1.163      15.781
# scale(passes_accuracy)                 6.6695      3.749      1.779      0.082      -0.872      14.211
# scale(tackles_total)                  12.6059      4.444      2.836      0.007       3.665      21.547
# scale(tackles_interceptions)          -8.9876      3.184     -2.823      0.007     -15.392      -2.583
# scale(fouls_drawn)                     7.2689      4.830      1.505      0.139      -2.448      16.985
# scale(fouls_committed)               -13.1715      5.216     -2.525      0.015     -23.665      -2.677
# scale(cards_yellow)                    5.8964      3.293      1.790      0.080      -0.729      12.522
# scale(cards_red)                       5.1332      2.565      2.001      0.051      -0.027      10.294
# scale(penalty_won)                     4.6317      2.870      1.614      0.113      -1.141      10.405
# scale(penalty_success)                -5.6488      3.518     -1.606      0.115     -12.727       1.429
# scale(games_lineups)                 -18.3655      4.955     -3.706      0.001     -28.335      -8.397
# scale(substitutes_out)                16.9437      4.985      3.399      0.001       6.915      26.973
# scale(games_played)                   13.0794      3.579      3.655      0.001       5.880      20.279
# scale(hw)                             -3.4408      3.024     -1.138      0.261      -9.524       2.643
# scale(shotsOnTotal_goalsTotal)        15.7608      4.784      3.295      0.002       6.137      25.384
# scale(passesKeyTotal_goalsAssists)     4.1668      4.110      1.014      0.316      -4.101      12.434
# scale(dribblesAtmptsSuc)              -5.4850      4.941     -1.110      0.273     -15.424       4.454
# scale(gamesAppearance_sub)           -23.7026      5.842     -4.057      0.000     -35.455     -11.950
# ==============================================================================
# Omnibus:                        8.286   Durbin-Watson:                   2.324
# Prob(Omnibus):                  0.016   Jarque-Bera (JB):               10.703
# Skew:                           0.470   Prob(JB):                      0.00474
# Kurtosis:                       4.717   Cond. No.                         8.35
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.014706431955394329

# %%
# OLS - 8차

# %%
df_ols_7 = df_ols_6.drop(['passesKeyTotal_goalsAssists'], axis=1)
len(df_ols_6.columns), len(df_ols_7.columns)
# Out:
# (20, 19)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_7
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())




##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.760
# Model:                            OLS   Adj. R-squared:                  0.670
# Method:                 Least Squares   F-statistic:                     8.434
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           1.77e-09
# Time:                        18:05:04   Log-Likelihood:                -277.71
# No. Observations:                  67   AIC:                             593.4
# Df Residuals:                      48   BIC:                             635.3
# Df Model:                          18
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         42.6493      2.204     19.349      0.000      38.217      47.081
# scale(age)                       -16.9001      3.456     -4.889      0.000     -23.850      -9.950
# scale(follower)                    8.0923      3.615      2.239      0.030       0.824      15.361
# scale(passes_accuracy)             7.3001      3.698      1.974      0.054      -0.135      14.735
# scale(tackles_total)              12.6384      4.446      2.843      0.007       3.700      21.577
# scale(tackles_interceptions)      -8.0252      3.040     -2.640      0.011     -14.137      -1.913
# scale(fouls_drawn)                 7.7843      4.804      1.620      0.112      -1.876      17.444
# scale(fouls_committed)           -13.8198      5.179     -2.669      0.010     -24.232      -3.408
# scale(cards_yellow)                5.5013      3.271      1.682      0.099      -1.076      12.079
# scale(cards_red)                   4.5316      2.496      1.815      0.076      -0.488       9.551
# scale(penalty_won)                 4.0239      2.807      1.433      0.158      -1.620       9.668
# scale(penalty_success)            -5.7302      3.518     -1.629      0.110     -12.804       1.344
# scale(games_lineups)             -18.0397      4.946     -3.647      0.001     -27.985      -8.094
# scale(substitutes_out)            16.9931      4.986      3.408      0.001       6.967      27.019
# scale(games_played)               13.3242      3.572      3.731      0.001       6.143      20.505
# scale(hw)                         -4.0671      2.961     -1.374      0.176     -10.021       1.887
# scale(shotsOnTotal_goalsTotal)    16.7885      4.676      3.590      0.001       7.386      26.191
# scale(dribblesAtmptsSuc)          -3.0620      4.325     -0.708      0.482     -11.759       5.635
# scale(gamesAppearance_sub)       -23.6099      5.843     -4.041      0.000     -35.358     -11.862
# ==============================================================================
# Omnibus:                        9.077   Durbin-Watson:                   2.286
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):               11.160
# Skew:                           0.557   Prob(JB):                      0.00377
# Kurtosis:                       4.661   Cond. No.                         8.24
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.005998383477711833

# %% [markdown]
# # OLS - 9차

# %%
df_ols_8 = df_ols_7.drop(['dribblesAtmptsSuc'], axis=1)
len(df_ols_7.columns), len(df_ols_8.columns)
# Out:
# (19, 18)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_8
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())




##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.757
# Model:                            OLS   Adj. R-squared:                  0.673
# Method:                 Least Squares   F-statistic:                     8.992
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           7.17e-10
# Time:                        18:05:38   Log-Likelihood:                -278.06
# No. Observations:                  67   AIC:                             592.1
# Df Residuals:                      49   BIC:                             631.8
# Df Model:                          17
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         42.6493      2.193     19.448      0.000      38.242      47.056
# scale(age)                       -16.4839      3.389     -4.864      0.000     -23.294      -9.674
# scale(follower)                    7.2661      3.404      2.135      0.038       0.426      14.106
# scale(passes_accuracy)             7.4824      3.670      2.039      0.047       0.107      14.858
# scale(tackles_total)              10.9418      3.725      2.937      0.005       3.456      18.428
# scale(tackles_interceptions)      -7.8143      3.010     -2.596      0.012     -13.862      -1.766
# scale(fouls_drawn)                 5.4276      3.446      1.575      0.122      -1.498      12.353
# scale(fouls_committed)           -11.6534      4.156     -2.804      0.007     -20.006      -3.301
# scale(cards_yellow)                4.9045      3.145      1.560      0.125      -1.415      11.224
# scale(cards_red)                   4.7156      2.470      1.909      0.062      -0.248       9.680
# scale(penalty_won)                 3.9097      2.788      1.402      0.167      -1.693       9.513
# scale(penalty_success)            -5.1551      3.406     -1.514      0.137     -11.999       1.689
# scale(games_lineups)             -17.5448      4.872     -3.601      0.001     -27.335      -7.755
# scale(substitutes_out)            15.7547      4.646      3.391      0.001       6.419      25.091
# scale(games_played)               12.7718      3.467      3.683      0.001       5.804      19.740
# scale(hw)                         -3.7035      2.901     -1.277      0.208      -9.534       2.127
# scale(shotsOnTotal_goalsTotal)    16.1085      4.553      3.538      0.001       6.958      25.259
# scale(gamesAppearance_sub)       -23.0571      5.761     -4.002      0.000     -34.634     -11.480
# ==============================================================================
# Omnibus:                        9.897   Durbin-Watson:                   2.300
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):               11.970
# Skew:                           0.624   Prob(JB):                      0.00252
# Kurtosis:                       4.652   Cond. No.                         7.33
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.11966598526452343

# %%
# OLS - 10차

# %%
df_ols_9 = df_ols_8.drop(['hw'], axis=1)
len(df_ols_8.columns), len(df_ols_9.columns)
# Out:
# (18, 17)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_9
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())




##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.749
# Model:                            OLS   Adj. R-squared:                  0.669
# Method:                 Least Squares   F-statistic:                     9.335
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           4.71e-10
# Time:                        18:06:10   Log-Likelihood:                -279.15
# No. Observations:                  67   AIC:                             592.3
# Df Residuals:                      50   BIC:                             629.8
# Df Model:                          16
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         42.6493      2.207     19.327      0.000      38.217      47.082
# scale(age)                       -15.4765      3.316     -4.667      0.000     -22.137      -8.816
# scale(follower)                    8.2371      3.339      2.467      0.017       1.531      14.943
# scale(passes_accuracy)             8.0836      3.663      2.207      0.032       0.727      15.440
# scale(tackles_total)               9.3277      3.526      2.645      0.011       2.246      16.410
# scale(tackles_interceptions)      -8.5625      2.971     -2.883      0.006     -14.529      -2.596
# scale(fouls_drawn)                 4.6785      3.417      1.369      0.177      -2.185      11.542
# scale(fouls_committed)            -9.6608      3.876     -2.492      0.016     -17.446      -1.875
# scale(cards_yellow)                4.6572      3.158      1.475      0.147      -1.687      11.001
# scale(cards_red)                   5.0795      2.469      2.057      0.045       0.120      10.039
# scale(penalty_won)                 4.6215      2.749      1.681      0.099      -0.900      10.143
# scale(penalty_success)            -5.1198      3.427     -1.494      0.141     -12.003       1.764
# scale(games_lineups)             -17.1737      4.894     -3.509      0.001     -27.003      -7.345
# scale(substitutes_out)            16.3970      4.647      3.528      0.001       7.063      25.731
# scale(games_played)               13.6678      3.417      4.000      0.000       6.805      20.531
# scale(shotsOnTotal_goalsTotal)    14.7129      4.448      3.308      0.002       5.779      23.647
# scale(gamesAppearance_sub)       -22.8295      5.794     -3.940      0.000     -34.468     -11.191
# ==============================================================================
# Omnibus:                        8.215   Durbin-Watson:                   2.254
# Prob(Omnibus):                  0.016   Jarque-Bera (JB):                9.226
# Skew:                           0.546   Prob(JB):                      0.00992
# Kurtosis:                       4.454   Cond. No.                         7.28
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.11301028236261401

# %%
# OLS - 11차

# %%
df_ols_10 = df_ols_9.drop(['fouls_drawn'], axis=1)
len(df_ols_9.columns), len(df_ols_10.columns)
# Out:
# (17, 16)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_10
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())




##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.740
# Model:                            OLS   Adj. R-squared:                  0.663
# Method:                 Least Squares   F-statistic:                     9.667
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           3.39e-10
# Time:                        18:07:04   Log-Likelihood:                -280.39
# No. Observations:                  67   AIC:                             592.8
# Df Residuals:                      51   BIC:                             628.0
# Df Model:                          15
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         42.6493      2.226     19.163      0.000      38.181      47.117
# scale(age)                       -15.2942      3.342     -4.577      0.000     -22.003      -8.585
# scale(follower)                    9.7947      3.165      3.094      0.003       3.440      16.150
# scale(passes_accuracy)             9.1520      3.609      2.536      0.014       1.907      16.398
# scale(tackles_total)               8.0389      3.427      2.346      0.023       1.159      14.919
# scale(tackles_interceptions)      -7.3351      2.856     -2.568      0.013     -13.069      -1.601
# scale(fouls_committed)            -7.1038      3.425     -2.074      0.043     -13.981      -0.227
# scale(cards_yellow)                5.0979      3.169      1.609      0.114      -1.264      11.459
# scale(cards_red)                   4.9610      2.489      1.994      0.052      -0.035       9.957
# scale(penalty_won)                 6.2634      2.495      2.511      0.015       1.255      11.272
# scale(penalty_success)            -4.9527      3.454     -1.434      0.158     -11.887       1.982
# scale(games_lineups)             -17.1465      4.935     -3.474      0.001     -27.055      -7.238
# scale(substitutes_out)            15.7922      4.666      3.385      0.001       6.425      25.159
# scale(games_played)               13.6543      3.446      3.962      0.000       6.736      20.573
# scale(shotsOnTotal_goalsTotal)    13.7018      4.424      3.097      0.003       4.821      22.583
# scale(gamesAppearance_sub)       -23.4030      5.828     -4.015      0.000     -35.104     -11.702
# ==============================================================================
# Omnibus:                        6.879   Durbin-Watson:                   2.258
# Prob(Omnibus):                  0.032   Jarque-Bera (JB):                6.984
# Skew:                           0.501   Prob(JB):                       0.0304
# Kurtosis:                       4.223   Cond. No.                         7.27
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.17000008893879756

# %%
# OLS - 12차

# %%
df_ols_11 = df_ols_10.drop(['penalty_success'], axis=1)
len(df_ols_10.columns), len(df_ols_11.columns)
# Out:
# (16, 15)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_11
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())




##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.729
# Model:                            OLS   Adj. R-squared:                  0.656
# Method:                 Least Squares   F-statistic:                     10.01
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           2.61e-10
# Time:                        18:07:43   Log-Likelihood:                -281.71
# No. Observations:                  67   AIC:                             593.4
# Df Residuals:                      52   BIC:                             626.5
# Df Model:                          14
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         42.6493      2.248     18.971      0.000      38.138      47.160
# scale(age)                       -17.0195      3.149     -5.404      0.000     -23.339     -10.700
# scale(follower)                   10.1614      3.187      3.188      0.002       3.766      16.557
# scale(passes_accuracy)             9.7775      3.619      2.702      0.009       2.516      17.039
# scale(tackles_total)               8.7662      3.423      2.561      0.013       1.897      15.636
# scale(tackles_interceptions)      -7.5800      2.880     -2.632      0.011     -13.359      -1.801
# scale(fouls_committed)            -6.1193      3.390     -1.805      0.077     -12.921       0.683
# scale(cards_yellow)                4.6967      3.188      1.473      0.147      -1.701      11.094
# scale(cards_red)                   5.7057      2.458      2.321      0.024       0.773      10.639
# scale(penalty_won)                 5.6688      2.485      2.281      0.027       0.683      10.655
# scale(games_lineups)             -17.8961      4.957     -3.610      0.001     -27.843      -7.949
# scale(substitutes_out)            16.3022      4.699      3.469      0.001       6.873      25.732
# scale(games_played)               14.5953      3.417      4.271      0.000       7.738      21.453
# scale(shotsOnTotal_goalsTotal)    11.0538      4.060      2.722      0.009       2.906      19.201
# scale(gamesAppearance_sub)       -23.1484      5.885     -3.934      0.000     -34.957     -11.340
# ==============================================================================
# Omnibus:                        8.119   Durbin-Watson:                   2.235
# Prob(Omnibus):                  0.017   Jarque-Bera (JB):                9.421
# Skew:                           0.519   Prob(JB):                      0.00900
# Kurtosis:                       4.516   Cond. No.                         6.76
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.14587290332932779

# %%
# OLS - 13차

# %%
df_ols_12 = df_ols_11.drop(['cards_yellow'], axis=1)
len(df_ols_11.columns), len(df_ols_12.columns)
# Out:
# (15, 14)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_12
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())




##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.718
# Model:                            OLS   Adj. R-squared:                  0.649
# Method:                 Least Squares   F-statistic:                     10.38
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           2.07e-10
# Time:                        18:08:04   Log-Likelihood:                -283.08
# No. Observations:                  67   AIC:                             594.2
# Df Residuals:                      53   BIC:                             625.0
# Df Model:                          13
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         42.6493      2.273     18.765      0.000      38.091      47.208
# scale(age)                       -17.5169      3.165     -5.534      0.000     -23.866     -11.168
# scale(follower)                   10.8378      3.188      3.399      0.001       4.443      17.233
# scale(passes_accuracy)            10.7676      3.595      2.995      0.004       3.557      17.978
# scale(tackles_total)               7.0064      3.243      2.160      0.035       0.501      13.512
# scale(tackles_interceptions)      -6.6882      2.846     -2.350      0.023     -12.397      -0.979
# scale(fouls_committed)            -3.2624      2.811     -1.161      0.251      -8.900       2.375
# scale(cards_red)                   6.1337      2.468      2.485      0.016       1.184      11.084
# scale(penalty_won)                 5.7713      2.511      2.298      0.026       0.735      10.808
# scale(games_lineups)             -17.3509      4.998     -3.472      0.001     -27.375      -7.327
# scale(substitutes_out)            14.8350      4.643      3.195      0.002       5.523      24.147
# scale(games_played)               13.5506      3.380      4.010      0.000       6.772      20.329
# scale(shotsOnTotal_goalsTotal)    10.3393      4.076      2.537      0.014       2.165      18.514
# scale(gamesAppearance_sub)       -23.1072      5.949     -3.884      0.000     -35.040     -11.175
# ==============================================================================
# Omnibus:                        8.175   Durbin-Watson:                   2.192
# Prob(Omnibus):                  0.017   Jarque-Bera (JB):                8.994
# Skew:                           0.555   Prob(JB):                       0.0111
# Kurtosis:                       4.410   Cond. No.                         6.69
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.19370418529183744

# %%
# OLS - 14차

# %%
df_ols_13 = df_ols_12.drop(['fouls_committed'], axis=1)
len(df_ols_12.columns), len(df_ols_13.columns)
# Out:
# (14, 13)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_13
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())




##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.711
# Model:                            OLS   Adj. R-squared:                  0.647
# Method:                 Least Squares   F-statistic:                     11.06
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           1.11e-10
# Time:                        18:08:31   Log-Likelihood:                -283.92
# No. Observations:                  67   AIC:                             593.8
# Df Residuals:                      54   BIC:                             622.5
# Df Model:                          12
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         42.6493      2.280     18.705      0.000      38.078      47.220
# scale(age)                       -17.5060      3.176     -5.513      0.000     -23.873     -11.139
# scale(follower)                   11.7850      3.092      3.811      0.000       5.586      17.984
# scale(passes_accuracy)            12.1816      3.393      3.590      0.001       5.379      18.984
# scale(tackles_total)               5.7392      3.064      1.873      0.066      -0.404      11.882
# scale(tackles_interceptions)      -6.5201      2.852     -2.286      0.026     -12.238      -0.803
# scale(cards_red)                   5.8877      2.467      2.387      0.021       0.942      10.833
# scale(penalty_won)                 5.1653      2.464      2.096      0.041       0.225      10.106
# scale(games_lineups)             -18.2059      4.959     -3.671      0.001     -28.148      -8.264
# scale(substitutes_out)            15.5496      4.617      3.368      0.001       6.294      24.805
# scale(games_played)               14.3516      3.319      4.324      0.000       7.697      21.006
# scale(shotsOnTotal_goalsTotal)     9.0284      3.928      2.298      0.025       1.152      16.904
# scale(gamesAppearance_sub)       -24.3955      5.863     -4.161      0.000     -36.151     -12.640
# ==============================================================================
# Omnibus:                       10.210   Durbin-Watson:                   2.169
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):               11.963
# Skew:                           0.666   Prob(JB):                      0.00252
# Kurtosis:                       4.585   Cond. No.                         6.52
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.19830669290538155

# %%
scale(tackles_total)               5.7392      3.064      1.873      0.066      -0.404      11.882
scale(penalty_won)                 5.1653      2.464      2.096      0.041       0.225      10.106
scale(shotsOnTotal_goalsTotal)     9.0284      3.928      2.298      0.025       1.152      16.904

# %%
# OLS - 15차

# %%
df_ols_14 = df_ols_13.drop(['tackles_total'], axis=1)
len(df_ols_13.columns), len(df_ols_14.columns)
# Out:
# (13, 12)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_14
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())




##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.692
# Model:                            OLS   Adj. R-squared:                  0.630
# Method:                 Least Squares   F-statistic:                     11.24
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           1.54e-10
# Time:                        18:09:26   Log-Likelihood:                -286.03
# No. Observations:                  67   AIC:                             596.1
# Df Residuals:                      55   BIC:                             622.5
# Df Model:                          11
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         42.6493      2.331     18.293      0.000      37.977      47.322
# scale(age)                       -16.6523      3.214     -5.182      0.000     -23.092     -10.212
# scale(follower)                   11.7013      3.161      3.701      0.000       5.366      18.037
# scale(passes_accuracy)            14.0044      3.324      4.213      0.000       7.343      20.665
# scale(tackles_interceptions)      -3.8008      2.510     -1.514      0.136      -8.831       1.229
# scale(cards_red)                   5.7089      2.520      2.265      0.027       0.658      10.760
# scale(penalty_won)                 6.2190      2.453      2.535      0.014       1.303      11.135
# scale(games_lineups)             -17.2403      5.043     -3.418      0.001     -27.347      -7.133
# scale(substitutes_out)            14.5610      4.690      3.105      0.003       5.162      23.960
# scale(games_played)               14.2614      3.393      4.203      0.000       7.461      21.062
# scale(shotsOnTotal_goalsTotal)     7.0797      3.874      1.828      0.073      -0.683      14.843
# scale(gamesAppearance_sub)       -24.3656      5.996     -4.064      0.000     -36.381     -12.350
# ==============================================================================
# Omnibus:                        9.105   Durbin-Watson:                   2.058
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):               11.368
# Skew:                           0.550   Prob(JB):                      0.00340
# Kurtosis:                       4.692   Cond. No.                         6.37
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.20941829830366077

# %%
# OLS - 16차

# %%
df_ols_15 = df_ols_14.drop(['tackles_interceptions'], axis=1)
len(df_ols_14.columns), len(df_ols_15.columns)
# Out:
# (12, 11)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_15
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())




##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.679
# Model:                            OLS   Adj. R-squared:                  0.622
# Method:                 Least Squares   F-statistic:                     11.86
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           1.22e-10
# Time:                        18:09:59   Log-Likelihood:                -287.40
# No. Observations:                  67   AIC:                             596.8
# Df Residuals:                      56   BIC:                             621.0
# Df Model:                          10
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         42.6493      2.358     18.085      0.000      37.925      47.373
# scale(age)                       -16.3828      3.245     -5.048      0.000     -22.884      -9.881
# scale(follower)                   11.4932      3.195      3.598      0.001       5.093      17.893
# scale(passes_accuracy)            13.2531      3.324      3.987      0.000       6.594      19.912
# scale(cards_red)                   5.4024      2.541      2.126      0.038       0.312      10.493
# scale(penalty_won)                 6.3422      2.480      2.557      0.013       1.374      11.310
# scale(games_lineups)             -17.8738      5.084     -3.516      0.001     -28.057      -7.690
# scale(substitutes_out)            15.1142      4.729      3.196      0.002       5.641      24.588
# scale(games_played)               13.6111      3.405      3.998      0.000       6.790      20.432
# scale(shotsOnTotal_goalsTotal)     8.5608      3.791      2.258      0.028       0.966      16.155
# scale(gamesAppearance_sub)       -25.1303      6.043     -4.159      0.000     -37.236     -13.025
# ==============================================================================
# Omnibus:                       10.958   Durbin-Watson:                   2.090
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               14.240
# Skew:                           0.655   Prob(JB):                     0.000809
# Kurtosis:                       4.840   Cond. No.                         6.26
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.20408376946185514

# %% [markdown]
# # P값 모두 0.05 미만

# %%
# OLS - 17차

# %%
df_ols_16 = df_ols_15.drop(['cards_red'], axis=1)
len(df_ols_15.columns), len(df_ols_16.columns)
# Out:
# (11, 10)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_16
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())




##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.653
# Model:                            OLS   Adj. R-squared:                  0.599
# Method:                 Least Squares   F-statistic:                     11.94
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           2.57e-10
# Time:                        18:11:21   Log-Likelihood:                -290.00
# No. Observations:                  67   AIC:                             600.0
# Df Residuals:                      57   BIC:                             622.0
# Df Model:                           9
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         42.6493      2.430     17.551      0.000      37.783      47.515
# scale(age)                       -16.1354      3.342     -4.828      0.000     -22.828      -9.443
# scale(follower)                   11.0422      3.285      3.362      0.001       4.465      17.619
# scale(passes_accuracy)            11.9719      3.369      3.554      0.001       5.226      18.717
# scale(penalty_won)                 6.0666      2.552      2.377      0.021       0.957      11.177
# scale(games_lineups)             -15.5574      5.116     -3.041      0.004     -25.803      -5.312
# scale(substitutes_out)            15.0171      4.873      3.082      0.003       5.260      24.775
# scale(games_played)               12.7842      3.485      3.668      0.001       5.805      19.764
# scale(shotsOnTotal_goalsTotal)    10.3727      3.806      2.725      0.009       2.750      17.995
# scale(gamesAppearance_sub)       -23.3770      6.168     -3.790      0.000     -35.729     -11.025
# ==============================================================================
# Omnibus:                       24.845   Durbin-Watson:                   2.158
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               57.071
# Skew:                           1.148   Prob(JB):                     4.05e-13
# Kurtosis:                       6.895   Cond. No.                         6.19
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.2608856168050746

# %% [markdown]
# # OLS - 18차

# %% [markdown]
# df_ols_17 = df_ols_16.drop(['penalty_won'], axis=1)
# len(df_ols_16.columns), len(df_ols_17.columns)

# %% [markdown]
# from sklearn.model_selection import train_test_split
#
# df_ols = df_ols_17
# dfX = df_ols.drop(['value'], axis=1)
# dfy = df_ols['value']
# df = pd.concat([dfX, dfy], axis=1)
# df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)
#
# feature_names = list(dfX.columns)
# feature_names = ["scale({})".format(name) for name in feature_names]
#
# #formula = "value ~ " + "+".join(feature_names)
#
# model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
# result = model.fit()
# print(result.summary())
#
#
#
#
# ##############################################################################
# from sklearn.model_selection import KFold
#
# scores = np.zeros(10)
# cv = KFold(10, shuffle=True, random_state=0)
# for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
#     df_train = df_ols.iloc[idx_train]
#     df_test = df_ols.iloc[idx_test]
#
#     model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
#     result = model.fit()
#
#     pred = result.predict(df_test)
#     rss = ((df_test.value - pred) ** 2).sum()
#     tss = ((df_test.value - df_test.value.mean())** 2).sum()
#     rsquared = 1 - rss / tss
#
#     scores[i] = rsquared
# #    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
# print("모델 성능 : {}".format(scores.mean()))

# %% [markdown]
# # OLS - 19차

# %% [markdown]
# df_ols_18 = df_ols_17.drop(['substitutes_out'], axis=1)
# len(df_ols_17.columns), len(df_ols_18.columns)

# %% [markdown]
# from sklearn.model_selection import train_test_split
#
# df_ols = df_ols_18
# dfX = df_ols.drop(['value'], axis=1)
# dfy = df_ols['value']
# df = pd.concat([dfX, dfy], axis=1)
# df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)
#
# feature_names = list(dfX.columns)
# feature_names = ["scale({})".format(name) for name in feature_names]
#
# #formula = "value ~ " + "+".join(feature_names)
#
# model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
# result = model.fit()
# print(result.summary())
#
#
#
#
# ##############################################################################
# from sklearn.model_selection import KFold
#
# scores = np.zeros(10)
# cv = KFold(10, shuffle=True, random_state=0)
# for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
#     df_train = df_ols.iloc[idx_train]
#     df_test = df_ols.iloc[idx_test]
#
#     model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
#     result = model.fit()
#
#     pred = result.predict(df_test)
#     rss = ((df_test.value - pred) ** 2).sum()
#     tss = ((df_test.value - df_test.value.mean())** 2).sum()
#     rsquared = 1 - rss / tss
#
#     scores[i] = rsquared
# #    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
# print("모델 성능 : {}".format(scores.mean()))

# %% [markdown]
# # OLS - 20차

# %% [markdown]
# df_ols_19 = df_ols_18.drop(['games_lineups'], axis=1)
# len(df_ols_18.columns), len(df_ols_19.columns)

# %% [markdown]
# from sklearn.model_selection import train_test_split
#
# df_ols = df_ols_19
# dfX = df_ols.drop(['value'], axis=1)
# dfy = df_ols['value']
# df = pd.concat([dfX, dfy], axis=1)
# df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)
#
# feature_names = list(dfX.columns)
# feature_names = ["scale({})".format(name) for name in feature_names]
#
# #formula = "value ~ " + "+".join(feature_names)
#
# model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
# result = model.fit()
# print(result.summary())
#
#
#
#
# ##############################################################################
# from sklearn.model_selection import KFold
#
# scores = np.zeros(10)
# cv = KFold(10, shuffle=True, random_state=0)
# for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
#     df_train = df_ols.iloc[idx_train]
#     df_test = df_ols.iloc[idx_test]
#
#     model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
#     result = model.fit()
#
#     pred = result.predict(df_test)
#     rss = ((df_test.value - pred) ** 2).sum()
#     tss = ((df_test.value - df_test.value.mean())** 2).sum()
#     rsquared = 1 - rss / tss
#
#     scores[i] = rsquared
# #    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
# print("모델 성능 : {}".format(scores.mean()))

# %% [markdown]
# # OLS - 21차

# %% [markdown]
# df_ols_20 = df_ols_19.drop(['gamesAppearance_sub'], axis=1)
# len(df_ols_19.columns), len(df_ols_20.columns)

# %% [markdown]
# from sklearn.model_selection import train_test_split
#
# df_ols = df_ols_20
# dfX = df_ols.drop(['value'], axis=1)
# dfy = df_ols['value']
# df = pd.concat([dfX, dfy], axis=1)
# df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)
#
# feature_names = list(dfX.columns)
# feature_names = ["scale({})".format(name) for name in feature_names]
#
# #formula = "value ~ " + "+".join(feature_names)
#
# model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
# result = model.fit()
# print(result.summary())
#
#
#
#
# ##############################################################################
# from sklearn.model_selection import KFold
#
# scores = np.zeros(10)
# cv = KFold(10, shuffle=True, random_state=0)
# for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
#     df_train = df_ols.iloc[idx_train]
#     df_test = df_ols.iloc[idx_test]
#
#     model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
#     result = model.fit()
#
#     pred = result.predict(df_test)
#     rss = ((df_test.value - pred) ** 2).sum()
#     tss = ((df_test.value - df_test.value.mean())** 2).sum()
#     rsquared = 1 - rss / tss
#
#     scores[i] = rsquared
# #    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
# print("모델 성능 : {}".format(scores.mean()))

# %% [markdown]
# # OLS - 22차

# %% [markdown]
# df_ols_21 = df_ols_20.drop(['passes_accuracy'], axis=1)
# len(df_ols_20.columns), len(df_ols_21.columns)

# %% [markdown]
# from sklearn.model_selection import train_test_split
#
# df_ols = df_ols_21
# dfX = df_ols.drop(['value'], axis=1)
# dfy = df_ols['value']
# df = pd.concat([dfX, dfy], axis=1)
# df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)
#
# feature_names = list(dfX.columns)
# feature_names = ["scale({})".format(name) for name in feature_names]
#
# #formula = "value ~ " + "+".join(feature_names)
#
# model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
# result = model.fit()
# print(result.summary())
#
#
#
#
# ##############################################################################
# from sklearn.model_selection import KFold
#
# scores = np.zeros(10)
# cv = KFold(10, shuffle=True, random_state=0)
# for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
#     df_train = df_ols.iloc[idx_train]
#     df_test = df_ols.iloc[idx_test]
#
#     model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
#     result = model.fit()
#
#     pred = result.predict(df_test)
#     rss = ((df_test.value - pred) ** 2).sum()
#     tss = ((df_test.value - df_test.value.mean())** 2).sum()
#     rsquared = 1 - rss / tss
#
#     scores[i] = rsquared
# #    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
# print("모델 성능 : {}".format(scores.mean()))

# %%
# 가중치

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_16
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ scale(age) + scale(I(age**2)) + scale(I(age**3)) + \
            scale(follower) + \
            scale(passes_accuracy) + \
            scale(penalty_won) + \
            scale(games_lineups) + \
            scale(substitutes_out) + \
            scale(games_played) + \
            scale(shotsOnTotal_goalsTotal) + \
            scale(gamesAppearance_sub)"

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())


##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.771
# Model:                            OLS   Adj. R-squared:                  0.726
# Method:                 Least Squares   F-statistic:                     16.87
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           6.83e-14
# Time:                        20:11:16   Log-Likelihood:                -276.06
# No. Observations:                  67   AIC:                             576.1
# Df Residuals:                      55   BIC:                             602.6
# Df Model:                          11
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         42.6493      2.009     21.228      0.000      38.623      46.676
# scale(age)                     -1892.9247    379.976     -4.982      0.000   -2654.414   -1131.436
# scale(I(age ** 2))              3820.9507    760.636      5.023      0.000    2296.602    5345.299
# scale(I(age ** 3))             -1955.5680    383.607     -5.098      0.000   -2724.334   -1186.802
# scale(follower)                   19.7782      3.214      6.154      0.000      13.337      26.219
# scale(passes_accuracy)             8.4373      2.890      2.920      0.005       2.646      14.229
# scale(penalty_won)                 6.5924      2.141      3.079      0.003       2.302      10.883
# scale(games_lineups)             -10.7759      4.329     -2.489      0.016     -19.451      -2.100
# scale(substitutes_out)            12.9591      4.071      3.183      0.002       4.800      21.118
# scale(games_played)               15.8208      3.033      5.217      0.000       9.743      21.898
# scale(shotsOnTotal_goalsTotal)     8.8513      3.160      2.801      0.007       2.518      15.184
# scale(gamesAppearance_sub)       -15.6056      5.306     -2.941      0.005     -26.239      -4.972
# ==============================================================================
# Omnibus:                       39.758   Durbin-Watson:                   2.192
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              152.411
# Skew:                           1.668   Prob(JB):                     8.02e-34
# Kurtosis:                       9.593   Cond. No.                         970.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.49986016615096424

# %% [markdown]
# # Ridge

# %%
result_ridge3 = model.fit_regularized(alpha=0.01, L1_wt=0)

# %%
dfX_test = df_test.drop(['value'], axis=1)
dfy_test = df_test['value']

# %%
pred = result_ridge3.predict(dfX_test)

rss = ((dfy_test.values - pred) ** 2).sum()
tss = ((dfy_test.values - dfy_test.values.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared
# Out:
# 0.42612200964541924

# %% [markdown]
# # Lasso

# %%
result_ridge3 = model.fit_regularized(alpha=0.01, L1_wt=1)

# %%
dfX_test = df_test.drop(['value'], axis=1)
dfy_test = df_test['value']

# %%
pred = result_ridge3.predict(dfX_test)

rss = ((dfy_test.values - pred) ** 2).sum()
tss = ((dfy_test.values - dfy_test.values.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared
# Out:
# 0.41346932667216074

# %% [markdown]
# # ElasticNet

# %%
result_ridge3 = model.fit_regularized(alpha=0.01, L1_wt=0.5)

# %%
dfX_test = df_test.drop(['value'], axis=1)
dfy_test = df_test['value']

# %%
pred = result_ridge3.predict(dfX_test)

rss = ((dfy_test.values - pred) ** 2).sum()
tss = ((dfy_test.values - dfy_test.values.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared
# Out:
# 0.3218179773592672
