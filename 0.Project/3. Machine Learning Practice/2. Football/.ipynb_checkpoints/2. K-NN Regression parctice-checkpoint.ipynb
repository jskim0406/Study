# %%
data = pd.read_csv("/Users/kimjeongseob/Desktop/Study/0.Project/3. Machine Learning Practice/2. Football/dataset_football.csv")

# %%
data = data.drop(columns = 'Unnamed: 0')

# %%
data_origin = data.copy()

# %%
data
# Out:
#         player_name  value  follower  shots_total  shots_on  goals_total  \
# 0       A. Anguissa   20.0     67879       0.5541    0.1288       0.0129
# 1        A. Bastoni   31.5    232370       0.3101    0.1128       0.0564
# 2        A. Belotti   32.0    740918       2.8169    1.0539       0.4432
# 3    A. Christensen   24.0    601838       0.3802    0.0613       0.0000
# 4         A. Correa   32.0    652886       1.9735    0.8442       0.2282
# ..              ...    ...       ...          ...       ...          ...
# 452         Y. Atal   20.0   1955121       1.3472    0.5672       0.1654
# 453     Y. Carrasco   22.5    797767       2.6060    0.8687       0.2044
# 454         Y. Mina   20.0   3339896       0.8766    0.3080       0.0711
# 455      Y. Poulsen   24.0    109000       2.0141    0.7524       0.3357
# 456    Y. Tielemans   44.0    282254       1.6978    0.6011       0.1476
#
#      goals_assists  passes_total  passes_key  passes_accuracy  ...  \
# 0           0.0000       22.1879      0.2706           3.2985  ...
# 1           0.0000       40.9924      0.3665          13.7863  ...
# 2           0.0985       12.3215      0.9554           4.0185  ...
# 3           0.0123       58.0206      0.1717          13.4535  ...
# 4           0.2167       23.4885      1.5286           9.1604  ...
# ..             ...           ...         ...              ...  ...
# 452         0.0236       28.5984      0.7800           5.6251  ...
# 453         0.3066       22.6878      1.6863          20.3373  ...
# 454         0.0474       46.6951      0.2843          14.5226  ...
# 455         0.2662       16.8654      1.2038           7.4314  ...
# 456         0.1371       38.4372      1.1705           6.6013  ...
#
#      penalty_missed  games_appearences  games_lineups  substitutes_in  \
# 0            0.0000             1.4045         0.9277          0.4767
# 1            0.0000             1.2969         0.9304          0.3665
# 2            0.0295             1.0539         0.9948          0.0591
# 3            0.0000             1.1160         1.0056          0.1104
# 4            0.0000             1.5514         0.9697          0.5818
# ..              ...                ...            ...             ...
# 452          0.0236             1.2290         0.9927          0.2364
# 453          0.0000             1.7885         0.8687          0.9198
# 454          0.0000             1.1846         1.0187          0.1658
# 455          0.0000             1.4006         0.9492          0.4514
# 456          0.0000             1.2022         1.0334          0.1687
#
#      substitutes_out  substitutes_bench   age  height  weight    rating
# 0             0.2577             0.5927  25.0   184.0    78.0  2.333333
# 1             0.0564             1.6070  21.0   190.0    75.0  4.777778
# 2             0.0689             0.0689  27.0   181.0    72.0  5.250000
# 3             0.1840             0.7604  24.0   188.0    78.0  6.000000
# 4             0.6731             0.6160  25.0   171.0    70.0  7.000000
# ..               ...                ...   ...     ...     ...       ...
# 452           0.1418             0.3782  24.0   176.0    64.0  3.333333
# 453           0.6643             1.2775  27.0   180.0    71.0  4.857143
# 454           0.0948             0.5449  26.0   195.0    94.0  6.125000
# 455           0.2894             0.5788  26.0   192.0    84.0  6.545455
# 456           0.3058             0.2636  23.0   176.0    72.0  4.384615
#
# [457 rows x 35 columns]

# %%
data.follower = data.follower + 10
data.follower = np.log(data.follower)

# %%
# data = data.drop(columns='player_name')

# %%
col_name = list(data.columns)
col_name.remove('player_name')

# %%
# from patsy import *

# %%
# col_names = ["scale({})".format(name) for name in col_name]

# %%
# col_names

# %%
# data_scaled = dmatrix("0+"+"+".join(col_names),data=data)

# %%
# data_scaled = pd.DataFrame(data_scaled,columns = [col_name])

# %%
# data_scaled

# %%
# from sklearn.preprocessing import MinMaxScaler

# scaler = MinMaxScaler()
# scaler.fit(data)
# scaled = scaler.transform(data)

# %%
# from sklearn.preprocessing import StandardScaler

# scaler = StandardScaler()
# scaler.fit(data)
# data_scaled = scaler.transform(data)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
classifier = KNeighborsClassifier(n_neighbors = 100)

# %%
data_X = data.drop(columns='value')

# %%
data_y = data.value

# %%
data_y = map(int,data_y)

# %%
data_y = list(data_y)

# %%
# data_y

# %%
data_X
# Out:
#         player_name   follower  shots_total  shots_on  goals_total  \
# 0       A. Anguissa  11.125629       0.5541    0.1288       0.0129
# 1        A. Bastoni  12.356129       0.3101    0.1128       0.0564
# 2        A. Belotti  13.515659       2.8169    1.0539       0.4432
# 3    A. Christensen  13.307760       0.3802    0.0613       0.0000
# 4         A. Correa  13.389173       1.9735    0.8442       0.2282
# ..              ...        ...          ...       ...          ...
# 452         Y. Atal  14.485968       1.3472    0.5672       0.1654
# 453     Y. Carrasco  13.589584       2.6060    0.8687       0.2044
# 454         Y. Mina  15.021453       0.8766    0.3080       0.0711
# 455      Y. Poulsen  11.599195       2.0141    0.7524       0.3357
# 456    Y. Tielemans  12.550598       1.6978    0.6011       0.1476
#
#      goals_assists  passes_total  passes_key  passes_accuracy  tackles_total  \
# 0           0.0000       22.1879      0.2706           3.2985         1.2112
# 1           0.0000       40.9924      0.3665          13.7863         1.0431
# 2           0.0985       12.3215      0.9554           4.0185         0.4629
# 3           0.0123       58.0206      0.1717          13.4535         1.0302
# 4           0.2167       23.4885      1.5286           9.1604         0.7757
# ..             ...           ...         ...              ...            ...
# 452         0.0236       28.5984      0.7800           5.6251         1.5835
# 453         0.3066       22.6878      1.6863          20.3373         0.0000
# 454         0.0474       46.6951      0.2843          14.5226         1.4925
# 455         0.2662       16.8654      1.2038           7.4314         0.3936
# 456         0.1371       38.4372      1.1705           6.6013         1.0018
#
#      ...  penalty_missed  games_appearences  games_lineups  substitutes_in  \
# 0    ...          0.0000             1.4045         0.9277          0.4767
# 1    ...          0.0000             1.2969         0.9304          0.3665
# 2    ...          0.0295             1.0539         0.9948          0.0591
# 3    ...          0.0000             1.1160         1.0056          0.1104
# 4    ...          0.0000             1.5514         0.9697          0.5818
# ..   ...             ...                ...            ...             ...
# 452  ...          0.0236             1.2290         0.9927          0.2364
# 453  ...          0.0000             1.7885         0.8687          0.9198
# 454  ...          0.0000             1.1846         1.0187          0.1658
# 455  ...          0.0000             1.4006         0.9492          0.4514
# 456  ...          0.0000             1.2022         1.0334          0.1687
#
#      substitutes_out  substitutes_bench   age  height  weight    rating
# 0             0.2577             0.5927  25.0   184.0    78.0  2.333333
# 1             0.0564             1.6070  21.0   190.0    75.0  4.777778
# 2             0.0689             0.0689  27.0   181.0    72.0  5.250000
# 3             0.1840             0.7604  24.0   188.0    78.0  6.000000
# 4             0.6731             0.6160  25.0   171.0    70.0  7.000000
# ..               ...                ...   ...     ...     ...       ...
# 452           0.1418             0.3782  24.0   176.0    64.0  3.333333
# 453           0.6643             1.2775  27.0   180.0    71.0  4.857143
# 454           0.0948             0.5449  26.0   195.0    94.0  6.125000
# 455           0.2894             0.5788  26.0   192.0    84.0  6.545455
# 456           0.3058             0.2636  23.0   176.0    72.0  4.384615
#
# [457 rows x 34 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data_X, data_y, test_size=0.4, random_state=0)

# %%
X_train.shape
# Out:
# (274, 34)

# %%
X_test.shape
# Out:
# (183, 34)

# %%
len(y_train)
# Out:
# 274

# %%
len(y_test)
# Out:
# 183

# %%
classifier.fit(X_train.drop(columns='player_name'), y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=100, p=2,
#                      weights='uniform')

# %%
X_train
# Out:
#        player_name   follower  shots_total  shots_on  goals_total  \
# 395    S. Busquets  14.907236       0.2460    0.0820       0.0246
# 418    T. Bakayoko  13.943641       1.3460    0.2868       0.0552
# 176        I. Sarr  12.427915       1.8658    0.6785       0.2908
# 374        R. Lodi  12.359536       0.7680    0.2304       0.0384
# 116      E. Hazard  17.105970       2.4497    1.1405       0.3967
# ..             ...        ...          ...       ...          ...
# 323  N'Golo KantÃ©  15.761440       0.7781    0.1729       0.0778
# 192      J. FÃ©lix  14.999321       2.8164    0.9645       0.4823
# 117    E. MilitÃ£o  13.952848       0.3630    0.1815       0.0000
# 47     B. Chilwell  12.550187       0.4998    0.1874       0.0208
# 172     I. KonatÃ©  11.014967       0.3686    0.0768       0.0461
#
#      goals_assists  passes_total  passes_key  passes_accuracy  tackles_total  \
# 395         0.0656       72.3598      0.7461           6.5759         1.3119
# 418         0.0662       44.3182      0.8164          11.4188         2.0300
# 176         0.1696       15.4228      1.1025           4.7613         0.4604
# 374         0.1152       26.2289      0.8833           5.7988         2.3041
# 116         0.2876       40.8708      2.9257           8.2614         0.2777
# ..             ...           ...         ...              ...            ...
# 323         0.0519       49.2349      1.2017           8.2649         2.2996
# 192         0.1929       19.3673      1.0995           9.2593         0.3665
# 117         0.0000       46.1887      0.0907          23.4120         1.8149
# 47          0.1041       36.6552      1.0934           5.5816         1.3954
# 172         0.0154       31.4084      0.1843           9.7988         0.9062
#
#      ...  penalty_missed  games_appearences  games_lineups  substitutes_in  \
# 395  ...             0.0             1.1151         1.0167          0.0984
# 418  ...             0.0             1.1805         1.0150          0.1655
# 176  ...             0.0             1.1873         1.0177          0.1696
# 374  ...             0.0             1.1905         1.0753          0.1152
# 116  ...             0.0             1.2100         0.9918          0.2182
# ..   ...             ...                ...            ...             ...
# 323  ...             0.0             1.0893         1.0115          0.0778
# 192  ...             0.0             1.2924         1.0417          0.2508
# 117  ...             0.0             1.1797         0.9982          0.1815
# 47   ...             0.0             1.0413         0.9893          0.0521
# 172  ...             0.0             1.0905         1.0137          0.0768
#
#      substitutes_out  substitutes_bench   age  height  weight    rating
# 395           0.3034             0.1558  32.0   189.0    76.0  6.300000
# 418           0.1434             0.3089  26.0   185.0    77.0  6.538462
# 176           0.4119             0.2060  22.0   185.0    76.0  2.916667
# 374           0.3072             0.1920  22.0   173.0    68.0  4.666667
# 116           0.4661             0.2678  29.0   175.0    74.0  6.416667
# ..               ...                ...   ...     ...     ...       ...
# 323           0.1383             0.1210  29.0   168.0    68.0  5.571429
# 192           0.6752             0.3665  21.0   181.0    70.0  5.500000
# 117           0.0907             2.2686  22.0   186.0    79.0  7.000000
# 47            0.0521             0.1562  24.0   178.0    77.0  5.555556
# 172           0.0922             0.4761  21.0   192.0    93.0  5.600000
#
# [274 rows x 34 columns]

# %%
len(y_train)
# Out:
# 274

# %%
print(classifier.score(X_test.drop(columns='player_name'),y_test))
# Out:
# 0.08743169398907104

# %%
import matplotlib.pyplot as plt
k_list = range(1,101)
accuracies = []
for k in k_list:
    classifier = KNeighborsClassifier(n_neighbors = k)
    classifier.fit(X_train.drop(columns='player_name'), y_train)
    accuracies.append(classifier.score(X_test.drop(columns='player_name'), y_test))
plt.plot(k_list, accuracies)
plt.xlabel("k")
plt.ylabel("Validation Accuracy")
plt.title("Breast Cancer Classifier Accuracy")
plt.show()

# %% [markdown]
# # K-NN regression 알고리즘

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
regressor = KNeighborsRegressor(n_neighbors = 10, weights = "distance")

# %%
regressor.fit(X_train.drop(columns='player_name'), y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                     weights='distance')

# %%
y_pred = regressor.predict(X_test.drop(columns='player_name'))
y_pred_train = regressor.predict(X_train.drop(columns='player_name'))

# %%
result = []

for i in range(len(y_pred)):
    if y_test[i] < y_pred[i]:
        result.append("overpaid")
    else:
        result.append("underpaid")

# %%
result
# Out:
# ['overpaid',
#  'underpaid',
#  'underpaid',
#  'overpaid',
#  'overpaid',
#  'underpaid',
#  'underpaid',
#  'underpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'underpaid',
#  'underpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'underpaid',
#  'underpaid',
#  'underpaid',
#  'overpaid',
#  'underpaid',
#  'overpaid',
#  'underpaid',
#  'overpaid',
#  'overpaid',
#  'underpaid',
#  'underpaid',
#  'underpaid',
#  'overpaid',
#  'overpaid',
#  'underpaid',
#  'underpaid',
#  'overpaid',
#  'underpaid',
#  'underpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'underpaid',
#  'overpaid',
#  'underpaid',
#  'overpaid',
#  'overpaid',
#  'underpaid',
#  'underpaid',
#  'overpaid',
#  'underpaid',
#  'underpaid',
#  'underpaid',
#  'overpaid',
#  'overpaid',
#  'underpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'underpaid',
#  'underpaid',
#  'overpaid',
#  'overpaid',
#  'underpaid',
#  'overpaid',
#  'overpaid',
#  'underpaid',
#  'underpaid',
#  'underpaid',
#  'underpaid',
#  'underpaid',
#  'overpaid',
#  'overpaid',
#  'underpaid',
#  'overpaid',
#  'underpaid',
#  'overpaid',
#  'overpaid',
#  'underpaid',
#  'overpaid',
#  'underpaid',
#  'overpaid',
#  'underpaid',
#  'underpaid',
#  'underpaid',
#  'overpaid',
#  'underpaid',
#  'underpaid',
#  'underpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'underpaid',
#  'overpaid',
#  'underpaid',
#  'underpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'underpaid',
#  'underpaid',
#  'underpaid',
#  'underpaid',
#  'overpaid',
#  'overpaid',
#  'underpaid',
#  'overpaid',
#  'underpaid',
#  'overpaid',
#  'underpaid',
#  'overpaid',
#  'overpaid',
#  'underpaid',
#  'overpaid',
#  'overpaid',
#  'underpaid',
#  'underpaid',
#  'underpaid',
#  'underpaid',
#  'underpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'underpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'underpaid',
#  'underpaid',
#  'overpaid',
#  'underpaid',
#  'overpaid',
#  'underpaid',
#  'overpaid',
#  'overpaid',
#  'underpaid',
#  'overpaid',
#  'overpaid',
#  'underpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'underpaid',
#  'overpaid',
#  'underpaid',
#  'underpaid',
#  'underpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'underpaid',
#  'underpaid',
#  'underpaid',
#  'underpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid']

# %%
len(y_pred)
# Out:
# 183

# %%
# X_train = X_train.reset_index().drop(columns='index')
X_test = X_test.reset_index().drop(columns='index')

# %%
X_train
# Out:
#        player_name   follower  shots_total  shots_on  goals_total  \
# 395    S. Busquets  14.907236       0.2460    0.0820       0.0246
# 418    T. Bakayoko  13.943641       1.3460    0.2868       0.0552
# 176        I. Sarr  12.427915       1.8658    0.6785       0.2908
# 374        R. Lodi  12.359536       0.7680    0.2304       0.0384
# 116      E. Hazard  17.105970       2.4497    1.1405       0.3967
# ..             ...        ...          ...       ...          ...
# 323  N'Golo KantÃ©  15.761440       0.7781    0.1729       0.0778
# 192      J. FÃ©lix  14.999321       2.8164    0.9645       0.4823
# 117    E. MilitÃ£o  13.952848       0.3630    0.1815       0.0000
# 47     B. Chilwell  12.550187       0.4998    0.1874       0.0208
# 172     I. KonatÃ©  11.014967       0.3686    0.0768       0.0461
#
#      goals_assists  passes_total  passes_key  passes_accuracy  tackles_total  \
# 395         0.0656       72.3598      0.7461           6.5759         1.3119
# 418         0.0662       44.3182      0.8164          11.4188         2.0300
# 176         0.1696       15.4228      1.1025           4.7613         0.4604
# 374         0.1152       26.2289      0.8833           5.7988         2.3041
# 116         0.2876       40.8708      2.9257           8.2614         0.2777
# ..             ...           ...         ...              ...            ...
# 323         0.0519       49.2349      1.2017           8.2649         2.2996
# 192         0.1929       19.3673      1.0995           9.2593         0.3665
# 117         0.0000       46.1887      0.0907          23.4120         1.8149
# 47          0.1041       36.6552      1.0934           5.5816         1.3954
# 172         0.0154       31.4084      0.1843           9.7988         0.9062
#
#      ...  penalty_missed  games_appearences  games_lineups  substitutes_in  \
# 395  ...             0.0             1.1151         1.0167          0.0984
# 418  ...             0.0             1.1805         1.0150          0.1655
# 176  ...             0.0             1.1873         1.0177          0.1696
# 374  ...             0.0             1.1905         1.0753          0.1152
# 116  ...             0.0             1.2100         0.9918          0.2182
# ..   ...             ...                ...            ...             ...
# 323  ...             0.0             1.0893         1.0115          0.0778
# 192  ...             0.0             1.2924         1.0417          0.2508
# 117  ...             0.0             1.1797         0.9982          0.1815
# 47   ...             0.0             1.0413         0.9893          0.0521
# 172  ...             0.0             1.0905         1.0137          0.0768
#
#      substitutes_out  substitutes_bench   age  height  weight    rating
# 395           0.3034             0.1558  32.0   189.0    76.0  6.300000
# 418           0.1434             0.3089  26.0   185.0    77.0  6.538462
# 176           0.4119             0.2060  22.0   185.0    76.0  2.916667
# 374           0.3072             0.1920  22.0   173.0    68.0  4.666667
# 116           0.4661             0.2678  29.0   175.0    74.0  6.416667
# ..               ...                ...   ...     ...     ...       ...
# 323           0.1383             0.1210  29.0   168.0    68.0  5.571429
# 192           0.6752             0.3665  21.0   181.0    70.0  5.500000
# 117           0.0907             2.2686  22.0   186.0    79.0  7.000000
# 47            0.0521             0.1562  24.0   178.0    77.0  5.555556
# 172           0.0922             0.4761  21.0   192.0    93.0  5.600000
#
# [274 rows x 34 columns]

# %%
X_test
# Out:
#      player_name   follower  shots_total  shots_on  goals_total  \
# 0      H. Wilson  12.918201       2.6999    1.0141       0.4346
# 1       K. Kampl  12.049243       0.7227    0.2677       0.0669
# 2       M. Salah  17.470353       4.0541    1.7630       0.7067
# 3      K. BaldÃ©  13.547245       2.1880    1.0419       0.4376
# 4    F. Anderson  13.125941       1.6084    0.6546       0.2057
# ..           ...        ...          ...       ...          ...
# 178   K. MbappÃ©  17.524389       3.0286    1.6620       0.8310
# 179    A. Ramsey  15.216520       2.4221    0.9929       0.3310
# 180  E. Forsberg  11.719997       2.1616    0.8711       0.3549
# 181     J. Firpo  13.295863       0.3005    0.0751       0.0751
# 182  D. Vlahovic  11.534149       3.5308    1.0820       0.4556
#
#      goals_assists  passes_total  passes_key  passes_accuracy  tackles_total  \
# 0           0.1054       22.8237      1.3565           7.7703         0.7639
# 1           0.1338       33.7928      1.2179          12.7141         0.5889
# 2           0.2485       22.0565      1.8639           6.2442         0.4039
# 3           0.2084       18.1913      1.0627          12.6485         0.3126
# 4           0.2057       40.1160      1.8702           8.7339         2.5996
# ..             ...           ...         ...              ...            ...
# 178         0.2862       18.5411      1.3943           7.2207         0.1385
# 179         0.2407       45.2535      1.3239          11.8851         1.4593
# 180         0.2420       26.8914      2.3068          11.0179         0.5969
# 181         0.0000       51.8407      0.6011          19.3088         1.5778
# 182         0.0000       10.3645      0.6264           9.2825         0.3417
#
#      ...  penalty_missed  games_appearences  games_lineups  substitutes_in  \
# 0    ...          0.0132             1.2116         1.0668          0.1449
# 1    ...          0.0000             1.1777         0.9770          0.2007
# 2    ...          0.0078             1.0951         1.0329          0.0621
# 3    ...          0.0000             1.8337         0.9794          0.8543
# 4    ...          0.0000             1.2156         1.0660          0.1496
# ..   ...             ...                ...            ...             ...
# 178  ...          0.0000             1.1450         0.9880          0.1570
# 179  ...          0.0000             1.4743         1.0080          0.4664
# 180  ...          0.0000             1.4680         1.0002          0.4678
# 181  ...          0.0000             1.2772         0.9767          0.3005
# 182  ...          0.0000             2.0501         0.7973          1.2528
#
#      substitutes_out  substitutes_bench   age  height  weight    rating
# 0             0.6190             0.1976  23.0   173.0    70.0  6.111111
# 1             0.3346             0.3078  30.0   178.0    67.0  5.923077
# 2             0.4116             0.0777  28.0   175.0    71.0  6.153846
# 3             0.6876             1.2086  25.0   184.0    80.0  5.090909
# 4             0.4863             0.1683  27.0   175.0    70.0  7.166667
# ..               ...                ...   ...     ...     ...       ...
# 178           0.2308             0.2216  22.0   178.0    73.0  4.875000
# 179           0.4513             0.6168  30.0   178.0    76.0  5.833333
# 180           0.5969             0.6775  29.0   179.0    78.0  5.909091
# 181           0.1503             1.0518  24.0   184.0    78.0  7.000000
# 182           0.2847             2.5057  20.0   190.0    75.0  4.750000
#
# [183 rows x 34 columns]

# %%
X_test.loc[1]['player_name']
# Out:
# 'K. Kampl'

# %%
underpaid = []

for i in range(len(y_pred)):
    if result[i] == 'underpaid':
        underpaid.append(X_test.loc[i]['player_name'])

# %%
len(underpaid)
# Out:
# 76

# %%
underpaid
# Out:
# ['K. Kampl',
#  'M. Salah',
#  'L. Messi',
#  'R. Bentancur',
#  'A. Griezmann',
#  'D. Upamecano',
#  'C. Eriksen',
#  'D. Alaba',
#  'Y. Tielemans',
#  'K. De Bruyne',
#  'A. Bastoni',
#  'Jorginho',
#  'G. Wijnaldum',
#  'R. Varane',
#  'R. JimÃ©nez',
#  'D. van de Beek',
#  'D. Kulusevski',
#  'T. Alexander-Arnold',
#  'L. Insigne',
#  'A. Silva',
#  'K. Trippier',
#  'M. Pjanic',
#  'M. Mount',
#  'I. GÃ¼ndogan',
#  'R. Firmino',
#  'O. DembÃ©lÃ©',
#  'S. Ã‘Ã\xadguez',
#  'S. Milinkovic-Savic',
#  'F. Chiesa',
#  'T. Kroos',
#  'H. Kane',
#  'D. SÃ¡nchez',
#  'V. van Dijk',
#  'J. Kimmich',
#  'R. Sterling',
#  'N. Zaniolo',
#  'J. RodrÃ\xadguez',
#  'F. Torres_Val',
#  'C. Nkunku',
#  'Koke_ATM',
#  'B. Silva',
#  'H. Aouar',
#  'L. Jovic',
#  'Isco',
#  'M. Kumbulla',
#  'B. Kamara_MSU',
#  'A. Oxlade-Chamberlain',
#  'Arthur',
#  'A. Davies_Mun',
#  'L. SanÃ©',
#  'L. MartÃ\xadnez_inter',
#  'F. Valverde',
#  'R. Neves',
#  'C. Soler',
#  'A. Laporte',
#  'A. Hakimi',
#  'W. Ndidi',
#  'J. Cancelo',
#  'M. Demiral',
#  'Casemiro',
#  'C. Lenglet',
#  'P. Dybala',
#  'M. Verratti',
#  'Rodrygo',
#  'M. DembÃ©lÃ©_Lyn',
#  'M. Greenwood',
#  'M. Depay',
#  'A. Kramaric',
#  'L. Alberto',
#  'L. Dendoncker',
#  'C. Pulisic',
#  'M. Diaby',
#  'G. Jesus',
#  'J. Maddison',
#  'K. MbappÃ©',
#  'A. Ramsey']

# %% [markdown]
# # K-NN regression 알고리즘 -> 전체를 다 학습시킴..

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
regressor = KNeighborsRegressor(n_neighbors = 10, weights = "distance")

# %%
regressor.fit(data.drop(columns=['player_name','value']), data.value)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                     weights='distance')

# %%
y_pred = regressor.predict(data.drop(columns=['player_name','value']))

# %%
result = []

for i in range(len(y_pred)):
    if data.value[i] < y_pred[i]:
        result.append("underpaid")
    else:
        result.append("overpaid")

# %%
data.value[1]
# Out:
# 31.5

# %%
y_pred[1]
# Out:
# 31.5

# %%
result
# Out:
# ['overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid',
#  'overpaid']

# %%
len(y_pred)
# Out:
# 457

# %%
# X_train = X_train.reset_index().drop(columns='index')
X_test = X_test.reset_index().drop(columns='index')

# %%
X_train
# Out:
#        player_name   follower  shots_total  shots_on  goals_total  \
# 0    G. Sigurdsson  12.357978       1.9891    0.7500       0.2391
# 1      M. Llorente  14.500676       0.3824    0.0956       0.2868
# 2           Wesley  10.966645       0.4836    0.2579       0.3761
# 3        M. Vecino  12.755194       1.8118    0.6471       0.1424
# 4        Q. Promes  13.344817       3.1250    1.5405       0.7042
# ..             ...        ...          ...       ...          ...
# 314  N'Golo KantÃ©  15.761440       0.7781    0.1729       0.0778
# 315      J. FÃ©lix  14.999321       2.8164    0.9645       0.4823
# 316    E. MilitÃ£o  13.952848       0.3630    0.1815       0.0000
# 317    B. Chilwell  12.550187       0.4998    0.1874       0.0208
# 318     I. KonatÃ©  11.014967       0.3686    0.0768       0.0461
#
#      goals_assists  passes_total  passes_key  passes_accuracy  tackles_total  \
# 0           0.1522       22.8478      1.9565           7.6522         1.4783
# 1           0.0000       27.3423      0.0956          23.5182         2.1033
# 2           0.0107        4.1156      0.2042           2.3641         0.1397
# 3           0.0776       43.7815      0.8930          10.1980         1.1130
# 4           0.1761       40.5370      2.1567          14.6127         0.7923
# ..             ...           ...         ...              ...            ...
# 314         0.0519       49.2349      1.2017           8.2649         2.2996
# 315         0.1929       19.3673      1.0995           9.2593         0.3665
# 316         0.0000       46.1887      0.0907          23.4120         1.8149
# 317         0.1041       36.6552      1.0934           5.5816         1.3954
# 318         0.0154       31.4084      0.1843           9.7988         0.9062
#
#      ...  penalty_missed  games_appearences  games_lineups  substitutes_in  \
# 0    ...          0.0326             1.1196         1.0217          0.0978
# 1    ...          0.0000             2.1033         0.8604          1.2428
# 2    ...          0.0107             1.2143         1.0531          0.1612
# 3    ...          0.0000             1.2165         1.0094          0.2071
# 4    ...          0.0000             1.1884         1.0563          0.1320
# ..   ...             ...                ...            ...             ...
# 314  ...          0.0000             1.0893         1.0115          0.0778
# 315  ...          0.0000             1.2924         1.0417          0.2508
# 316  ...          0.0000             1.1797         0.9982          0.1815
# 317  ...          0.0000             1.0413         0.9893          0.0521
# 318  ...          0.0000             1.0905         1.0137          0.0768
#
#      substitutes_out  substitutes_bench        age      height     weight  \
# 0             0.3696             0.1522  31.000000  186.000000  79.000000
# 1             0.4780             2.3901  25.000000  184.000000  74.000000
# 2             0.5158             0.3116  23.076923  188.230769  86.769231
# 3             0.2588             0.4400  29.000000  187.000000  81.000000
# 4             0.3961             0.3081  28.000000  174.000000  71.000000
# ..               ...                ...        ...         ...        ...
# 314           0.1383             0.1210  29.000000  168.000000  68.000000
# 315           0.6752             0.3665  21.000000  181.000000  70.000000
# 316           0.0907             2.2686  22.000000  186.000000  79.000000
# 317           0.0521             0.1562  24.000000  178.000000  77.000000
# 318           0.0922             0.4761  21.000000  192.000000  93.000000
#
#        rating
# 0    6.400000
# 1    7.000000
# 2    1.615385
# 3    7.100000
# 4    7.000000
# ..        ...
# 314  5.571429
# 315  5.500000
# 316  7.000000
# 317  5.555556
# 318  5.600000
#
# [319 rows x 34 columns]

# %%
X_test
# Out:
#      player_name   follower  shots_total  shots_on  goals_total  \
# 0      H. Wilson  12.918201       2.6999    1.0141       0.4346
# 1       K. Kampl  12.049243       0.7227    0.2677       0.0669
# 2       M. Salah  17.470353       4.0541    1.7630       0.7067
# 3      K. BaldÃ©  13.547245       2.1880    1.0419       0.4376
# 4    F. Anderson  13.125941       1.6084    0.6546       0.2057
# ..           ...        ...          ...       ...          ...
# 133     M. Boadu  10.971623       2.0824    1.0069       0.5263
# 134     I. Gueye  13.398494       0.6099    0.1577       0.0421
# 135     T. Mings  12.218031       0.3217    0.2011       0.0804
# 136   U. NÃºÃ±ez  10.612016       0.8116    0.1671       0.0239
# 137    N. Semedo  14.917822       0.2865    0.0836       0.0119
#
#      goals_assists  passes_total  passes_key  passes_accuracy  tackles_total  \
# 0           0.1054       22.8237      1.3565           7.7703         0.7639
# 1           0.1338       33.7928      1.2179          12.7141         0.5889
# 2           0.2485       22.0565      1.8639           6.2442         0.4039
# 3           0.2084       18.1913      1.0627          12.6485         0.3126
# 4           0.2057       40.1160      1.8702           8.7339         2.5996
# ..             ...           ...         ...              ...            ...
# 133         0.2288       12.7002      1.0069          10.1144         0.2517
# 134         0.0631       53.3495      0.6836           7.4771         3.6071
# 135         0.0201       35.0292      0.2614           6.8369         0.5630
# 136         0.0358       40.8879      0.5013           9.9893         0.7996
# 137         0.0716       52.0291      0.5849          10.2889         1.3607
#
#      ...  penalty_missed  games_appearences  games_lineups  substitutes_in  \
# 0    ...          0.0132             1.2116         1.0668          0.1449
# 1    ...          0.0000             1.1777         0.9770          0.2007
# 2    ...          0.0078             1.0951         1.0329          0.0621
# 3    ...          0.0000             1.8337         0.9794          0.8543
# 4    ...          0.0000             1.2156         1.0660          0.1496
# ..   ...             ...                ...            ...             ...
# 133  ...          0.0000             1.1670         1.0526          0.1144
# 134  ...          0.0000             1.0937         1.0411          0.0526
# 135  ...          0.0000             1.1261         1.0456          0.0804
# 136  ...          0.0000             1.1457         1.0144          0.1313
# 137  ...          0.0000             1.3249         1.0384          0.2865
#
#      substitutes_out  substitutes_bench        age      height     weight  \
# 0             0.6190             0.1976  23.000000  173.000000  70.000000
# 1             0.3346             0.3078  30.000000  178.000000  67.000000
# 2             0.4116             0.0777  28.000000  175.000000  71.000000
# 3             0.6876             1.2086  25.000000  184.000000  80.000000
# 4             0.4863             0.1683  27.000000  175.000000  70.000000
# ..               ...                ...        ...         ...        ...
# 133           0.4348             0.1602  19.000000  183.000000  67.000000
# 134           0.1893             0.1262  31.000000  174.000000  66.000000
# 135           0.1005             0.3620  27.000000  196.000000  77.000000
# 136           0.2148             0.8235  23.727273  180.181818  75.636364
# 137           0.2387             0.5968  27.000000  177.000000  67.000000
#
#        rating
# 0    6.111111
# 1    5.923077
# 2    6.153846
# 3    5.090909
# 4    7.166667
# ..        ...
# 133  4.250000
# 134  5.181818
# 135  3.888889
# 136  6.363636
# 137  6.363636
#
# [138 rows x 34 columns]

# %%
X_test.loc[1]['player_name']
# Out:
# 'K. Kampl'

# %%
underpaid = []

for i in range(len(y_pred)):
    if result[i] == 'underpaid':
        underpaid.append(X_test.loc[i]['player_name'])

# %%
len(underpaid)
# Out:
# 76

# %%
X_test
# Out:
#      player_name   follower  shots_total  shots_on  goals_total  \
# 0      H. Wilson  12.918201       2.6999    1.0141       0.4346
# 1       K. Kampl  12.049243       0.7227    0.2677       0.0669
# 2       M. Salah  17.470353       4.0541    1.7630       0.7067
# 3      K. BaldÃ©  13.547245       2.1880    1.0419       0.4376
# 4    F. Anderson  13.125941       1.6084    0.6546       0.2057
# ..           ...        ...          ...       ...          ...
# 178   K. MbappÃ©  17.524389       3.0286    1.6620       0.8310
# 179    A. Ramsey  15.216520       2.4221    0.9929       0.3310
# 180  E. Forsberg  11.719997       2.1616    0.8711       0.3549
# 181     J. Firpo  13.295863       0.3005    0.0751       0.0751
# 182  D. Vlahovic  11.534149       3.5308    1.0820       0.4556
#
#      goals_assists  passes_total  passes_key  passes_accuracy  tackles_total  \
# 0           0.1054       22.8237      1.3565           7.7703         0.7639
# 1           0.1338       33.7928      1.2179          12.7141         0.5889
# 2           0.2485       22.0565      1.8639           6.2442         0.4039
# 3           0.2084       18.1913      1.0627          12.6485         0.3126
# 4           0.2057       40.1160      1.8702           8.7339         2.5996
# ..             ...           ...         ...              ...            ...
# 178         0.2862       18.5411      1.3943           7.2207         0.1385
# 179         0.2407       45.2535      1.3239          11.8851         1.4593
# 180         0.2420       26.8914      2.3068          11.0179         0.5969
# 181         0.0000       51.8407      0.6011          19.3088         1.5778
# 182         0.0000       10.3645      0.6264           9.2825         0.3417
#
#      ...  penalty_missed  games_appearences  games_lineups  substitutes_in  \
# 0    ...          0.0132             1.2116         1.0668          0.1449
# 1    ...          0.0000             1.1777         0.9770          0.2007
# 2    ...          0.0078             1.0951         1.0329          0.0621
# 3    ...          0.0000             1.8337         0.9794          0.8543
# 4    ...          0.0000             1.2156         1.0660          0.1496
# ..   ...             ...                ...            ...             ...
# 178  ...          0.0000             1.1450         0.9880          0.1570
# 179  ...          0.0000             1.4743         1.0080          0.4664
# 180  ...          0.0000             1.4680         1.0002          0.4678
# 181  ...          0.0000             1.2772         0.9767          0.3005
# 182  ...          0.0000             2.0501         0.7973          1.2528
#
#      substitutes_out  substitutes_bench   age  height  weight    rating
# 0             0.6190             0.1976  23.0   173.0    70.0  6.111111
# 1             0.3346             0.3078  30.0   178.0    67.0  5.923077
# 2             0.4116             0.0777  28.0   175.0    71.0  6.153846
# 3             0.6876             1.2086  25.0   184.0    80.0  5.090909
# 4             0.4863             0.1683  27.0   175.0    70.0  7.166667
# ..               ...                ...   ...     ...     ...       ...
# 178           0.2308             0.2216  22.0   178.0    73.0  4.875000
# 179           0.4513             0.6168  30.0   178.0    76.0  5.833333
# 180           0.5969             0.6775  29.0   179.0    78.0  5.909091
# 181           0.1503             1.0518  24.0   184.0    78.0  7.000000
# 182           0.2847             2.5057  20.0   190.0    75.0  4.750000
#
# [183 rows x 34 columns]
